# %% [markdown]
# --CNN--

# %%
import os
from glob import glob
import numpy as np
import librosa
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, StratifiedKFold
import joblib
# Out:
# 2025-10-22 13:29:29.997030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761139770.173846      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761139770.228177      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
class FreqTemporalCoAttention(layers.Layer):
    """
    A custom layer to learn to focus on important frequency bands and
    time steps within a feature map simultaneously.
    """
    def __init__(self, ratio=8, **kwargs):
        super(FreqTemporalCoAttention, self).__init__(**kwargs)
        self.ratio = ratio

    def build(self, input_shape):
        # input_shape: (batch, height, width, channels)
        # height ~ frequency, width ~ time
        self.channels = input_shape[-1]
        
        # Neural network for Temporal Attention
        self.temporal_dense1 = layers.Dense(self.channels // self.ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)
        self.temporal_dense2 = layers.Dense(self.channels, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)
        
        # Neural network for Frequency Attention
        self.freq_dense1 = layers.Dense(self.channels // self.ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)
        self.freq_dense2 = layers.Dense(self.channels, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)
        
        super(FreqTemporalCoAttention, self).build(input_shape)

    def call(self, inputs):
        # inputs shape: (batch, freq_bins, time_steps, channels)
        
        # --- Temporal Attention ---
        # Squeeze along the frequency axis -> (batch, time_steps, channels)
        temporal_features = tf.reduce_mean(inputs, axis=1)
        temporal_attention = self.temporal_dense1(temporal_features)
        temporal_attention = self.temporal_dense2(temporal_attention)
        temporal_attention = tf.expand_dims(temporal_attention, axis=1) # (batch, 1, time_steps, channels)

        # --- Frequency Attention ---
        # Squeeze along the time axis -> (batch, freq_bins, channels)
        freq_features = tf.reduce_mean(inputs, axis=2)
        freq_attention = self.freq_dense1(freq_features)
        freq_attention = self.freq_dense2(freq_attention)
        freq_attention = tf.expand_dims(freq_attention, axis=2) # (batch, freq_bins, 1, channels)

        # Recalibrate the original feature map by multiplying with attention weights
        refined_feature_map = inputs * temporal_attention * freq_attention
        
        return refined_feature_map

    def get_config(self):
        config = super().get_config()
        config.update({'ratio': self.ratio})
        return config

# %%
EMO_DB = False

if EMO_DB:
    EMOTIONS = ['Angry', 'Happy', 'Fear', 'Neutral', 'Sad', 'Boredom', 'Disgust']
    NUM_CLASSES = len(EMOTIONS)
    emotion_map = {
        'Angry': 0, 
        'Happy': 1, 
        'Fear': 2, 
        'Neutral': 3, 
        'Sad': 4, 
        'Boredom': 5, 
        'Disgust': 6
    }
    DATA_PATH = '/kaggle/input/speech-emotion-10/EmoDB/EmoDB'
else:
    EMOTIONS = ['Angry', 'Happy', 'Anxiety', 'Neutral', 'Sad']
    NUM_CLASSES = len(EMOTIONS)
    emotion_map = {
        'Angry': 0, 'Happy': 1, 'Anxiety': 2, 'Neutral': 3, 'Sad': 4
    }
    DATA_PATH = '/kaggle/input/speech-emotion-10/VESC/VESC'

# Actual calculation needed from the data
GLOBAL_MEAN_PITCH = 0.0
GLOBAL_JITTER = 0.0
GLOBAL_PITCH_SLOPE = 0.0

# Function to add noise
def add_noise(audio, noise_factor=0.01):
    noise = np.random.randn(len(audio))
    return audio + noise_factor * noise

# Function to change pitch
def pitch_shift(audio, sr, n_steps=1): # Random n_steps
    return librosa.effects.pitch_shift(audio, sr=sr, n_steps=n_steps)

# Function to apply time stretching
def time_stretch(audio, rate=0.95): # Random rate
    return librosa.effects.time_stretch(audio, rate=rate)

# Function to apply time shifting
def time_shift(audio, shift_max=0.15, sr= 24200):
    shift = int(np.random.uniform(-shift_max, shift_max) * sr)
    return np.roll(audio, shift)

# Function to normalize pitch
def normalize_pitch(pitches):
    pitches = pitches[pitches > 0]
    if len(pitches) == 0:
        return GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE

    mean_pitch = np.mean(pitches)
    normalized_pitches = pitches - mean_pitch
    jitter = np.std(normalized_pitches) if len(normalized_pitches) > 0 else 0

    if len(pitches) > 1:
        slope = np.polyfit(np.arange(len(pitches)), pitches, 1)[0]
    else:
        slope = 0

    if np.isnan(mean_pitch): mean_pitch = GLOBAL_MEAN_PITCH
    if np.isnan(jitter): jitter = GLOBAL_JITTER
    if np.isnan(slope): slope = GLOBAL_PITCH_SLOPE

    return mean_pitch, jitter, slope

# Feature extraction
def extract_features(audio_path, sample_rate= 24200, duration=10, n_mfcc=26, n_frames=157, augment_type='normal', global_pitch_params=None):
    try:
        audio, sr = librosa.load(audio_path, sr=sample_rate)
        target_length = sample_rate * duration

        if len(audio) < target_length:
            audio = np.pad(audio, (0, target_length - len(audio)), mode='constant')
        else:
            audio = audio[:target_length]

        if augment_type == 'noise':
            audio = add_noise(audio)
        elif augment_type == 'pitch':
            audio = pitch_shift(audio, sr)
        elif augment_type == 'stretch':
            audio = time_stretch(audio)
        elif augment_type == 'shift':
            audio = time_shift(audio)

        hop_length = target_length // (n_frames - 1)

        # MFCCs + Delta + Delta-Delta
        mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length, n_fft=2048)
        mfcc_delta = librosa.feature.delta(mfcc)
        mfcc_delta2 = librosa.feature.delta(mfcc, order=2)
        mfcc_features = np.concatenate((mfcc, mfcc_delta, mfcc_delta2), axis=0)

        # Pad or truncate MFCCs
        if mfcc_features.shape[1] > n_frames:
            mfcc_features = mfcc_features[:, :n_frames]
        elif mfcc_features.shape[1] < n_frames:
            mfcc_features = np.pad(mfcc_features, ((0, 0), (0, n_frames - mfcc_features.shape[1])), mode='constant')

        # Pitch features
        pitches, magnitudes = librosa.piptrack(y=audio, sr=sr, hop_length=hop_length)
        if global_pitch_params:
            mean_pitch, jitter, pitch_slope = normalize_pitch(pitches)
            if mean_pitch == 0 and jitter == 0 and pitch_slope == 0:
                mean_pitch, jitter, pitch_slope = global_pitch_params
        else:
            mean_pitch, jitter, pitch_slope = normalize_pitch(pitches) # Will use current GLOBAL_*

        pitch_features_single = np.array([mean_pitch, jitter, pitch_slope])
        pitch_features = np.tile(pitch_features_single, (n_frames, 1)).T # Tile to match n_frames

        # Energy features (RMS + mean and std)
        energy = librosa.feature.rms(y=audio, hop_length=hop_length)[0]
        if len(energy) > n_frames:
            energy = energy[:n_frames]
        elif len(energy) < n_frames:
            energy = np.pad(energy, (0, n_frames - len(energy)), mode='constant')

        mean_energy = np.mean(energy)
        shimmer = np.std(energy) if len(energy) > 0 else 0
        energy_features = np.array([energy, np.full(n_frames, mean_energy), np.full(n_frames, shimmer)])

        # Zero-Crossing Rate
        zcr = librosa.feature.zero_crossing_rate(y=audio, hop_length=hop_length)[0]
        if len(zcr) > n_frames:
            zcr = zcr[:n_frames]
        elif len(zcr) < n_frames:
            zcr = np.pad(zcr, (0, n_frames - len(zcr)), mode='constant')
        zcr_features = zcr[np.newaxis, :]

        # Chroma features
        chroma = librosa.feature.chroma_stft(y=audio, sr=sr, hop_length=hop_length, n_chroma=12)
        if chroma.shape[1] > n_frames:
            chroma = chroma[:, :n_frames]
        elif chroma.shape[1] < n_frames:
            chroma = np.pad(chroma, ((0, 0), (0, n_frames - chroma.shape[1])), mode='constant')

        # Spectral features
        spectral_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr, hop_length=hop_length)[0]
        spectral_rolloff = librosa.feature.spectral_rolloff(y=audio, sr=sr, hop_length=hop_length)[0]
        spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sr, hop_length=hop_length, n_bands=5)

        # Pad or truncate spectral features
        # Assuming all spectral features have the same number of frames
        if spectral_centroid.shape[0] > n_frames:
            spectral_centroid = spectral_centroid[:n_frames]
            spectral_rolloff = spectral_rolloff[:n_frames]
            spectral_contrast = spectral_contrast[:, :n_frames]
        elif spectral_centroid.shape[0] < n_frames:
            spectral_centroid = np.pad(spectral_centroid, (0, n_frames - spectral_centroid.shape[0]), mode='constant')
            spectral_rolloff = np.pad(spectral_rolloff, (0, n_frames - spectral_rolloff.shape[0]), mode='constant')
            spectral_contrast = np.pad(spectral_contrast, ((0, 0), (0, n_frames - spectral_contrast.shape[1])), mode='constant')
        spectral_features = np.vstack([spectral_centroid, spectral_rolloff, spectral_contrast])

        # Temporal features
        voiced_frames = librosa.effects.split(audio, top_db=20)
        speech_rate = len(voiced_frames) / (duration if duration > 0 else 1)
        pauses = len(voiced_frames) - 1 if len(voiced_frames) > 1 else 0
        temporal_features_single = np.array([speech_rate, pauses])
        temporal_features = np.tile(temporal_features_single, (n_frames, 1)).T

        features = np.concatenate([
            mfcc_features, # Now includes delta and delta-delta
            pitch_features,
            energy_features,
            zcr_features,
            chroma,
            spectral_features,
            temporal_features
        ], axis=0)

        return np.expand_dims(features, axis=-1)

    except Exception as e:
        print(f"Error processing {audio_path}: {e}")
        return None

# Build Orionnet-refine model
def build_orionnet(input_shape=(55, 157, 1)):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        #FreqTemporalCoAttention(ratio=4),
        layers.Dropout(0.25),

        layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        #FreqTemporalCoAttention(ratio=8),
        layers.Dropout(0.3),

        layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Flatten(),
        layers.Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
        layers.Dropout(0.4),
        layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    model.summary()
    return model

# Add a function to calculate GLOBAL_PITCH_PARAMS
def calculate_global_pitch_params(audio_files, sample_rate= 24200): #24200
    all_pitches = []
    for audio_path in audio_files:
        try:
            audio, sr = librosa.load(audio_path, sr=sample_rate)
            pitches, magnitudes = librosa.piptrack(y=audio, sr=sr)
            pitches = pitches[pitches > 0]
            if len(pitches) > 0:
                all_pitches.extend(pitches)
        except Exception as e:
            print(f"Error calculating global pitch for {audio_path}: {e}")
            continue

    if len(all_pitches) == 0:
        print("Warning: No valid pitches found to calculate global parameters. Using default zeros.")
        return 0.0, 0.0, 0.0

    all_pitches = np.array(all_pitches)
    global_mean_pitch = np.mean(all_pitches)

    normalized_all_pitches = all_pitches - global_mean_pitch
    global_jitter = np.std(normalized_all_pitches) if len(normalized_all_pitches) > 0 else 0

    global_pitch_slope = 0.0

    global_mean_pitch = 0.0 if np.isnan(global_mean_pitch) or np.isinf(global_mean_pitch) else global_mean_pitch
    global_jitter = 0.0 if np.isnan(global_jitter) or np.isinf(global_jitter) else global_jitter
    global_pitch_slope = 0.0 if np.isnan(global_pitch_slope) or np.isinf(global_pitch_slope) else global_pitch_slope

    return global_mean_pitch, global_jitter, global_pitch_slope


# Function to prepare data with label mapping from directory
def prepare_training_data(audio_files, emotion_map, global_pitch_params):
    X, y = [], []
    augment_types = ['normal', 'noise', 'pitch', 'stretch', 'shift']
    skipped_files = 0
    processed_files = 0

    print(f"Total number of audio files: {len(audio_files)}")
    for audio_path in audio_files:
        folder_name = os.path.basename(os.path.dirname(audio_path))
        if folder_name not in emotion_map:
            skipped_files += 1
            continue
        emotion_idx = emotion_map[folder_name]

        for aug_type in augment_types:
            features = extract_features(str(audio_path), augment_type=aug_type, global_pitch_params=global_pitch_params)
            if features is None or np.all(features == 0):
                continue
            X.append(features)
            y.append(emotion_idx)
            processed_files += 1

    print(f"Processed: {processed_files} samples, skipped: {skipped_files} files.")
    if not X or not y:
        raise ValueError("No audio files were successfully processed. Please check the data path or emotion_map.")

    X = np.array(X)
    y = to_categorical(y, num_classes=NUM_CLASSES)
    print(f"Dataset shape: X={X.shape}, y={y.shape}")
    return X, y

# Function to prepare test data
def prepare_test_data(audio_files, emotion_map, global_pitch_params):
    X, y = [], []
    skipped_files = 0
    processed_files = 0

    print(f"Total number of test audio files: {len(audio_files)}")
    for audio_path in audio_files:
        folder_name = os.path.basename(os.path.dirname(audio_path))
        if folder_name not in emotion_map:
            skipped_files += 1
            continue
        emotion_idx = emotion_map[folder_name]
        features = extract_features(str(audio_path), augment_type='normal', global_pitch_params=global_pitch_params)
        if features is None or np.all(features == 0):
            continue
        X.append(features)
        y.append(emotion_idx)
        processed_files += 1

    print(f"Processed: {processed_files} samples, skipped: {skipped_files} files.")
    if not X or not y:
        raise ValueError("No test audio files were successfully processed.")

    X = np.array(X)
    y = to_categorical(y, num_classes=NUM_CLASSES)
    print(f"Test dataset shape: X={X.shape}, y={y.shape}")
    return X, y

# Evaluate the model using confusion matrix and F1 Score
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)

    print("\nSample prediction probabilities:")
    for i in range(min(5, len(X_test))):
        print(f"Sample {i+1}: True={EMOTIONS[y_true_classes[i]]}, Pred={EMOTIONS[y_pred_classes[i]]}, Prob={y_pred[i]}")

    cm = confusion_matrix(y_true_classes, y_pred_classes)
    plt.figure(figsize=(10, 8))
    sns_heatmap = sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=EMOTIONS, yticklabels=EMOTIONS)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    print("\nClassification Report:")
    print(classification_report(y_true_classes, y_pred_classes, target_names=EMOTIONS))

    print("\nEvaluation metric formulas:")
    print("1. Precision = TP / (TP + FP)")
    print("   - TP (True Positives): Number of samples correctly predicted for a class.")
    print("   - FP (False Positives): Number of samples incorrectly predicted as that class.")
    print("2. Recall = TP / (TP + FN)")
    print("   - FN (False Negatives): Number of samples that belong to the class but were incorrectly predicted.")
    print("3. F1 Score = 2 * (Precision * Recall) / (Precision + Recall)")

# Train and evaluate
def train_and_evaluate_model(model, X, y, epochs=200, batch_size=16, checkpoint_path='best_model.h5', class_weight=None, k_folds=5):
    if len(X) == 0 or len(y) == 0:
        raise ValueError("Training dataset is empty. Please check the input data.")

    kf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)
    fold_no = 1
    val_losses = []
    val_accuracies = []
    best_model = None
    best_history = None
    best_val_loss = float('inf')
    X_val_last, y_val_last = None, None
    scaler = StandardScaler()
    y_indices = np.argmax(y, axis=1)
    for train_index, val_index in kf.split(X, y_indices):
        print(f"\nTraining on fold {fold_no}/{k_folds}...")

        X_train, X_val = X[train_index], X[val_index]
        y_train, y_val = y[train_index], y[val_index]
        print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}")

        original_shape_train = X_train.shape
        X_train_2d = X_train.reshape(original_shape_train[0], -1)
        
        original_shape_val = X_val.shape
        X_val_2d = X_val.reshape(original_shape_val[0], -1)
        
        X_train_2d = scaler.fit_transform(X_train_2d)
        X_val_2d = scaler.transform(X_val_2d)
        
        X_train = X_train_2d.reshape(original_shape_train)
        X_val = X_val_2d.reshape(original_shape_val)

        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                      loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                      metrics=['accuracy'])

        early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=0.00001)
        checkpoint = ModelCheckpoint(f"{checkpoint_path}_fold_{fold_no}.h5", monitor='val_loss', save_best_only=True, mode='min', verbose=1)

        history = model.fit(X_train, y_train,
                            validation_data=(X_val, y_val),
                            epochs=epochs,
                            batch_size=batch_size,
                            callbacks=[early_stopping, reduce_lr, checkpoint],
                            class_weight=class_weight,
                            verbose=1)

        val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
        print(f"\nFold {fold_no} - Evaluation on validation set:")
        print(f" - Loss: {val_loss:.4f}")
        print(f" - Accuracy: {val_accuracy:.4f}")
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = model
            best_history = history
            X_val_last, y_val_last = X_val, y_val

        fold_no += 1

    print(f"\nAverage results across {k_folds} folds:")
    print(f" - Average Loss: {np.mean(val_losses):.4f}")
    print(f" - Average Accuracy: {np.mean(val_accuracies):.4f}")

    return best_model, best_history, X_val_last, y_val_last

# Direct prediction using CNN
def predict_emotion(audio_path, model, scaler, global_pitch_params):
    features = extract_features(audio_path, augment_type='normal', global_pitch_params=global_pitch_params)
    if features is None or np.all(features == 0):
        return "Prediction failed: Feature extraction error."

    features_2d = features.reshape(1, -1)
    features_2d = scaler.transform(features_2d)
    features = features_2d.reshape(features.shape)

    features = np.expand_dims(features, axis=0)
    prediction = model.predict(features, verbose=0)
    predicted_emotion_idx = np.argmax(prediction, axis=1)[0]

    print(f"Prediction probabilities for {audio_path}: {prediction[0]}")
    return EMOTIONS[predicted_emotion_idx]

# Plot Loss Chart
def plot_loss_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
	
if __name__ == "__main__":
    # Path to the data
    root_folder = DATA_PATH
    folders = [f for f in glob(os.path.join(root_folder, "*")) if os.path.isdir(f)]
    all_files = []
    for folder in folders:
        files = glob(os.path.join(folder, "**", "*.wav"), recursive=True)
        all_files.extend(files)
        print(f"Found {len(files)} files in folder: {os.path.basename(folder)}")

    if not all_files:
        raise ValueError("No audio files found in the training directory.")

    # Calculate GLOBAL_PITCH_PARAMS first
    print("Calculating GLOBAL_PITCH_PARAMS from training data...")
    GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE = calculate_global_pitch_params(all_files)
    print(f"GLOBAL_MEAN_PITCH: {GLOBAL_MEAN_PITCH:.4f}, GLOBAL_JITTER: {GLOBAL_JITTER:.4f}, GLOBAL_PITCH_SLOPE: {GLOBAL_PITCH_SLOPE:.4f}")

    # Ensure y_raw_train has valid labels before computing class weights
    y_raw = []
    for f in all_files:
        folder_name = os.path.basename(os.path.dirname(f))
        if folder_name in emotion_map:
            y_raw.append(emotion_map[folder_name])
    
    y_raw_train = np.array(y_raw)

    if len(y_raw_train) == 0:
        raise ValueError("No valid emotion labels found for class weight calculation. Check your data and emotion_map.")

    print("Original label distribution:", Counter([EMOTIONS[i] for i in y_raw_train]))

    # Compute class weights
    # Ensure classes are passed correctly as np.unique(y_raw_train)
    class_weights = compute_class_weight('balanced', classes=np.unique(y_raw_train), y=y_raw_train)
    class_weight_dict = dict(enumerate(class_weights))
    print("Class weights:", class_weight_dict)

    # Prepare data
    X, y = prepare_training_data(all_files, emotion_map, (GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE))
    print(f"X shape: {X.shape}")

    # Normalize features
    scaler = StandardScaler()
    original_shape = X.shape
    X_2d = X.reshape(original_shape[0], -1)
    X_2d = scaler.fit_transform(X_2d)
    X = X_2d.reshape(original_shape)

    calculated_input_dim0 = X.shape[1]
    cnn_input_shape = (calculated_input_dim0, X.shape[2], 1)
    print(f"Calculated CNN Input Shape: {cnn_input_shape}")
    
    # Build and train the model
    cnn_model = build_orionnet(input_shape=cnn_input_shape)
    cnn_model, history, X_test, y_test = train_and_evaluate_model(
        cnn_model, X, y,
        epochs=100,
        batch_size=16,
        checkpoint_path='best_cnn_2d_vesc.keras',
        class_weight=class_weight_dict,
        k_folds=5
    )
    joblib.dump(scaler, 'final_cnn_2d_vesc.pkl')
    # Save the final model
    cnn_model.save('final_cnn_2d_vesc.keras')
    evaluate_model(cnn_model, X_test, y_test)
    plot_loss_history(history)
# Out:
# Found 144 files in folder: Angry
# Found 164 files in folder: Neutral
# Found 109 files in folder: Anxiety
# Found 141 files in folder: Sad
# Found 114 files in folder: Happy
# Calculating GLOBAL_PITCH_PARAMS from training data...
# GLOBAL_MEAN_PITCH: 1314.3724, GLOBAL_JITTER: 1039.1417, GLOBAL_PITCH_SLOPE: 0.0000
# Original label distribution: Counter({'Neutral': 164, 'Angry': 144, 'Sad': 141, 'Happy': 114, 'Anxiety': 109})
# Class weights: {0: 0.9333333333333333, 1: 1.1789473684210525, 2: 1.2330275229357799, 3: 0.8195121951219512, 4: 0.9531914893617022}
# Total number of audio files: 672
# Processed: 3360 samples, skipped: 0 files.
# Dataset shape: X=(3360, 107, 157, 1), y=(3360, 5)
# X shape: (3360, 107, 157, 1)
# Calculated CNN Input Shape: (107, 157, 1)
# I0000 00:00:1761140233.082050      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 107, 157, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 107, 157, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 107, 157, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 107, 157, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 53, 78, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 53, 78, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 53, 78, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 53, 78, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 26, 39, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 26, 39, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 26, 39, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 26, 39, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 19, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 13, 19, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 31616)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     8,093,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,198,181 (31.27 MB)
#  Trainable params: 8,197,669 (31.27 MB)
#  Non-trainable params: 512 (2.00 KB)
# Training on fold 1/5...
# Train shape: (2688, 107, 157, 1), Val shape: (672, 107, 157, 1)
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761140241.391171      89 service.cc:148] XLA service 0x7a3740006270 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761140241.391629      89 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1761140241.914526      89 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  13/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.1651 - loss: 5.8133
# I0000 00:00:1761140247.807610      89 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3192 - loss: 3.7103
# Epoch 1: val_loss improved from inf to 4.86158, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.3199 - loss: 3.6989 - val_accuracy: 0.1920 - val_loss: 4.8616 - learning_rate: 1.0000e-04
# Epoch 2/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4544 - loss: 2.0525
# Epoch 2: val_loss improved from 4.86158 to 3.02299, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.4545 - loss: 2.0525 - val_accuracy: 0.3170 - val_loss: 3.0230 - learning_rate: 1.0000e-04
# Epoch 3/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5019 - loss: 1.9822
# Epoch 3: val_loss improved from 3.02299 to 2.27754, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.5020 - loss: 1.9821 - val_accuracy: 0.4807 - val_loss: 2.2775 - learning_rate: 1.0000e-04
# Epoch 4/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5263 - loss: 1.9166
# Epoch 4: val_loss improved from 2.27754 to 2.01493, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5264 - loss: 1.9166 - val_accuracy: 0.5625 - val_loss: 2.0149 - learning_rate: 1.0000e-04
# Epoch 5/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5734 - loss: 1.8761
# Epoch 5: val_loss improved from 2.01493 to 1.95159, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.5734 - loss: 1.8759 - val_accuracy: 0.6235 - val_loss: 1.9516 - learning_rate: 1.0000e-04
# Epoch 6/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6231 - loss: 1.7860
# Epoch 6: val_loss improved from 1.95159 to 1.90808, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6233 - loss: 1.7856 - val_accuracy: 0.6280 - val_loss: 1.9081 - learning_rate: 1.0000e-04
# Epoch 7/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6562 - loss: 1.6960
# Epoch 7: val_loss improved from 1.90808 to 1.87637, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6562 - loss: 1.6961 - val_accuracy: 0.6399 - val_loss: 1.8764 - learning_rate: 1.0000e-04
# Epoch 8/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6889 - loss: 1.6527
# Epoch 8: val_loss improved from 1.87637 to 1.77484, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6887 - loss: 1.6527 - val_accuracy: 0.6801 - val_loss: 1.7748 - learning_rate: 1.0000e-04
# Epoch 9/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7291 - loss: 1.5872
# Epoch 9: val_loss improved from 1.77484 to 1.66027, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7290 - loss: 1.5872 - val_accuracy: 0.7054 - val_loss: 1.6603 - learning_rate: 1.0000e-04
# Epoch 10/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7304 - loss: 1.5541
# Epoch 10: val_loss improved from 1.66027 to 1.61962, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7304 - loss: 1.5540 - val_accuracy: 0.7158 - val_loss: 1.6196 - learning_rate: 1.0000e-04
# Epoch 11/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7476 - loss: 1.5140
# Epoch 11: val_loss improved from 1.61962 to 1.56533, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7477 - loss: 1.5138 - val_accuracy: 0.7232 - val_loss: 1.5653 - learning_rate: 1.0000e-04
# Epoch 12/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7798 - loss: 1.4509
# Epoch 12: val_loss improved from 1.56533 to 1.47587, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7802 - loss: 1.4503 - val_accuracy: 0.7634 - val_loss: 1.4759 - learning_rate: 1.0000e-04
# Epoch 13/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7875 - loss: 1.4040
# Epoch 13: val_loss improved from 1.47587 to 1.40457, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7875 - loss: 1.4040 - val_accuracy: 0.7887 - val_loss: 1.4046 - learning_rate: 1.0000e-04
# Epoch 14/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8217 - loss: 1.3579
# Epoch 14: val_loss improved from 1.40457 to 1.33373, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8216 - loss: 1.3579 - val_accuracy: 0.8095 - val_loss: 1.3337 - learning_rate: 1.0000e-04
# Epoch 15/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8413 - loss: 1.3135
# Epoch 15: val_loss improved from 1.33373 to 1.29368, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8413 - loss: 1.3135 - val_accuracy: 0.8199 - val_loss: 1.2937 - learning_rate: 1.0000e-04
# Epoch 16/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8607 - loss: 1.2765
# Epoch 16: val_loss improved from 1.29368 to 1.21887, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8607 - loss: 1.2765 - val_accuracy: 0.8601 - val_loss: 1.2189 - learning_rate: 1.0000e-04
# Epoch 17/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8490 - loss: 1.2688
# Epoch 17: val_loss improved from 1.21887 to 1.18188, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8491 - loss: 1.2686 - val_accuracy: 0.8780 - val_loss: 1.1819 - learning_rate: 1.0000e-04
# Epoch 18/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8843 - loss: 1.2094
# Epoch 18: val_loss improved from 1.18188 to 1.14476, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8843 - loss: 1.2094 - val_accuracy: 0.8750 - val_loss: 1.1448 - learning_rate: 1.0000e-04
# Epoch 19/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8825 - loss: 1.1829
# Epoch 19: val_loss improved from 1.14476 to 1.08932, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8826 - loss: 1.1829 - val_accuracy: 0.9152 - val_loss: 1.0893 - learning_rate: 1.0000e-04
# Epoch 20/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8880 - loss: 1.1535
# Epoch 20: val_loss improved from 1.08932 to 1.07497, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8880 - loss: 1.1536 - val_accuracy: 0.9092 - val_loss: 1.0750 - learning_rate: 1.0000e-04
# Epoch 21/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9142 - loss: 1.1142
# Epoch 21: val_loss improved from 1.07497 to 1.02660, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9141 - loss: 1.1142 - val_accuracy: 0.9360 - val_loss: 1.0266 - learning_rate: 1.0000e-04
# Epoch 22/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9087 - loss: 1.0942
# Epoch 22: val_loss improved from 1.02660 to 1.01551, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9085 - loss: 1.0942 - val_accuracy: 0.9315 - val_loss: 1.0155 - learning_rate: 1.0000e-04
# Epoch 23/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9094 - loss: 1.0725
# Epoch 23: val_loss did not improve from 1.01551
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9095 - loss: 1.0725 - val_accuracy: 0.9122 - val_loss: 1.0242 - learning_rate: 1.0000e-04
# Epoch 24/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9154 - loss: 1.0570
# Epoch 24: val_loss improved from 1.01551 to 0.96143, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9154 - loss: 1.0570 - val_accuracy: 0.9435 - val_loss: 0.9614 - learning_rate: 1.0000e-04
# Epoch 25/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9163 - loss: 1.0277
# Epoch 25: val_loss improved from 0.96143 to 0.94597, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9163 - loss: 1.0277 - val_accuracy: 0.9435 - val_loss: 0.9460 - learning_rate: 1.0000e-04
# Epoch 26/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9426 - loss: 0.9895
# Epoch 26: val_loss improved from 0.94597 to 0.92015, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9425 - loss: 0.9898 - val_accuracy: 0.9464 - val_loss: 0.9202 - learning_rate: 1.0000e-04
# Epoch 27/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9295 - loss: 0.9850
# Epoch 27: val_loss improved from 0.92015 to 0.88753, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9295 - loss: 0.9849 - val_accuracy: 0.9583 - val_loss: 0.8875 - learning_rate: 1.0000e-04
# Epoch 28/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9390 - loss: 0.9628
# Epoch 28: val_loss improved from 0.88753 to 0.87721, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9389 - loss: 0.9627 - val_accuracy: 0.9598 - val_loss: 0.8772 - learning_rate: 1.0000e-04
# Epoch 29/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9437 - loss: 0.9399
# Epoch 29: val_loss improved from 0.87721 to 0.85249, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9437 - loss: 0.9399 - val_accuracy: 0.9688 - val_loss: 0.8525 - learning_rate: 1.0000e-04
# Epoch 30/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9389 - loss: 0.9416
# Epoch 30: val_loss improved from 0.85249 to 0.83736, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9389 - loss: 0.9416 - val_accuracy: 0.9732 - val_loss: 0.8374 - learning_rate: 1.0000e-04
# Epoch 31/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9478 - loss: 0.9129
# Epoch 31: val_loss improved from 0.83736 to 0.83105, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9478 - loss: 0.9131 - val_accuracy: 0.9658 - val_loss: 0.8310 - learning_rate: 1.0000e-04
# Epoch 32/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9407 - loss: 0.9137
# Epoch 32: val_loss improved from 0.83105 to 0.80364, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9407 - loss: 0.9137 - val_accuracy: 0.9732 - val_loss: 0.8036 - learning_rate: 1.0000e-04
# Epoch 33/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9505 - loss: 0.8910
# Epoch 33: val_loss improved from 0.80364 to 0.79106, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9506 - loss: 0.8909 - val_accuracy: 0.9777 - val_loss: 0.7911 - learning_rate: 1.0000e-04
# Epoch 34/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9542 - loss: 0.8704
# Epoch 34: val_loss improved from 0.79106 to 0.78158, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9541 - loss: 0.8705 - val_accuracy: 0.9821 - val_loss: 0.7816 - learning_rate: 1.0000e-04
# Epoch 35/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9587 - loss: 0.8643
# Epoch 35: val_loss improved from 0.78158 to 0.77979, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9586 - loss: 0.8642 - val_accuracy: 0.9777 - val_loss: 0.7798 - learning_rate: 1.0000e-04
# Epoch 36/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9662 - loss: 0.8525
# Epoch 36: val_loss improved from 0.77979 to 0.76816, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9661 - loss: 0.8524 - val_accuracy: 0.9807 - val_loss: 0.7682 - learning_rate: 1.0000e-04
# Epoch 37/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9654 - loss: 0.8353
# Epoch 37: val_loss improved from 0.76816 to 0.75902, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9654 - loss: 0.8353 - val_accuracy: 0.9807 - val_loss: 0.7590 - learning_rate: 1.0000e-04
# Epoch 38/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9607 - loss: 0.8307
# Epoch 38: val_loss improved from 0.75902 to 0.75449, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9607 - loss: 0.8307 - val_accuracy: 0.9777 - val_loss: 0.7545 - learning_rate: 1.0000e-04
# Epoch 39/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9693 - loss: 0.8202
# Epoch 39: val_loss improved from 0.75449 to 0.73723, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9693 - loss: 0.8201 - val_accuracy: 0.9821 - val_loss: 0.7372 - learning_rate: 1.0000e-04
# Epoch 40/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9628 - loss: 0.8147
# Epoch 40: val_loss improved from 0.73723 to 0.72489, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9628 - loss: 0.8146 - val_accuracy: 0.9836 - val_loss: 0.7249 - learning_rate: 1.0000e-04
# Epoch 41/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9660 - loss: 0.8083
# Epoch 41: val_loss improved from 0.72489 to 0.72198, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9660 - loss: 0.8083 - val_accuracy: 0.9851 - val_loss: 0.7220 - learning_rate: 1.0000e-04
# Epoch 42/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9622 - loss: 0.8040
# Epoch 42: val_loss improved from 0.72198 to 0.71809, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9622 - loss: 0.8039 - val_accuracy: 0.9807 - val_loss: 0.7181 - learning_rate: 1.0000e-04
# Epoch 43/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9684 - loss: 0.7746
# Epoch 43: val_loss improved from 0.71809 to 0.70567, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9684 - loss: 0.7746 - val_accuracy: 0.9866 - val_loss: 0.7057 - learning_rate: 1.0000e-04
# Epoch 44/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9682 - loss: 0.7775
# Epoch 44: val_loss improved from 0.70567 to 0.70222, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9682 - loss: 0.7775 - val_accuracy: 0.9836 - val_loss: 0.7022 - learning_rate: 1.0000e-04
# Epoch 45/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9716 - loss: 0.7698
# Epoch 45: val_loss did not improve from 0.70222
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9716 - loss: 0.7698 - val_accuracy: 0.9821 - val_loss: 0.7056 - learning_rate: 1.0000e-04
# Epoch 46/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9676 - loss: 0.7706
# Epoch 46: val_loss improved from 0.70222 to 0.69685, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9676 - loss: 0.7706 - val_accuracy: 0.9851 - val_loss: 0.6969 - learning_rate: 1.0000e-04
# Epoch 47/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9681 - loss: 0.7711
# Epoch 47: val_loss improved from 0.69685 to 0.68948, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9682 - loss: 0.7710 - val_accuracy: 0.9866 - val_loss: 0.6895 - learning_rate: 1.0000e-04
# Epoch 48/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9747 - loss: 0.7551
# Epoch 48: val_loss improved from 0.68948 to 0.68843, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9747 - loss: 0.7552 - val_accuracy: 0.9866 - val_loss: 0.6884 - learning_rate: 1.0000e-04
# Epoch 49/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9822 - loss: 0.7454
# Epoch 49: val_loss improved from 0.68843 to 0.67541, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9821 - loss: 0.7455 - val_accuracy: 0.9881 - val_loss: 0.6754 - learning_rate: 1.0000e-04
# Epoch 50/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9739 - loss: 0.7549
# Epoch 50: val_loss did not improve from 0.67541
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9738 - loss: 0.7549 - val_accuracy: 0.9911 - val_loss: 0.6782 - learning_rate: 1.0000e-04
# Epoch 51/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9735 - loss: 0.7435
# Epoch 51: val_loss improved from 0.67541 to 0.66975, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9735 - loss: 0.7434 - val_accuracy: 0.9896 - val_loss: 0.6698 - learning_rate: 1.0000e-04
# Epoch 52/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9709 - loss: 0.7407
# Epoch 52: val_loss did not improve from 0.66975
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9709 - loss: 0.7407 - val_accuracy: 0.9881 - val_loss: 0.6796 - learning_rate: 1.0000e-04
# Epoch 53/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9739 - loss: 0.7392
# Epoch 53: val_loss improved from 0.66975 to 0.66006, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9739 - loss: 0.7391 - val_accuracy: 0.9881 - val_loss: 0.6601 - learning_rate: 1.0000e-04
# Epoch 54/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9824 - loss: 0.7225
# Epoch 54: val_loss did not improve from 0.66006
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9824 - loss: 0.7225 - val_accuracy: 0.9896 - val_loss: 0.6605 - learning_rate: 1.0000e-04
# Epoch 55/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9816 - loss: 0.7233
# Epoch 55: val_loss improved from 0.66006 to 0.65963, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9816 - loss: 0.7233 - val_accuracy: 0.9866 - val_loss: 0.6596 - learning_rate: 1.0000e-04
# Epoch 56/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9779 - loss: 0.7306
# Epoch 56: val_loss did not improve from 0.65963
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9779 - loss: 0.7306 - val_accuracy: 0.9866 - val_loss: 0.6672 - learning_rate: 1.0000e-04
# Epoch 57/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9881 - loss: 0.7080
# Epoch 57: val_loss improved from 0.65963 to 0.65458, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9880 - loss: 0.7081 - val_accuracy: 0.9866 - val_loss: 0.6546 - learning_rate: 1.0000e-04
# Epoch 58/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9818 - loss: 0.7193
# Epoch 58: val_loss improved from 0.65458 to 0.63861, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9818 - loss: 0.7192 - val_accuracy: 0.9881 - val_loss: 0.6386 - learning_rate: 1.0000e-04
# Epoch 59/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9809 - loss: 0.7134
# Epoch 59: val_loss improved from 0.63861 to 0.63851, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9809 - loss: 0.7134 - val_accuracy: 0.9881 - val_loss: 0.6385 - learning_rate: 1.0000e-04
# Epoch 60/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9820 - loss: 0.7164
# Epoch 60: val_loss did not improve from 0.63851
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9820 - loss: 0.7164 - val_accuracy: 0.9896 - val_loss: 0.6478 - learning_rate: 1.0000e-04
# Epoch 61/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - loss: 0.7009
# Epoch 61: val_loss did not improve from 0.63851
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9857 - loss: 0.7009 - val_accuracy: 0.9866 - val_loss: 0.6515 - learning_rate: 1.0000e-04
# Epoch 62/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9880 - loss: 0.6974
# Epoch 62: val_loss did not improve from 0.63851
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9879 - loss: 0.6974 - val_accuracy: 0.9881 - val_loss: 0.6445 - learning_rate: 1.0000e-04
# Epoch 63/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9874 - loss: 0.6967
# Epoch 63: val_loss improved from 0.63851 to 0.63382, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9874 - loss: 0.6966 - val_accuracy: 0.9911 - val_loss: 0.6338 - learning_rate: 1.0000e-04
# Epoch 64/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9871 - loss: 0.6916
# Epoch 64: val_loss did not improve from 0.63382
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9870 - loss: 0.6917 - val_accuracy: 0.9881 - val_loss: 0.6360 - learning_rate: 1.0000e-04
# Epoch 65/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9846 - loss: 0.6929
# Epoch 65: val_loss improved from 0.63382 to 0.63265, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9846 - loss: 0.6929 - val_accuracy: 0.9911 - val_loss: 0.6326 - learning_rate: 1.0000e-04
# Epoch 66/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9876 - loss: 0.6869
# Epoch 66: val_loss did not improve from 0.63265
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9876 - loss: 0.6868 - val_accuracy: 0.9881 - val_loss: 0.6354 - learning_rate: 1.0000e-04
# Epoch 67/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9851 - loss: 0.6873
# Epoch 67: val_loss improved from 0.63265 to 0.62842, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9851 - loss: 0.6873 - val_accuracy: 0.9881 - val_loss: 0.6284 - learning_rate: 1.0000e-04
# Epoch 68/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9878 - loss: 0.6809
# Epoch 68: val_loss improved from 0.62842 to 0.62205, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9878 - loss: 0.6809 - val_accuracy: 0.9866 - val_loss: 0.6221 - learning_rate: 1.0000e-04
# Epoch 69/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9839 - loss: 0.6798
# Epoch 69: val_loss did not improve from 0.62205
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9840 - loss: 0.6797 - val_accuracy: 0.9881 - val_loss: 0.6288 - learning_rate: 1.0000e-04
# Epoch 70/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9867 - loss: 0.6800
# Epoch 70: val_loss improved from 0.62205 to 0.61952, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9867 - loss: 0.6800 - val_accuracy: 0.9866 - val_loss: 0.6195 - learning_rate: 1.0000e-04
# Epoch 71/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9835 - loss: 0.6785
# Epoch 71: val_loss did not improve from 0.61952
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9835 - loss: 0.6785 - val_accuracy: 0.9881 - val_loss: 0.6208 - learning_rate: 1.0000e-04
# Epoch 72/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9861 - loss: 0.6635
# Epoch 72: val_loss improved from 0.61952 to 0.61202, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9861 - loss: 0.6636 - val_accuracy: 0.9896 - val_loss: 0.6120 - learning_rate: 1.0000e-04
# Epoch 73/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9898 - loss: 0.6629
# Epoch 73: val_loss improved from 0.61202 to 0.61137, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9898 - loss: 0.6629 - val_accuracy: 0.9866 - val_loss: 0.6114 - learning_rate: 1.0000e-04
# Epoch 74/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9893 - loss: 0.6613
# Epoch 74: val_loss improved from 0.61137 to 0.60507, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9893 - loss: 0.6612 - val_accuracy: 0.9896 - val_loss: 0.6051 - learning_rate: 1.0000e-04
# Epoch 75/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.6639
# Epoch 75: val_loss improved from 0.60507 to 0.60262, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9892 - loss: 0.6639 - val_accuracy: 0.9911 - val_loss: 0.6026 - learning_rate: 1.0000e-04
# Epoch 76/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9898 - loss: 0.6561
# Epoch 76: val_loss improved from 0.60262 to 0.60232, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9898 - loss: 0.6561 - val_accuracy: 0.9881 - val_loss: 0.6023 - learning_rate: 1.0000e-04
# Epoch 77/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9916 - loss: 0.6512
# Epoch 77: val_loss improved from 0.60232 to 0.60063, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9916 - loss: 0.6513 - val_accuracy: 0.9896 - val_loss: 0.6006 - learning_rate: 1.0000e-04
# Epoch 78/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9934 - loss: 0.6501
# Epoch 78: val_loss improved from 0.60063 to 0.59757, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9934 - loss: 0.6502 - val_accuracy: 0.9851 - val_loss: 0.5976 - learning_rate: 1.0000e-04
# Epoch 79/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9824 - loss: 0.6584
# Epoch 79: val_loss improved from 0.59757 to 0.59373, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9826 - loss: 0.6582 - val_accuracy: 0.9851 - val_loss: 0.5937 - learning_rate: 1.0000e-04
# Epoch 80/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9895 - loss: 0.6436
# Epoch 80: val_loss improved from 0.59373 to 0.59350, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9895 - loss: 0.6437 - val_accuracy: 0.9911 - val_loss: 0.5935 - learning_rate: 1.0000e-04
# Epoch 81/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9915 - loss: 0.6420
# Epoch 81: val_loss did not improve from 0.59350
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9914 - loss: 0.6421 - val_accuracy: 0.9911 - val_loss: 0.5948 - learning_rate: 1.0000e-04
# Epoch 82/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9918 - loss: 0.6396
# Epoch 82: val_loss improved from 0.59350 to 0.58880, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9918 - loss: 0.6396 - val_accuracy: 0.9940 - val_loss: 0.5888 - learning_rate: 1.0000e-04
# Epoch 83/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9942 - loss: 0.6348
# Epoch 83: val_loss improved from 0.58880 to 0.58859, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9942 - loss: 0.6348 - val_accuracy: 0.9911 - val_loss: 0.5886 - learning_rate: 1.0000e-04
# Epoch 84/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9921 - loss: 0.6348
# Epoch 84: val_loss improved from 0.58859 to 0.58150, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9921 - loss: 0.6348 - val_accuracy: 0.9940 - val_loss: 0.5815 - learning_rate: 1.0000e-04
# Epoch 85/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9890 - loss: 0.6366
# Epoch 85: val_loss did not improve from 0.58150
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9890 - loss: 0.6366 - val_accuracy: 0.9911 - val_loss: 0.5916 - learning_rate: 1.0000e-04
# Epoch 86/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.6314
# Epoch 86: val_loss did not improve from 0.58150
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9928 - loss: 0.6314 - val_accuracy: 0.9955 - val_loss: 0.5825 - learning_rate: 1.0000e-04
# Epoch 87/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9943 - loss: 0.6246
# Epoch 87: val_loss improved from 0.58150 to 0.57779, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9943 - loss: 0.6246 - val_accuracy: 0.9940 - val_loss: 0.5778 - learning_rate: 1.0000e-04
# Epoch 88/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9965 - loss: 0.6226
# Epoch 88: val_loss improved from 0.57779 to 0.57035, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9965 - loss: 0.6225 - val_accuracy: 0.9940 - val_loss: 0.5703 - learning_rate: 1.0000e-04
# Epoch 89/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9966 - loss: 0.6203
# Epoch 89: val_loss did not improve from 0.57035
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9965 - loss: 0.6203 - val_accuracy: 0.9955 - val_loss: 0.5725 - learning_rate: 1.0000e-04
# Epoch 90/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9964 - loss: 0.6159
# Epoch 90: val_loss did not improve from 0.57035
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9964 - loss: 0.6160 - val_accuracy: 0.9896 - val_loss: 0.5786 - learning_rate: 1.0000e-04
# Epoch 91/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9978 - loss: 0.6091
# Epoch 91: val_loss did not improve from 0.57035
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9978 - loss: 0.6091 - val_accuracy: 0.9911 - val_loss: 0.5753 - learning_rate: 1.0000e-04
# Epoch 92/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9918 - loss: 0.6250
# Epoch 92: val_loss did not improve from 0.57035
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9918 - loss: 0.6248 - val_accuracy: 0.9866 - val_loss: 0.5851 - learning_rate: 1.0000e-04
# Epoch 93/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9949 - loss: 0.6099
# Epoch 93: val_loss did not improve from 0.57035
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9949 - loss: 0.6099 - val_accuracy: 0.9911 - val_loss: 0.5783 - learning_rate: 1.0000e-04
# Epoch 94/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9962 - loss: 0.6062
# Epoch 94: val_loss did not improve from 0.57035
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9961 - loss: 0.6062 - val_accuracy: 0.9926 - val_loss: 0.5712 - learning_rate: 1.0000e-04
# Epoch 95/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9947 - loss: 0.6105
# Epoch 95: val_loss improved from 0.57035 to 0.56546, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9947 - loss: 0.6105 - val_accuracy: 0.9911 - val_loss: 0.5655 - learning_rate: 1.0000e-04
# Epoch 96/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9965 - loss: 0.6044
# Epoch 96: val_loss did not improve from 0.56546
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9965 - loss: 0.6044 - val_accuracy: 0.9940 - val_loss: 0.5658 - learning_rate: 1.0000e-04
# Epoch 97/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9984 - loss: 0.5970
# Epoch 97: val_loss improved from 0.56546 to 0.56442, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9984 - loss: 0.5970 - val_accuracy: 0.9911 - val_loss: 0.5644 - learning_rate: 1.0000e-04
# Epoch 98/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9951 - loss: 0.5962
# Epoch 98: val_loss improved from 0.56442 to 0.55972, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9950 - loss: 0.5962 - val_accuracy: 0.9911 - val_loss: 0.5597 - learning_rate: 1.0000e-04
# Epoch 99/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.5944
# Epoch 99: val_loss improved from 0.55972 to 0.55818, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9955 - loss: 0.5945 - val_accuracy: 0.9911 - val_loss: 0.5582 - learning_rate: 1.0000e-04
# Epoch 100/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.5926
# Epoch 100: val_loss improved from 0.55818 to 0.55792, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9955 - loss: 0.5926 - val_accuracy: 0.9940 - val_loss: 0.5579 - learning_rate: 1.0000e-04
#
# Fold 1 - Evaluation on validation set:
#  - Loss: 0.5579
#  - Accuracy: 0.9940
#
# Training on fold 2/5...
# Train shape: (2688, 107, 157, 1), Val shape: (672, 107, 157, 1)
# Epoch 1/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9827 - loss: 0.6196
# Epoch 1: val_loss improved from inf to 0.52090, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.9827 - loss: 0.6195 - val_accuracy: 1.0000 - val_loss: 0.5209 - learning_rate: 1.0000e-04
# Epoch 2/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9932 - loss: 0.5924
# Epoch 2: val_loss did not improve from 0.52090
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9932 - loss: 0.5924 - val_accuracy: 1.0000 - val_loss: 0.5221 - learning_rate: 1.0000e-04
# Epoch 3/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9913 - loss: 0.5934
# Epoch 3: val_loss improved from 0.52090 to 0.52045, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9913 - loss: 0.5935 - val_accuracy: 1.0000 - val_loss: 0.5204 - learning_rate: 1.0000e-04
# Epoch 4/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9966 - loss: 0.5909
# Epoch 4: val_loss did not improve from 0.52045
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9966 - loss: 0.5909 - val_accuracy: 0.9985 - val_loss: 0.5280 - learning_rate: 1.0000e-04
# Epoch 5/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9962 - loss: 0.5866
# Epoch 5: val_loss improved from 0.52045 to 0.51899, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9962 - loss: 0.5866 - val_accuracy: 0.9985 - val_loss: 0.5190 - learning_rate: 1.0000e-04
# Epoch 6/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9934 - loss: 0.5932
# Epoch 6: val_loss did not improve from 0.51899
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9935 - loss: 0.5932 - val_accuracy: 1.0000 - val_loss: 0.5191 - learning_rate: 1.0000e-04
# Epoch 7/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9950 - loss: 0.5867
# Epoch 7: val_loss did not improve from 0.51899
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9950 - loss: 0.5867 - val_accuracy: 0.9985 - val_loss: 0.5247 - learning_rate: 1.0000e-04
# Epoch 8/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9979 - loss: 0.5815
# Epoch 8: val_loss did not improve from 0.51899
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9979 - loss: 0.5815 - val_accuracy: 0.9985 - val_loss: 0.5252 - learning_rate: 1.0000e-04
# Epoch 9/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9965 - loss: 0.5876
# Epoch 9: val_loss did not improve from 0.51899
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9965 - loss: 0.5875 - val_accuracy: 0.9985 - val_loss: 0.5213 - learning_rate: 1.0000e-04
# Epoch 10/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9954 - loss: 0.5808
# Epoch 10: val_loss did not improve from 0.51899
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9954 - loss: 0.5807 - val_accuracy: 0.9985 - val_loss: 0.5211 - learning_rate: 1.0000e-04
# Epoch 11/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9985 - loss: 0.5772
# Epoch 11: val_loss improved from 0.51899 to 0.51747, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9985 - loss: 0.5772 - val_accuracy: 0.9985 - val_loss: 0.5175 - learning_rate: 1.0000e-04
# Epoch 12/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9989 - loss: 0.5677
# Epoch 12: val_loss did not improve from 0.51747
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9989 - loss: 0.5677 - val_accuracy: 0.9985 - val_loss: 0.5213 - learning_rate: 1.0000e-04
# Epoch 13/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9991 - loss: 0.5763
# Epoch 13: val_loss improved from 0.51747 to 0.51531, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9991 - loss: 0.5763 - val_accuracy: 0.9985 - val_loss: 0.5153 - learning_rate: 1.0000e-04
# Epoch 14/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9960 - loss: 0.5796
# Epoch 14: val_loss did not improve from 0.51531
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9960 - loss: 0.5795 - val_accuracy: 0.9985 - val_loss: 0.5186 - learning_rate: 1.0000e-04
# Epoch 15/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9995 - loss: 0.5643
# Epoch 15: val_loss did not improve from 0.51531
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9995 - loss: 0.5644 - val_accuracy: 0.9985 - val_loss: 0.5174 - learning_rate: 1.0000e-04
# Epoch 16/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9978 - loss: 0.5712
# Epoch 16: val_loss improved from 0.51531 to 0.50892, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9978 - loss: 0.5712 - val_accuracy: 0.9985 - val_loss: 0.5089 - learning_rate: 1.0000e-04
# Epoch 17/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9990 - loss: 0.5665
# Epoch 17: val_loss did not improve from 0.50892
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9989 - loss: 0.5665 - val_accuracy: 0.9985 - val_loss: 0.5107 - learning_rate: 1.0000e-04
# Epoch 18/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9975 - loss: 0.5665
# Epoch 18: val_loss did not improve from 0.50892
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9975 - loss: 0.5665 - val_accuracy: 0.9985 - val_loss: 0.5153 - learning_rate: 1.0000e-04
# Epoch 19/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9994 - loss: 0.5603
# Epoch 19: val_loss did not improve from 0.50892
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9993 - loss: 0.5603 - val_accuracy: 0.9985 - val_loss: 0.5103 - learning_rate: 1.0000e-04
# Epoch 20/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.5550
# Epoch 20: val_loss did not improve from 0.50892
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9996 - loss: 0.5550 - val_accuracy: 0.9985 - val_loss: 0.5102 - learning_rate: 1.0000e-04
# Epoch 21/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5612
# Epoch 21: val_loss improved from 0.50892 to 0.50615, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.5611 - val_accuracy: 0.9985 - val_loss: 0.5062 - learning_rate: 1.0000e-04
# Epoch 22/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9960 - loss: 0.5579
# Epoch 22: val_loss improved from 0.50615 to 0.50493, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9960 - loss: 0.5579 - val_accuracy: 0.9985 - val_loss: 0.5049 - learning_rate: 1.0000e-04
# Epoch 23/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9998 - loss: 0.5507
# Epoch 23: val_loss did not improve from 0.50493
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9998 - loss: 0.5508 - val_accuracy: 0.9985 - val_loss: 0.5064 - learning_rate: 1.0000e-04
# Epoch 24/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9975 - loss: 0.5516
# Epoch 24: val_loss improved from 0.50493 to 0.50472, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9975 - loss: 0.5517 - val_accuracy: 0.9985 - val_loss: 0.5047 - learning_rate: 1.0000e-04
# Epoch 25/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9988 - loss: 0.5559
# Epoch 25: val_loss improved from 0.50472 to 0.50338, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9988 - loss: 0.5559 - val_accuracy: 0.9985 - val_loss: 0.5034 - learning_rate: 1.0000e-04
# Epoch 26/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9993 - loss: 0.5470
# Epoch 26: val_loss did not improve from 0.50338
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9993 - loss: 0.5471 - val_accuracy: 0.9985 - val_loss: 0.5109 - learning_rate: 1.0000e-04
# Epoch 27/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9999 - loss: 0.5467
# Epoch 27: val_loss did not improve from 0.50338
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9999 - loss: 0.5467 - val_accuracy: 0.9985 - val_loss: 0.5081 - learning_rate: 1.0000e-04
# Epoch 28/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9979 - loss: 0.5449
# Epoch 28: val_loss improved from 0.50338 to 0.50115, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9979 - loss: 0.5449 - val_accuracy: 0.9985 - val_loss: 0.5011 - learning_rate: 1.0000e-04
# Epoch 29/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.5457
# Epoch 29: val_loss did not improve from 0.50115
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9996 - loss: 0.5457 - val_accuracy: 0.9985 - val_loss: 0.5025 - learning_rate: 1.0000e-04
# Epoch 30/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9999 - loss: 0.5464
# Epoch 30: val_loss did not improve from 0.50115
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9999 - loss: 0.5464 - val_accuracy: 0.9985 - val_loss: 0.5028 - learning_rate: 1.0000e-04
# Epoch 31/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9990 - loss: 0.5460
# Epoch 31: val_loss improved from 0.50115 to 0.50021, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9990 - loss: 0.5459 - val_accuracy: 0.9985 - val_loss: 0.5002 - learning_rate: 1.0000e-04
# Epoch 32/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9987 - loss: 0.5455
# Epoch 32: val_loss improved from 0.50021 to 0.49895, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9987 - loss: 0.5454 - val_accuracy: 0.9985 - val_loss: 0.4990 - learning_rate: 1.0000e-04
# Epoch 33/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9989 - loss: 0.5355
# Epoch 33: val_loss did not improve from 0.49895
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9989 - loss: 0.5355 - val_accuracy: 0.9985 - val_loss: 0.4995 - learning_rate: 1.0000e-04
# Epoch 34/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9994 - loss: 0.5407
# Epoch 34: val_loss did not improve from 0.49895
# ...
# Epoch 52: val_loss did not improve from 0.42271
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4471 - val_accuracy: 1.0000 - val_loss: 0.4230 - learning_rate: 2.0000e-05
# Epoch 53/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4432
# Epoch 53: val_loss improved from 0.42271 to 0.42166, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4433 - val_accuracy: 1.0000 - val_loss: 0.4217 - learning_rate: 2.0000e-05
# Epoch 54/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4453
# Epoch 54: val_loss did not improve from 0.42166
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4453 - val_accuracy: 1.0000 - val_loss: 0.4222 - learning_rate: 2.0000e-05
# Epoch 55/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4441
# Epoch 55: val_loss did not improve from 0.42166
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4441 - val_accuracy: 1.0000 - val_loss: 0.4222 - learning_rate: 2.0000e-05
# Epoch 56/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4449
# Epoch 56: val_loss did not improve from 0.42166
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4450 - val_accuracy: 1.0000 - val_loss: 0.4226 - learning_rate: 2.0000e-05
# Epoch 57/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4409
# Epoch 57: val_loss did not improve from 0.42166
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4409 - val_accuracy: 1.0000 - val_loss: 0.4227 - learning_rate: 2.0000e-05
# Epoch 58/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4475
# Epoch 58: val_loss improved from 0.42166 to 0.42151, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4475 - val_accuracy: 1.0000 - val_loss: 0.4215 - learning_rate: 2.0000e-05
# Epoch 59/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4431
# Epoch 59: val_loss did not improve from 0.42151
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4431 - val_accuracy: 1.0000 - val_loss: 0.4219 - learning_rate: 2.0000e-05
# Epoch 60/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4425
# Epoch 60: val_loss did not improve from 0.42151
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4425 - val_accuracy: 1.0000 - val_loss: 0.4220 - learning_rate: 2.0000e-05
# Epoch 61/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4450
# Epoch 61: val_loss did not improve from 0.42151
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4450 - val_accuracy: 1.0000 - val_loss: 0.4215 - learning_rate: 2.0000e-05
# Epoch 62/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4442
# Epoch 62: val_loss did not improve from 0.42151
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4442 - val_accuracy: 1.0000 - val_loss: 0.4227 - learning_rate: 2.0000e-05
# Epoch 63/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4401
# Epoch 63: val_loss improved from 0.42151 to 0.42090, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4402 - val_accuracy: 1.0000 - val_loss: 0.4209 - learning_rate: 2.0000e-05
# Epoch 64/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4433
# Epoch 64: val_loss did not improve from 0.42090
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4433 - val_accuracy: 1.0000 - val_loss: 0.4213 - learning_rate: 2.0000e-05
# Epoch 65/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4443
# Epoch 65: val_loss did not improve from 0.42090
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4443 - val_accuracy: 1.0000 - val_loss: 0.4211 - learning_rate: 2.0000e-05
# Epoch 66/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4413
# Epoch 66: val_loss did not improve from 0.42090
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4413 - val_accuracy: 1.0000 - val_loss: 0.4221 - learning_rate: 2.0000e-05
# Epoch 67/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4434
# Epoch 67: val_loss did not improve from 0.42090
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4434 - val_accuracy: 1.0000 - val_loss: 0.4211 - learning_rate: 2.0000e-05
# Epoch 68/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4405
# Epoch 68: val_loss did not improve from 0.42090
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4405 - val_accuracy: 1.0000 - val_loss: 0.4212 - learning_rate: 2.0000e-05
# Epoch 69/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4411
# Epoch 69: val_loss did not improve from 0.42090
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4411 - val_accuracy: 1.0000 - val_loss: 0.4209 - learning_rate: 2.0000e-05
# Epoch 70/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4417
# Epoch 70: val_loss improved from 0.42090 to 0.42020, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4417 - val_accuracy: 1.0000 - val_loss: 0.4202 - learning_rate: 2.0000e-05
# Epoch 71/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4428
# Epoch 71: val_loss improved from 0.42020 to 0.41938, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4427 - val_accuracy: 1.0000 - val_loss: 0.4194 - learning_rate: 2.0000e-05
# Epoch 72/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4415
# Epoch 72: val_loss did not improve from 0.41938
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4415 - val_accuracy: 1.0000 - val_loss: 0.4204 - learning_rate: 2.0000e-05
# Epoch 73/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4409
# Epoch 73: val_loss did not improve from 0.41938
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4409 - val_accuracy: 1.0000 - val_loss: 0.4207 - learning_rate: 2.0000e-05
# Epoch 74/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4413
# Epoch 74: val_loss did not improve from 0.41938
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4414 - val_accuracy: 1.0000 - val_loss: 0.4195 - learning_rate: 2.0000e-05
# Epoch 75/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4414
# Epoch 75: val_loss did not improve from 0.41938
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4414 - val_accuracy: 1.0000 - val_loss: 0.4207 - learning_rate: 2.0000e-05
# Epoch 76/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4411
# Epoch 76: val_loss improved from 0.41938 to 0.41864, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4411 - val_accuracy: 1.0000 - val_loss: 0.4186 - learning_rate: 2.0000e-05
# Epoch 77/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4379
# Epoch 77: val_loss did not improve from 0.41864
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4380 - val_accuracy: 1.0000 - val_loss: 0.4196 - learning_rate: 2.0000e-05
# Epoch 78/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4412
# Epoch 78: val_loss did not improve from 0.41864
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4412 - val_accuracy: 1.0000 - val_loss: 0.4188 - learning_rate: 2.0000e-05
# Epoch 79/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4408
# Epoch 79: val_loss did not improve from 0.41864
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4408 - val_accuracy: 1.0000 - val_loss: 0.4191 - learning_rate: 2.0000e-05
# Epoch 80/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4403
# Epoch 80: val_loss did not improve from 0.41864
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4404 - val_accuracy: 1.0000 - val_loss: 0.4194 - learning_rate: 2.0000e-05
# Epoch 81/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4384
# Epoch 81: val_loss improved from 0.41864 to 0.41860, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4384 - val_accuracy: 1.0000 - val_loss: 0.4186 - learning_rate: 2.0000e-05
# Epoch 82/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4402
# Epoch 82: val_loss improved from 0.41860 to 0.41846, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4402 - val_accuracy: 1.0000 - val_loss: 0.4185 - learning_rate: 2.0000e-05
# Epoch 83/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4414
# Epoch 83: val_loss did not improve from 0.41846
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4413 - val_accuracy: 1.0000 - val_loss: 0.4199 - learning_rate: 2.0000e-05
# Epoch 84/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4385
# Epoch 84: val_loss did not improve from 0.41846
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4385 - val_accuracy: 1.0000 - val_loss: 0.4198 - learning_rate: 2.0000e-05
# Epoch 85/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4396
# Epoch 85: val_loss improved from 0.41846 to 0.41841, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4395 - val_accuracy: 1.0000 - val_loss: 0.4184 - learning_rate: 2.0000e-05
# Epoch 86/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4400
# Epoch 86: val_loss did not improve from 0.41841
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4400 - val_accuracy: 1.0000 - val_loss: 0.4195 - learning_rate: 2.0000e-05
# Epoch 87/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4392
# Epoch 87: val_loss did not improve from 0.41841
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4392 - val_accuracy: 1.0000 - val_loss: 0.4190 - learning_rate: 2.0000e-05
# Epoch 88/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4423
# Epoch 88: val_loss improved from 0.41841 to 0.41819, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4422 - val_accuracy: 1.0000 - val_loss: 0.4182 - learning_rate: 2.0000e-05
# Epoch 89/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4421
# Epoch 89: val_loss did not improve from 0.41819
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4420 - val_accuracy: 1.0000 - val_loss: 0.4191 - learning_rate: 2.0000e-05
# Epoch 90/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4368
# Epoch 90: val_loss improved from 0.41819 to 0.41779, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4369 - val_accuracy: 1.0000 - val_loss: 0.4178 - learning_rate: 2.0000e-05
# Epoch 91/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4373
# Epoch 91: val_loss did not improve from 0.41779
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4373 - val_accuracy: 1.0000 - val_loss: 0.4206 - learning_rate: 2.0000e-05
# Epoch 92/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4420
# Epoch 92: val_loss did not improve from 0.41779
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4419 - val_accuracy: 1.0000 - val_loss: 0.4192 - learning_rate: 2.0000e-05
# Epoch 93/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4418
# Epoch 93: val_loss did not improve from 0.41779
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4417 - val_accuracy: 1.0000 - val_loss: 0.4195 - learning_rate: 2.0000e-05
# Epoch 94/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4396
# Epoch 94: val_loss did not improve from 0.41779
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4396 - val_accuracy: 1.0000 - val_loss: 0.4197 - learning_rate: 2.0000e-05
# Epoch 95/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4395
# Epoch 95: val_loss did not improve from 0.41779
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4395 - val_accuracy: 1.0000 - val_loss: 0.4184 - learning_rate: 2.0000e-05
# Epoch 96/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4427
# Epoch 96: val_loss did not improve from 0.41779
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4426 - val_accuracy: 1.0000 - val_loss: 0.4183 - learning_rate: 2.0000e-05
# Epoch 97/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4405
# Epoch 97: val_loss did not improve from 0.41779
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4405 - val_accuracy: 1.0000 - val_loss: 0.4192 - learning_rate: 2.0000e-05
# Epoch 98/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4390
# Epoch 98: val_loss did not improve from 0.41779
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4390 - val_accuracy: 1.0000 - val_loss: 0.4189 - learning_rate: 2.0000e-05
# Epoch 99/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4392
# Epoch 99: val_loss did not improve from 0.41779
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4392 - val_accuracy: 1.0000 - val_loss: 0.4190 - learning_rate: 2.0000e-05
# Epoch 100/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4379
# Epoch 100: val_loss did not improve from 0.41779
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4379 - val_accuracy: 1.0000 - val_loss: 0.4179 - learning_rate: 2.0000e-05
#
# Fold 5 - Evaluation on validation set:
#  - Loss: 0.4178
#  - Accuracy: 1.0000
#
# Average results across 5 folds:
#  - Average Loss: 0.4610
#  - Average Accuracy: 0.9973
#
# Sample prediction probabilities:
# Sample 1: True=Angry, Pred=Angry, Prob=[0.9286849  0.0160569  0.02102513 0.01799109 0.01624193]
# Sample 2: True=Angry, Pred=Angry, Prob=[0.9355971  0.0195817  0.01482797 0.01562805 0.01436517]
# Sample 3: True=Angry, Pred=Angry, Prob=[0.9363064  0.01417054 0.01692363 0.01658218 0.01601726]
# Sample 4: True=Angry, Pred=Angry, Prob=[0.9426277  0.01450604 0.0130551  0.01499834 0.01481268]
# Sample 5: True=Angry, Pred=Angry, Prob=[0.8771788  0.03133647 0.02785538 0.03012992 0.03349937]
# Classification Report:
#               precision    recall  f1-score   support
#
#        Angry       1.00      1.00      1.00       144
#        Happy       1.00      1.00      1.00       114
#      Anxiety       1.00      1.00      1.00       109
#      Neutral       1.00      1.00      1.00       164
#          Sad       1.00      1.00      1.00       141
#
#     accuracy                           1.00       672
#    macro avg       1.00      1.00      1.00       672
# weighted avg       1.00      1.00      1.00       672
#
#
# Evaluation metric formulas:
# 1. Precision = TP / (TP + FP)
#    - TP (True Positives): Number of samples correctly predicted for a class.
#    - FP (False Positives): Number of samples incorrectly predicted as that class.
# 2. Recall = TP / (TP + FN)
#    - FN (False Negatives): Number of samples that belong to the class but were incorrectly predicted.
# 3. F1 Score = 2 * (Precision * Recall) / (Precision + Recall)

# %% [markdown]
# Test Part

# %%
    #best_model = tf.keras.models.load_model('final_cnn_2d_vesc.keras')
    #best_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    #                   loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    #                   metrics=['accuracy'])
    #scaler = joblib.load('final_cnn_2d_vesc.pkl')
    # Prepare test data
    root_folder_test = "/kaggle/input/speech-emotion-10/VESC_test/VESC_test"
    folders_test = [f for f in glob(os.path.join(root_folder_test, "*")) if os.path.isdir(f)]
    all_files_test = []
    for folder in folders_test:
        files = glob(os.path.join(folder, "**", "*.wav"), recursive=True)
        all_files_test.extend(files)
        print(f"Found {len(files)} files in folder: {os.path.basename(folder)}")

    if not all_files_test:
        raise ValueError("No audio files found in the test directory.")

    print(f"Total test files: {len(all_files_test)}")

    y_raw_test = [emotion_map.get(os.path.basename(os.path.dirname(f)), -1) for f in all_files_test]
    print("Original label distribution (test):", Counter([EMOTIONS[i] for i in y_raw_test if i != -1]))
    print(f"GLOBAL_MEAN_PITCH: {GLOBAL_MEAN_PITCH:.4f}, GLOBAL_JITTER: {GLOBAL_JITTER:.4f}, GLOBAL_PITCH_SLOPE: {GLOBAL_PITCH_SLOPE:.4f}")
    X_test, y_test = prepare_test_data(all_files_test, emotion_map, (GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE))

    # Normalize features for the test set
    X_test_2d = X_test.reshape(X_test.shape[0], -1)
    X_test_2d = scaler.transform(X_test_2d)
    X_test = X_test_2d.reshape(X_test.shape)

    evaluate_model(cnn_model, X_test, y_test)

    print("\nPredictions on test files:")
    for test_path in all_files_test:
        predicted_emotion = predict_emotion(test_path, cnn_model, scaler, (GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE))
        print(f"Predicted emotion for {os.path.basename(test_path)} (best model): {predicted_emotion}")
# Out:
# Found 37 files in folder: Angry
# Found 32 files in folder: Neutral
# Found 20 files in folder: Anxiety
# Found 99 files in folder: Sad
# Found 44 files in folder: Happy
# Total test files: 232
# Original label distribution (test): Counter({'Sad': 99, 'Happy': 44, 'Angry': 37, 'Neutral': 32, 'Anxiety': 20})
# GLOBAL_MEAN_PITCH: 1314.3724, GLOBAL_JITTER: 1039.1417, GLOBAL_PITCH_SLOPE: 0.0000
# Total number of test audio files: 232
# Processed: 232 samples, skipped: 0 files.
# Test dataset shape: X=(232, 107, 157, 1), y=(232, 5)
#
# Sample prediction probabilities:
# Sample 1: True=Angry, Pred=Angry, Prob=[0.8778887  0.03222863 0.02916138 0.03641919 0.02430212]
# Sample 2: True=Angry, Pred=Angry, Prob=[0.8573377  0.03734735 0.03609584 0.03440867 0.03481043]
# Sample 3: True=Angry, Pred=Angry, Prob=[0.7705119  0.07806911 0.05872199 0.04701592 0.04568102]
# Sample 4: True=Angry, Pred=Angry, Prob=[0.9250886  0.02419742 0.0125698  0.02082098 0.01732307]
# Sample 5: True=Angry, Pred=Angry, Prob=[0.9476053  0.01434496 0.01290824 0.01406445 0.01107695]
# Classification Report:
#               precision    recall  f1-score   support
#
#        Angry       0.97      0.89      0.93        37
#        Happy       0.91      0.91      0.91        44
#      Anxiety       0.83      0.95      0.88        20
#      Neutral       1.00      1.00      1.00        32
#          Sad       0.98      0.98      0.98        99
#
#     accuracy                           0.95       232
#    macro avg       0.94      0.95      0.94       232
# weighted avg       0.95      0.95      0.95       232
#
#
# Evaluation metric formulas:
# 1. Precision = TP / (TP + FP)
#    - TP (True Positives): Number of samples correctly predicted for a class.
#    - FP (False Positives): Number of samples incorrectly predicted as that class.
# 2. Recall = TP / (TP + FN)
#    - FN (False Negatives): Number of samples that belong to the class but were incorrectly predicted.
# 3. F1 Score = 2 * (Precision * Recall) / (Precision + Recall)
#
# Predictions on test files:
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p02_M2_12147_12151.wav: [0.8778887  0.03222863 0.02916137 0.03641918 0.02430211]
# Predicted emotion for angry_p02_M2_12147_12151.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p02_M3_11533_11539.wav: [0.8573378  0.03734735 0.03609585 0.03440868 0.03481042]
# Predicted emotion for angry_p02_M3_11533_11539.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2616_2622.wav: [0.770512   0.07806908 0.05872196 0.0470159  0.04568101]
# Predicted emotion for angry_p06_F10_2616_2622.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p03_t4_F4_4547_4552.wav: [0.9250886  0.02419744 0.01256981 0.02082099 0.01732308]
# Predicted emotion for angry_p03_t4_F4_4547_4552.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2743_2747.wav: [0.9476053  0.01434495 0.01290823 0.01406445 0.01107695]
# Predicted emotion for angry_p06_F10_2743_2747.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_F1_2433_2436.wav: [0.8755634  0.03776864 0.03068683 0.02948715 0.02649398]
# Predicted emotion for angry_p01_F1_2433_2436.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F7_12809_12811.wav: [0.24634191 0.6013109  0.05415931 0.0551652  0.04302267]
# Predicted emotion for angry_p04_F7_12809_12811.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_322_328.wav: [0.8627785  0.0382016  0.03133472 0.03261775 0.03506745]
# Predicted emotion for angry_p01_M2_322_328.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_2634_2629.wav: [0.9234603  0.01669541 0.02182532 0.02217782 0.01584116]
# Predicted emotion for angry_p01_M2_2634_2629.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p03_t4_F4_1340_1350.wav: [0.7622635  0.08334079 0.04177639 0.04622024 0.06639911]
# Predicted emotion for angry_p03_t4_F4_1340_1350.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p03_t11_M5_1325_1332.wav: [0.59443843 0.03545469 0.12134355 0.19851048 0.05025282]
# Predicted emotion for angry_p03_t11_M5_1325_1332.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_F1_2639_2622.wav: [0.96629137 0.00939369 0.00802667 0.01001304 0.00627525]
# Predicted emotion for angry_p01_F1_2639_2622.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F9_4125_4130.wav: [0.9241722  0.0210932  0.0181266  0.02056549 0.01604244]
# Predicted emotion for angry_p06_F9_4125_4130.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p02_M2_12026_12029.wav: [0.9309464  0.01799697 0.01640535 0.01674374 0.01790757]
# Predicted emotion for angry_p02_M2_12026_12029.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2652_2657.wav: [0.8910937  0.02757525 0.02351107 0.02950595 0.02831404]
# Predicted emotion for angry_p06_F10_2652_2657.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F7_12835_12837.wav: [0.3930869  0.42595074 0.0669381  0.06185108 0.05217313]
# Predicted emotion for angry_p04_F7_12835_12837.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_M20_4257_4304.wav: [0.6614759  0.07586528 0.05797987 0.0683439  0.13633502]
# Predicted emotion for angry_p06_M20_4257_4304.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_M20_3004_3008.wav: [0.92150414 0.01957164 0.02059029 0.0220838  0.01625004]
# Predicted emotion for angry_p06_M20_3004_3008.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F8_152_154.wav: [0.91798383 0.0229383  0.02100897 0.02034035 0.01772849]
# Predicted emotion for angry_p04_F8_152_154.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_M17_10415_10420_vocals.wav: [0.76647204 0.07140552 0.05322999 0.04921906 0.05967341]
# Predicted emotion for angry_p04_M17_10415_10420_vocals.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F8_2523_2526.wav: [0.6558859  0.18910027 0.05255838 0.04678338 0.05567209]
# Predicted emotion for angry_p04_F8_2523_2526.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F8_5042_5046.wav: [0.20296359 0.23778816 0.47411382 0.06555519 0.01957928]
# Predicted emotion for angry_p04_F8_5042_5046.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p03_t11_M5_1049_1056.wav: [0.7377161  0.04590458 0.03158415 0.10825522 0.07653996]
# Predicted emotion for angry_p03_t11_M5_1049_1056.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_3034_3037.wav: [0.87942874 0.03455611 0.02637484 0.03907905 0.02056132]
# Predicted emotion for angry_p01_M2_3034_3037.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p02_M1_4754_4756.wav: [0.8394953  0.04670259 0.03607966 0.04015383 0.03756857]
# Predicted emotion for angry_p02_M1_4754_4756.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_322_328_vocals.wav: [0.8714499  0.0316002  0.02925535 0.031062   0.03663248]
# Predicted emotion for angry_p01_M2_322_328_vocals.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_M17_10350_10400_vocals.wav: [0.8368226  0.0434044  0.03928187 0.03982694 0.0406643 ]
# Predicted emotion for angry_p04_M17_10350_10400_vocals.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p02_M3_11614_11617.wav: [0.85442424 0.0429866  0.02706942 0.0349278  0.04059199]
# Predicted emotion for angry_p02_M3_11614_11617.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p03_t11_M5_1301_1308.wav: [0.96676844 0.00583108 0.00906156 0.00951172 0.00882722]
# Predicted emotion for angry_p03_t11_M5_1301_1308.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2634_2637_vocals.wav: [0.86978656 0.03264866 0.03114906 0.03241843 0.0339973 ]
# Predicted emotion for angry_p06_F10_2634_2637_vocals.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_3011_3016.wav: [0.93764234 0.01844484 0.0120265  0.0181062  0.01378006]
# Predicted emotion for angry_p06_F10_3011_3016.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_2620_2625.wav: [0.9269611  0.02136962 0.01515303 0.0194465  0.01706959]
# Predicted emotion for angry_p01_M2_2620_2625.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_4225_4231.wav: [0.9661875  0.00865864 0.00801724 0.01023181 0.00690484]
# Predicted emotion for angry_p06_F10_4225_4231.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2737_2741.wav: [0.9567326  0.01273793 0.0092775  0.01232182 0.00893019]
# Predicted emotion for angry_p06_F10_2737_2741.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F7_12820_12822.wav: [0.35070196 0.53302777 0.033612   0.05148373 0.03117452]
# Predicted emotion for angry_p04_F7_12820_12822.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2817_2820.wav: [0.94863427 0.01502523 0.01278419 0.01287283 0.01068355]
# Predicted emotion for angry_p06_F10_2817_2820.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_2230_2235.wav: [0.9147635  0.01971412 0.02295537 0.02372946 0.01883762]
# Predicted emotion for angry_p01_M2_2230_2235.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F35_3033_3038.wav: [0.02795094 0.02402703 0.02395741 0.90221494 0.02184971]
# Predicted emotion for neutral_p12_F35_3033_3038.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M31_2615_2620.wav: [0.05492152 0.04289106 0.04552328 0.8085276  0.04813661]
# Predicted emotion for neutral_p12_M31_2615_2620.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F34_26552657.wav: [0.03733044 0.04593523 0.04586248 0.84011745 0.03075437]
# Predicted emotion for neutral_p12_F34_26552657.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_2907_2910.wav: [0.01518571 0.0215383  0.01835003 0.931764   0.01316198]
# Predicted emotion for neutral_p12_M30_2907_2910.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3236_3239.wav: [0.0402426  0.02531022 0.04935976 0.85282886 0.03225858]
# Predicted emotion for neutral_p12_M30_3236_3239.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3253_3256.wav: [0.01599312 0.01498637 0.01583096 0.93985415 0.01333538]
# Predicted emotion for neutral_p12_M30_3253_3256.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F36_3133_3137.wav: [0.02091876 0.02517083 0.02157911 0.91236377 0.01996755]
# Predicted emotion for neutral_p12_F36_3133_3137.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3230_3233.wav: [0.01404728 0.01586658 0.01140461 0.9494672  0.00921432]
# Predicted emotion for neutral_p12_M30_3230_3233.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3147_3151.wav: [0.02926778 0.04339572 0.08126197 0.77979994 0.0662746 ]
# Predicted emotion for neutral_p12_M30_3147_3151.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M31_2620_2624.wav: [0.03028404 0.02722394 0.02180616 0.89956355 0.02112229]
# Predicted emotion for neutral_p12_M31_2620_2624.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_2910_2914.wav: [0.01832056 0.01851742 0.01589851 0.9317744  0.01548917]
# Predicted emotion for neutral_p12_M30_2910_2914.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_2914_2919.wav: [0.02017023 0.02271421 0.02219521 0.90928954 0.02563087]
# Predicted emotion for neutral_p12_M30_2914_2919.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3248_3251.wav: [0.02911285 0.02169694 0.02710829 0.8875027  0.03457918]
# Predicted emotion for neutral_p12_M30_3248_3251.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F35_3028_3032.wav: [0.02118131 0.01931767 0.02175631 0.9182608  0.0194839 ]
# Predicted emotion for neutral_p12_F35_3028_3032.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3152_3155.wav: [0.01957809 0.01936581 0.02782897 0.9152155  0.01801168]
# Predicted emotion for neutral_p12_M30_3152_3155.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M31_2607_2610.wav: [0.01123343 0.01416135 0.01184041 0.9528101  0.00995466]
# Predicted emotion for neutral_p12_M31_2607_2610.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3233_3235.wav: [0.04504023 0.0416351  0.03316758 0.8523802  0.02777684]
# Predicted emotion for neutral_p12_M30_3233_3235.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3144_3147.wav: [0.02058892 0.02606706 0.03276115 0.89601445 0.0245684 ]
# Predicted emotion for neutral_p12_M30_3144_3147.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_719_722.wav: [0.03877564 0.03385188 0.01667012 0.88113296 0.02956943]
# Predicted emotion for neutral_p12_M30_719_722.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F34_2819_2822.wav: [0.01219033 0.01100535 0.0113564  0.95491254 0.01053541]
# Predicted emotion for neutral_p12_F34_2819_2822.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M31_1457_1500.wav: [0.07125624 0.08193718 0.05755764 0.7105667  0.07868215]
# Predicted emotion for neutral_p12_M31_1457_1500.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3222_3227.wav: [0.04411428 0.03514977 0.0522998  0.8254873  0.0429488 ]
# Predicted emotion for neutral_p12_M30_3222_3227.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3227_3229.wav: [0.01714137 0.01805951 0.01733394 0.9338986  0.01356664]
# Predicted emotion for neutral_p12_M30_3227_3229.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F34_2825_2828.wav: [0.05125165 0.05308197 0.0206903  0.8525141  0.02246208]
# Predicted emotion for neutral_p12_F34_2825_2828.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F37_1449_1453.wav: [0.03566454 0.03619772 0.04039149 0.76871353 0.11903278]
# Predicted emotion for neutral_p12_F37_1449_1453.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3250_3252.wav: [0.01383605 0.01730537 0.01689913 0.9406665  0.01129289]
# Predicted emotion for neutral_p12_M30_3250_3252.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M31_2610_2614.wav: [0.02388485 0.0316924  0.02815793 0.892402   0.02386281]
# Predicted emotion for neutral_p12_M31_2610_2614.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3240_3242.wav: [0.05953557 0.09870595 0.3315649  0.41740245 0.09279107]
# Predicted emotion for neutral_p12_M30_3240_3242.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_714_718.wav: [0.04326497 0.05444833 0.03195113 0.79640275 0.07393287]
# Predicted emotion for neutral_p12_M30_714_718.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_2903_2906.wav: [0.0105457  0.01134096 0.01120503 0.95892614 0.00798221]
# Predicted emotion for neutral_p12_M30_2903_2906.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F34_2820_2824.wav: [0.01427981 0.0131463  0.01700918 0.94256914 0.01299552]
# Predicted emotion for neutral_p12_F34_2820_2824.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_2901_2903.wav: [0.04694334 0.03748011 0.03868152 0.83290434 0.04399072]
# Predicted emotion for neutral_p12_M30_2901_2903.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p09_M25_2459_2505.wav: [0.04286025 0.05383303 0.7839213  0.03914097 0.08024442]
# Predicted emotion for anxiety_p09_M25_2459_2505.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p03_F12_4635_4639_vocals.wav: [0.01892411 0.0147128  0.93364364 0.01883059 0.01388893]
# Predicted emotion for anxiety_p03_F12_4635_4639_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p02_F3_10129_10132.wav: [0.03025186 0.03805444 0.8667236  0.02813351 0.03683657]
# Predicted emotion for anxiety_p02_F3_10129_10132.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p03_t2_F14_4730_4731_vocals.wav: [0.01636658 0.01379176 0.93461263 0.02204608 0.01318297]
# Predicted emotion for anxiety_p03_t2_F14_4730_4731_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F7_5326_5233.wav: [0.07864961 0.14526887 0.36959985 0.05071706 0.35576457]
# Predicted emotion for anxiety_p04_F7_5326_5233.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p03_t2_M16_4723_4726_vocals.wav: [0.01687704 0.03652845 0.889289   0.02084014 0.03646535]
# Predicted emotion for anxiety_p03_t2_M16_4723_4726_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F7_3259_3303.wav: [0.09851714 0.20342512 0.571992   0.05543111 0.07063458]
# Predicted emotion for anxiety_p04_F7_3259_3303.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p03_t3_M14_457_502_vocals.wav: [0.03445467 0.04541357 0.8374808  0.03741199 0.04523904]
# Predicted emotion for anxiety_p03_t3_M14_457_502_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F8_4154_4157.wav: [0.02092827 0.02095668 0.92508614 0.01657612 0.01645286]
# Predicted emotion for anxiety_p04_F8_4154_4157.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p03_M6_3137_3139_vocals.wav: [0.02199889 0.02398908 0.915293   0.02400685 0.01471223]
# Predicted emotion for anxiety_p03_M6_3137_3139_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/auxiety_p07_F24_13005_13011_vocals.wav: [0.08580298 0.07193603 0.30148703 0.05226184 0.4885122 ]
# Predicted emotion for auxiety_p07_F24_13005_13011_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p06_F18_1624_1632_vocals.wav: [0.2672554  0.2521984  0.356454   0.07875277 0.04533938]
# Predicted emotion for anxiety_p06_F18_1624_1632_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/auxiety_p07_F24_12923_12929.wav: [0.06349279 0.09863013 0.43094695 0.06864589 0.33828428]
# Predicted emotion for auxiety_p07_F24_12923_12929.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p06_F9_2550_2553.wav: [0.09974461 0.04793593 0.74900013 0.08045021 0.02286911]
# Predicted emotion for anxiety_p06_F9_2550_2553.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_M17_3054_3058.wav: [0.0098338  0.0103298  0.958905   0.01160069 0.00933082]
# Predicted emotion for anxiety_p04_M17_3054_3058.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F8_4150_4154_vocals.wav: [0.02940846 0.03188569 0.89511216 0.02034684 0.02324677]
# Predicted emotion for anxiety_p04_F8_4150_4154_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F7_2420_2422.wav: [0.01440209 0.01704737 0.9402299  0.01848629 0.00983441]
# Predicted emotion for anxiety_p04_F7_2420_2422.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p06_F18_3315_3320_vocals.wav: [0.15978754 0.1198221  0.525763   0.05085327 0.14377405]
# Predicted emotion for anxiety_p06_F18_3315_3320_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F7_2214_2216.wav: [0.07907268 0.22040938 0.5452257  0.06071638 0.09457596]
# Predicted emotion for anxiety_p04_F7_2214_2216.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F15_12316_12320.wav: [0.01696776 0.06174492 0.872074   0.02312567 0.02608761]
# Predicted emotion for anxiety_p04_F15_12316_12320.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_3232_3237.wav: [0.04983028 0.03495625 0.08456108 0.03556799 0.7950844 ]
# Predicted emotion for sad_p06_F9_3232_3237.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_1918_1925.wav: [0.0269275  0.01974125 0.03128444 0.02090951 0.9011373 ]
# Predicted emotion for sad_p06_F9_1918_1925.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_2728_2733.wav: [0.02389867 0.0233428  0.01932873 0.01949431 0.9139355 ]
# Predicted emotion for sad_p06_F9_2728_2733.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_13223_13236.wav: [0.04962997 0.08636344 0.05038116 0.09538341 0.718242  ]
# Predicted emotion for sad_p07_M19_13223_13236.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F17_13405_13413.wav: [0.01051916 0.00732329 0.00985625 0.00976168 0.9625396 ]
# Predicted emotion for sad_p07_F17_13405_13413.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F17_13320_13328.wav: [0.04033587 0.04136609 0.03000319 0.02627598 0.8620188 ]
# Predicted emotion for sad_p07_F17_13320_13328.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1629_1635.wav: [0.02049628 0.01136505 0.01129399 0.01370928 0.9431354 ]
# Predicted emotion for sad_p09_F21_1629_1635.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F29_331_335_vocals.wav: [0.02545475 0.02933703 0.02549035 0.02320119 0.8965167 ]
# Predicted emotion for sad_p10_F29_331_335_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F17_5132_5140.wav: [0.02028352 0.02441502 0.02375768 0.01648219 0.91506153]
# Predicted emotion for sad_p07_F17_5132_5140.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p04_F8_13806_13810.wav: [0.01513481 0.04058672 0.02208058 0.01847889 0.903719  ]
# Predicted emotion for sad_p04_F8_13806_13810.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_5048_5055.wav: [0.02829925 0.04950819 0.05778052 0.03603628 0.8283757 ]
# Predicted emotion for sad_p07_M19_5048_5055.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_2308_2311.wav: [0.01860549 0.02067819 0.03067357 0.02550468 0.90453804]
# Predicted emotion for sad_p07_M19_2308_2311.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F19_1831_1836_vocals.wav: [0.03373922 0.03104399 0.02726183 0.02466306 0.8832919 ]
# Predicted emotion for sad_p09_F19_1831_1836_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_2628_2633.wav: [0.08635036 0.11208642 0.06296732 0.09672327 0.64187264]
# Predicted emotion for sad_p06_F9_2628_2633.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_12429_12436.wav: [0.02988332 0.02468291 0.02386096 0.02039636 0.90117645]
# Predicted emotion for sad_p07_M19_12429_12436.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_2329_2333.wav: [0.02002456 0.0187248  0.01779633 0.02107479 0.9223795 ]
# Predicted emotion for sad_p07_F33_2329_2333.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F43_11712_11717.wav: [0.02745199 0.02616402 0.02914588 0.02364998 0.8935882 ]
# Predicted emotion for sad_p07_F43_11712_11717.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_336_341_vocals.wav: [0.02432456 0.02881741 0.0180938  0.0248096  0.9039547 ]
# Predicted emotion for sad_p10_F28_336_341_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F29_428_434_vocals.wav: [0.04570406 0.10388727 0.10805707 0.03475508 0.7075965 ]
# Predicted emotion for sad_p10_F29_428_434_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_258_204_vocals.wav: [0.03484726 0.03740347 0.02684748 0.02227354 0.8786282 ]
# Predicted emotion for sad_p10_F28_258_204_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_2607_2611.wav: [0.11293556 0.136746   0.07507385 0.06507872 0.6101659 ]
# Predicted emotion for sad_p06_F9_2607_2611.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_M25_2507_2511_vocals.wav: [0.02584233 0.02867168 0.02558427 0.0197111  0.9001906 ]
# Predicted emotion for sad_p09_M25_2507_2511_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12409_12412_vocals.wav: [0.01596475 0.01896869 0.0169141  0.01506616 0.9330863 ]
# Predicted emotion for sad_p07_F33_12409_12412_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M2_12015_12023.wav: [0.02637356 0.06428708 0.0576117  0.04383304 0.8078946 ]
# Predicted emotion for sad_p02_M2_12015_12023.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_1052_1057.wav: [0.0298031  0.02883968 0.02561346 0.02722041 0.8885233 ]
# Predicted emotion for sad_p07_M19_1052_1057.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1552_1558_vocals.wav: [0.01508573 0.01159733 0.01251388 0.014569   0.94623405]
# Predicted emotion for sad_p09_F21_1552_1558_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_3227_3230.wav: [0.02038451 0.01932425 0.0184538  0.01997708 0.92186034]
# Predicted emotion for sad_p07_M19_3227_3230.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3909_3917_vocals.wav: [0.08739752 0.17825334 0.19986808 0.03804807 0.49643302]
# Predicted emotion for sad_p10_F28_3909_3917_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p04_F8_13745_13749.wav: [0.03013876 0.4798923  0.04862398 0.03657969 0.40476528]
# Predicted emotion for sad_p04_F8_13745_13749.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_F1_2611_2615.wav: [0.03366177 0.02592168 0.02628989 0.03908178 0.8750449 ]
# Predicted emotion for sad_p01_F1_2611_2615.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1638_1644.wav: [0.00944109 0.00921096 0.01047852 0.00791993 0.96294945]
# Predicted emotion for sad_p09_F21_1638_1644.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3401_3410_vocals.wav: [0.02048422 0.01961839 0.01889311 0.02034921 0.92065513]
# Predicted emotion for sad_p10_F28_3401_3410_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F22_2140_2144.wav: [0.09155929 0.0963572  0.42251757 0.11015359 0.2794123 ]
# Predicted emotion for sad_p09_F22_2140_2144.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_F38_2811_2816.wav: [0.01595839 0.01520266 0.01502693 0.01501142 0.93880063]
# Predicted emotion for sad_p01_F38_2811_2816.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_F2_5705_5712.wav: [0.0277606  0.01852326 0.02390708 0.02106819 0.9087409 ]
# Predicted emotion for sad_p02_F2_5705_5712.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F44_12540_12544.wav: [0.04652421 0.09097052 0.07058136 0.03902412 0.7528998 ]
# Predicted emotion for sad_p07_F44_12540_12544.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3744_3750_vocals.wav: [0.06765606 0.05756336 0.05856791 0.03980102 0.77641165]
# Predicted emotion for sad_p10_F28_3744_3750_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_2406_2412_vocals.wav: [0.01216084 0.01428711 0.01500819 0.0138584  0.9446854 ]
# Predicted emotion for sad_p09_F21_2406_2412_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_406_413.wav: [0.06778281 0.08474081 0.05667555 0.037588   0.7532128 ]
# Predicted emotion for sad_p06_F9_406_413.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_M32_806_809_vocals.wav: [0.03481933 0.01709938 0.0342277  0.02247517 0.8913784 ]
# Predicted emotion for sad_p09_M32_806_809_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_2530_2536.wav: [0.02800418 0.0302609  0.02858115 0.03084237 0.88231146]
# Predicted emotion for sad_p07_M19_2530_2536.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_1715_1722.wav: [0.03483241 0.02920815 0.05606784 0.02912324 0.8507683 ]
# Predicted emotion for sad_p07_M19_1715_1722.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_3320_3327_vocals.wav: [0.01263451 0.00980791 0.01168266 0.01107014 0.9548047 ]
# Predicted emotion for sad_p09_F21_3320_3327_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M1_12031_12036.wav: [0.06554409 0.04516787 0.05211211 0.03312225 0.8040537 ]
# Predicted emotion for sad_p02_M1_12031_12036.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12253_12300.wav: [0.02359659 0.02403501 0.02622183 0.02371841 0.9024282 ]
# Predicted emotion for sad_p07_F33_12253_12300.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_12417_12421.wav: [0.01554837 0.01408913 0.01054128 0.01302167 0.9467995 ]
# Predicted emotion for sad_p07_M19_12417_12421.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F29_402_406_vocals.wav: [0.03436396 0.03234283 0.01560443 0.02284651 0.8948423 ]
# Predicted emotion for sad_p10_F29_402_406_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_414_417_vocals.wav: [0.0318469  0.03289557 0.02884508 0.02345458 0.8829578 ]
# Predicted emotion for sad_p10_F28_414_417_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1708_1714_vocals.wav: [0.03003179 0.03368536 0.08096146 0.0475163  0.80780506]
# Predicted emotion for sad_p09_F21_1708_1714_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3753_3800_vocals.wav: [0.04257588 0.04062861 0.04165211 0.03219186 0.84295154]
# Predicted emotion for sad_p10_F28_3753_3800_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12225_12232.wav: [0.0211539  0.02322287 0.02759403 0.02503226 0.90299696]
# Predicted emotion for sad_p07_F33_12225_12232.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_314_318_vocals.wav: [0.02958584 0.04681258 0.03679758 0.03192676 0.8548773 ]
# Predicted emotion for sad_p10_F28_314_318_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_eb_M36_1953_1957.wav: [0.05285135 0.04980265 0.07311904 0.06156509 0.7626619 ]
# Predicted emotion for sad_p06_eb_M36_1953_1957.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12447_12452.wav: [0.02244825 0.02736411 0.04332568 0.02967956 0.8771824 ]
# Predicted emotion for sad_p07_F33_12447_12452.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3352_3401.wav: [0.03248886 0.03828439 0.04709361 0.03290281 0.84923035]
# Predicted emotion for sad_p10_F28_3352_3401.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_M35_1933_1937.wav: [0.01688849 0.01488047 0.01539    0.01525291 0.93758816]
# Predicted emotion for sad_p01_M35_1933_1937.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12459_12505.wav: [0.01029102 0.01245558 0.02012505 0.01170008 0.94542825]
# Predicted emotion for sad_p07_F33_12459_12505.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_M20_4343_4348.wav: [0.09743299 0.11731344 0.24024315 0.0682614  0.47674903]
# Predicted emotion for sad_p06_M20_4343_4348.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_5028_5035.wav: [0.03657641 0.02721073 0.04606195 0.03356281 0.85658807]
# Predicted emotion for sad_p07_M19_5028_5035.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_13934_13940.wav: [0.04546344 0.06569722 0.02931854 0.02873612 0.8307847 ]
# Predicted emotion for sad_p07_F33_13934_13940.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F29_349_353_vocals.wav: [0.03600955 0.05008076 0.03685703 0.0430067  0.83404595]
# Predicted emotion for sad_p10_F29_349_353_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M2_12051_12053.wav: [0.01085228 0.01051878 0.01169815 0.01192479 0.95500606]
# Predicted emotion for sad_p02_M2_12051_12053.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_2339_2337.wav: [0.02323533 0.02380393 0.0172445  0.02041872 0.91529745]
# Predicted emotion for sad_p07_F33_2339_2337.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_M35_2303_2306.wav: [0.01781828 0.02144215 0.02083208 0.0207269  0.91918063]
# Predicted emotion for sad_p01_M35_2303_2306.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3352_3401_vocals.wav: [0.07161054 0.07856545 0.08924287 0.04732963 0.71325153]
# Predicted emotion for sad_p10_F28_3352_3401_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F17_13456_13502.wav: [0.03374315 0.03247386 0.0305014  0.02741823 0.8758634 ]
# Predicted emotion for sad_p07_F17_13456_13502.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3437_3442_vocals.wav: [0.03074662 0.05604295 0.06253117 0.05260845 0.7980708 ]
# Predicted emotion for sad_p10_F28_3437_3442_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_M35_3047_3051.wav: [0.05603412 0.04413994 0.0465284  0.07844989 0.7748477 ]
# Predicted emotion for sad_p01_M35_3047_3051.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3717_3725_vocals.wav: [0.0719161  0.08113434 0.08492012 0.05427512 0.70775425]
# Predicted emotion for sad_p10_F28_3717_3725_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F19_1811_1816_vocals.wav: [0.0275404  0.0195075  0.01509961 0.02117514 0.91667736]
# Predicted emotion for sad_p09_F19_1811_1816_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M2_12051_12100.wav: [0.01051898 0.01152209 0.01379061 0.01069918 0.9534691 ]
# Predicted emotion for sad_p02_M2_12051_12100.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_F1_2616_2619.wav: [0.04436735 0.05577376 0.04193768 0.07671103 0.7812101 ]
# Predicted emotion for sad_p01_F1_2616_2619.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_5038_5046.wav: [0.02434902 0.01961486 0.02033863 0.02111459 0.91458285]
# Predicted emotion for sad_p07_M19_5038_5046.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F27_458_504_vocals.wav: [0.03850976 0.03623939 0.03883169 0.03301457 0.8534046 ]
# Predicted emotion for sad_p10_F27_458_504_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F19_1837_1843_vocals.wav: [0.18723777 0.16559097 0.07488383 0.06632611 0.50596124]
# Predicted emotion for sad_p09_F19_1837_1843_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1805_1808_vocals.wav: [0.02939384 0.02305611 0.02103343 0.02180981 0.90470684]
# Predicted emotion for sad_p09_F21_1805_1808_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_2234_2247.wav: [0.01972324 0.01703181 0.01553699 0.01694319 0.9307648 ]
# Predicted emotion for sad_p07_M19_2234_2247.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_12421_12425_vocals.wav: [0.04499657 0.03753986 0.03225602 0.03288352 0.852324  ]
# Predicted emotion for sad_p07_M19_12421_12425_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M1_4801_4807.wav: [0.01291007 0.01160558 0.01336638 0.01240673 0.94971126]
# Predicted emotion for sad_p02_M1_4801_4807.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_F1_2844_2849.wav: [0.06298749 0.03725981 0.0278977  0.05471106 0.8171439 ]
# Predicted emotion for sad_p01_F1_2844_2849.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_F39_5028_5032.wav: [0.03550366 0.16446583 0.05067598 0.03695738 0.7123972 ]
# Predicted emotion for sad_p02_F39_5028_5032.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F27_448_458_vocals.wav: [0.02611014 0.05004186 0.05176466 0.03951417 0.8325692 ]
# Predicted emotion for sad_p10_F27_448_458_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_2644_2649.wav: [0.02653702 0.01780551 0.01300407 0.01787929 0.92477405]
# Predicted emotion for sad_p07_M19_2644_2649.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_13352_13356.wav: [0.04492017 0.03242605 0.04189454 0.02806881 0.8526904 ]
# Predicted emotion for sad_p07_M19_13352_13356.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_2824_2829.wav: [0.0526724  0.05401381 0.02588128 0.02910472 0.83832777]
# Predicted emotion for sad_p06_F9_2824_2829.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_2331_2335.wav: [0.08269203 0.24576096 0.21967916 0.08446477 0.36740303]
# Predicted emotion for sad_p10_F28_2331_2335.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_F3_10139_10144.wav: [0.01564517 0.01445176 0.01409276 0.01664532 0.93916506]
# Predicted emotion for sad_p02_F3_10139_10144.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_1045_1051.wav: [0.02646229 0.02319626 0.02510806 0.02871197 0.8965214 ]
# Predicted emotion for sad_p07_M19_1045_1051.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_1934_1941.wav: [0.03031222 0.01439301 0.02290683 0.02167025 0.9107177 ]
# Predicted emotion for sad_p06_F9_1934_1941.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F29_354_359_vocals.wav: [0.02267267 0.01873122 0.01585575 0.01909763 0.9236427 ]
# Predicted emotion for sad_p10_F29_354_359_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_4008_4015_vocals.wav: [0.04742305 0.05669051 0.06034794 0.03702464 0.7985139 ]
# Predicted emotion for sad_p10_F28_4008_4015_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_5750_5757.wav: [0.04330518 0.0550223  0.09387491 0.04051261 0.767285  ]
# Predicted emotion for sad_p07_F33_5750_5757.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1732_1735_vocals.wav: [0.02198475 0.02577858 0.04500327 0.06648653 0.8407468 ]
# Predicted emotion for sad_p09_F21_1732_1735_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3736_3743_vocals.wav: [0.04224223 0.04971926 0.06162231 0.03930863 0.80710757]
# Predicted emotion for sad_p10_F28_3736_3743_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_440_445_vocals.wav: [0.02590267 0.02278951 0.01907556 0.02273911 0.90949315]
# Predicted emotion for sad_p10_F28_440_445_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M1_4819_4821.wav: [0.01728815 0.01667665 0.01536887 0.01798717 0.9326792 ]
# Predicted emotion for sad_p02_M1_4819_4821.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_2316_2321_vocals.wav: [0.03401609 0.02389441 0.01838394 0.02579683 0.8979087 ]
# Predicted emotion for sad_p10_F28_2316_2321_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_12306_12311.wav: [0.02675272 0.02685466 0.02680665 0.0269962  0.8925898 ]
# Predicted emotion for sad_p07_M19_12306_12311.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12359_12405.wav: [0.03141191 0.02765925 0.0266223  0.02764069 0.8866658 ]
# Predicted emotion for sad_p07_F33_12359_12405.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_2518_2522.wav: [0.01604507 0.9369881  0.01404539 0.01730479 0.01561664]
# Predicted emotion for happy_p04_M18_2518_2522.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F28_t10_14_19_vocals.wav: [0.29236194 0.46113276 0.05615755 0.07476299 0.11558481]
# Predicted emotion for happy_p10_F28_t10_14_19_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_5016_5017.wav: [0.01254018 0.9453135  0.01344155 0.01568823 0.01301654]
# Predicted emotion for happy_p04_M18_5016_5017.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_123_128_vocals.wav: [0.10237923 0.25536066 0.08773813 0.11944685 0.43507513]
# Predicted emotion for happy_p04_M18_123_128_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_1804_1807_vocals.wav: [0.33328584 0.48563302 0.0542059  0.07595432 0.05092088]
# Predicted emotion for happy_p11_M2_1804_1807_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_1856_1902_vocals.wav: [0.10455763 0.7526135  0.03728081 0.04513786 0.06041023]
# Predicted emotion for happy_p11_M2_1856_1902_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_4826_4831_vocals.wav: [0.02873929 0.8177893  0.06150824 0.04461859 0.04734449]
# Predicted emotion for happy_p11_M2_4826_4831_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_3434_3438_vocals.wav: [0.06231246 0.7730171  0.06028068 0.05018964 0.05420007]
# Predicted emotion for happy_p11_M2_3434_3438_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F28_2733_2737.wav: [0.05335927 0.70491904 0.10627909 0.06089225 0.07455028]
# Predicted emotion for happy_p10_F28_2733_2737.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F27_2104_2107_vocals.wav: [0.2103549  0.24927571 0.32780817 0.09517101 0.11739019]
# Predicted emotion for happy_p10_F27_2104_2107_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M27_1728_1731.wav: [0.03106002 0.88967973 0.02999585 0.02633075 0.02293358]
# Predicted emotion for happy_p11_M27_1728_1731.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_10305_10310.wav: [0.10403354 0.6823086  0.0767498  0.06481254 0.07209559]
# Predicted emotion for happy_p04_M18_10305_10310.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F27_2028_2034_vocals.wav: [0.15177748 0.35677502 0.13697587 0.08322486 0.2712468 ]
# Predicted emotion for happy_p10_F27_2028_2034_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_F31_4545_4550.wav: [0.01101457 0.94529164 0.01428385 0.01543431 0.01397557]
# Predicted emotion for happy_p04_F31_4545_4550.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p02_F2_10717_10721.wav: [0.06050213 0.84793925 0.03778512 0.03136589 0.02240751]
# Predicted emotion for happy_p02_F2_10717_10721.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F28_1531_1535_vocals.wav: [0.03809199 0.87482816 0.03101086 0.0242952  0.03177384]
# Predicted emotion for happy_p10_F28_1531_1535_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M27_3239_3243_vocals.wav: [0.09178721 0.7774827  0.03353732 0.04121096 0.05598195]
# Predicted emotion for happy_p11_M27_3239_3243_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p07_F33_2650_2656_vocals.wav: [0.0308342  0.75391406 0.11505269 0.03828919 0.06190986]
# Predicted emotion for happy_p07_F33_2650_2656_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_2359_2404.wav: [0.06368192 0.6382215  0.06187983 0.04094387 0.19527282]
# Predicted emotion for happy_p04_M18_2359_2404.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_2612_2615.wav: [0.01722496 0.91254014 0.02287806 0.0278205  0.01953638]
# Predicted emotion for happy_p04_M18_2612_2615.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F27_2043_22048_vocals.wav: [0.01788091 0.90424347 0.02548128 0.02114251 0.03125182]
# Predicted emotion for happy_p10_F27_2043_22048_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_1549_1553.wav: [0.06701162 0.78634626 0.06240176 0.03187297 0.0523674 ]
# Predicted emotion for happy_p04_M18_1549_1553.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F29_3623_3630_vocals.wav: [0.3153896  0.31805563 0.05808153 0.08705591 0.2214173 ]
# Predicted emotion for happy_p10_F29_3623_3630_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_1856_1902.wav: [0.16934621 0.588695   0.08482801 0.0713928  0.08573804]
# Predicted emotion for happy_p11_M2_1856_1902.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F27_2050_2054_vocals.wav: [0.06221472 0.6095197  0.05793253 0.06598389 0.20434918]
# Predicted emotion for happy_p10_F27_2050_2054_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M27_1934_1936_vocals.wav: [0.02457883 0.8936775  0.02668518 0.02729711 0.02776147]
# Predicted emotion for happy_p11_M27_1934_1936_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_34273429_vocals.wav: [0.21898232 0.46511883 0.08138359 0.0862048  0.14831036]
# Predicted emotion for happy_p11_M2_34273429_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_1058_1100.wav: [0.11197428 0.56576294 0.07418595 0.07285357 0.1752233 ]
# Predicted emotion for happy_p04_M18_1058_1100.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_F8_10221_10224.wav: [0.0630559  0.80814755 0.03516446 0.04199731 0.05163472]
# Predicted emotion for happy_p04_F8_10221_10224.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F28_3202_3208.wav: [0.096619   0.5936646  0.11047067 0.05794059 0.14130524]
# Predicted emotion for happy_p10_F28_3202_3208.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_1858_1859_vocals.wav: [0.02050791 0.9279331  0.01488974 0.02118749 0.01548172]
# Predicted emotion for happy_p11_M2_1858_1859_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M17_4635_4640.wav: [0.00677991 0.9667845  0.00939334 0.00992722 0.00711503]
# Predicted emotion for happy_p04_M17_4635_4640.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_1804_1807.wav: [0.38118532 0.37691233 0.06704982 0.0821102  0.09274232]
# Predicted emotion for happy_p11_M2_1804_1807.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M17_4536_4543.wav: [0.05663659 0.19285493 0.5472247  0.04375981 0.15952398]
# Predicted emotion for happy_p04_M17_4536_4543.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p07_F33_2610_2614_vocals.wav: [0.03046184 0.87792486 0.03031573 0.03236542 0.02893218]
# Predicted emotion for happy_p07_F33_2610_2614_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_3444_3450_vocals.wav: [0.06096276 0.8003115  0.04577852 0.04488514 0.04806203]
# Predicted emotion for happy_p11_M2_3444_3450_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M27_1924_1927_vocals.wav: [0.0965247  0.58475906 0.05592793 0.0765857  0.18620269]
# Predicted emotion for happy_p11_M27_1924_1927_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p07_M19_2615_2619_vocals.wav: [0.0132429  0.93897957 0.01742051 0.0167386  0.01361845]
# Predicted emotion for happy_p07_M19_2615_2619_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_eb_F30_10006_10010.wav: [0.01550267 0.9059774  0.04083498 0.021226   0.01645899]
# Predicted emotion for happy_p04_eb_F30_10006_10010.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_3414_3417_vocals.wav: [0.04105977 0.7585127  0.07925901 0.07343996 0.04772849]
# Predicted emotion for happy_p11_M2_3414_3417_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_130_133.wav: [0.04248472 0.85493034 0.03714865 0.03989301 0.02554327]
# Predicted emotion for happy_p04_M18_130_133.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p07_eb_F32_1442_1447_vocals.wav: [0.13844168 0.3713645  0.15324382 0.07297073 0.26397932]
# Predicted emotion for happy_p07_eb_F32_1442_1447_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M27_1921_1923_vocals.wav: [0.07337379 0.6974183  0.0510112  0.08442701 0.09376978]
# Predicted emotion for happy_p11_M27_1921_1923_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_3139_3143_vocals.wav: [0.02085798 0.9345813  0.01198235 0.01882618 0.01375221]
# Predicted emotion for happy_p11_M2_3139_3143_vocals.wav (best model): Happy

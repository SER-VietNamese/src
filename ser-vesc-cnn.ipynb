# %% [markdown]
# --CNN--

# %%
import os
from glob import glob
import numpy as np
import librosa
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
# Out:
# 2025-07-25 12:09:49.084679: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753445389.326535      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753445389.390676      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
EMO_DB = False

if EMO_DB:
    EMOTIONS = ['Angry', 'Happy', 'Fear', 'Neutral', 'Sad', 'Boredom', 'Disgust']
    NUM_CLASSES = len(EMOTIONS)
    emotion_map = {
        'Angry': 0, 
        'Happy': 1, 
        'Fear': 2, 
        'Neutral': 3, 
        'Sad': 4, 
        'Boredom': 5, 
        'Disgust': 6
    }
    DATA_PATH = '/kaggle/input/speech-emotion-10/EmoDB/EmoDB'
else:
    EMOTIONS = ['Angry', 'Happy', 'Anxiety', 'Neutral', 'Sad']
    NUM_CLASSES = len(EMOTIONS)
    emotion_map = {
        'Angry': 0, 'Happy': 1, 'Anxiety': 2, 'Neutral': 3, 'Sad': 4
    }
    DATA_PATH = '/kaggle/input/speech-emotion-10/VESC/VESC'

# Actual calculation needed from the data
GLOBAL_MEAN_PITCH = 0.0
GLOBAL_JITTER = 0.0
GLOBAL_PITCH_SLOPE = 0.0

# Function to add noise
def add_noise(audio, noise_factor=0.01):
    noise = np.random.randn(len(audio))
    return audio + noise_factor * noise

# Function to change pitch
def pitch_shift(audio, sr, n_steps=2): # Random n_steps
    return librosa.effects.pitch_shift(audio, sr=sr, n_steps=n_steps)

# Function to apply time stretching
def time_stretch(audio, rate=0.95): # Random rate
    return librosa.effects.time_stretch(audio, rate=rate)

# Function to apply time shifting
def time_shift(audio, shift_max=0.2, sr=24200):
    shift = int(np.random.uniform(-shift_max, shift_max) * sr)
    return np.roll(audio, shift)

# Function to normalize pitch
def normalize_pitch(pitches):
    pitches = pitches[pitches > 0]
    if len(pitches) == 0:
        return GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE

    mean_pitch = np.mean(pitches)
    normalized_pitches = pitches - mean_pitch
    jitter = np.std(normalized_pitches) if len(normalized_pitches) > 0 else 0

    if len(pitches) > 1:
        slope = np.polyfit(np.arange(len(pitches)), pitches, 1)[0]
    else:
        slope = 0

    if np.isnan(mean_pitch): mean_pitch = GLOBAL_MEAN_PITCH
    if np.isnan(jitter): jitter = GLOBAL_JITTER
    if np.isnan(slope): slope = GLOBAL_PITCH_SLOPE

    return mean_pitch, jitter, slope

# Feature extraction
def extract_features(audio_path, sample_rate=24200, duration=10, n_mfcc=26, n_frames=157, augment_type='normal', global_pitch_params=None):
    try:
        audio, sr = librosa.load(audio_path, sr=sample_rate)
        target_length = sample_rate * duration

        if len(audio) < target_length:
            audio = np.pad(audio, (0, target_length - len(audio)), mode='constant')
        else:
            audio = audio[:target_length]

        if augment_type == 'noise':
            audio = add_noise(audio)
        elif augment_type == 'pitch':
            audio = pitch_shift(audio, sr)
        elif augment_type == 'stretch':
            audio = time_stretch(audio)
        elif augment_type == 'shift':
            audio = time_shift(audio)

        hop_length = target_length // (n_frames - 1)

        # MFCCs + Delta + Delta-Delta
        mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length, n_fft=2048)
        mfcc_delta = librosa.feature.delta(mfcc)
        mfcc_delta2 = librosa.feature.delta(mfcc, order=2)
        mfcc_features = np.concatenate((mfcc, mfcc_delta, mfcc_delta2), axis=0)

        # Pad or truncate MFCCs
        if mfcc_features.shape[1] > n_frames:
            mfcc_features = mfcc_features[:, :n_frames]
        elif mfcc_features.shape[1] < n_frames:
            mfcc_features = np.pad(mfcc_features, ((0, 0), (0, n_frames - mfcc_features.shape[1])), mode='constant')

        # Pitch features
        pitches, magnitudes = librosa.piptrack(y=audio, sr=sr, hop_length=hop_length)
        if global_pitch_params:
            mean_pitch, jitter, pitch_slope = normalize_pitch(pitches)
            if mean_pitch == 0 and jitter == 0 and pitch_slope == 0:
                mean_pitch, jitter, pitch_slope = global_pitch_params
        else:
            mean_pitch, jitter, pitch_slope = normalize_pitch(pitches) # Will use current GLOBAL_*

        pitch_features_single = np.array([mean_pitch, jitter, pitch_slope])
        pitch_features = np.tile(pitch_features_single, (n_frames, 1)).T # Tile to match n_frames

        # Energy features (RMS + mean and std)
        energy = librosa.feature.rms(y=audio, hop_length=hop_length)[0]
        if len(energy) > n_frames:
            energy = energy[:n_frames]
        elif len(energy) < n_frames:
            energy = np.pad(energy, (0, n_frames - len(energy)), mode='constant')

        mean_energy = np.mean(energy)
        shimmer = np.std(energy) if len(energy) > 0 else 0
        energy_features = np.array([energy, np.full(n_frames, mean_energy), np.full(n_frames, shimmer)])

        # Zero-Crossing Rate
        zcr = librosa.feature.zero_crossing_rate(y=audio, hop_length=hop_length)[0]
        if len(zcr) > n_frames:
            zcr = zcr[:n_frames]
        elif len(zcr) < n_frames:
            zcr = np.pad(zcr, (0, n_frames - len(zcr)), mode='constant')
        zcr_features = zcr[np.newaxis, :]

        # Chroma features
        chroma = librosa.feature.chroma_stft(y=audio, sr=sr, hop_length=hop_length, n_chroma=12)
        if chroma.shape[1] > n_frames:
            chroma = chroma[:, :n_frames]
        elif chroma.shape[1] < n_frames:
            chroma = np.pad(chroma, ((0, 0), (0, n_frames - chroma.shape[1])), mode='constant')

        # Spectral features
        spectral_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr, hop_length=hop_length)[0]
        spectral_rolloff = librosa.feature.spectral_rolloff(y=audio, sr=sr, hop_length=hop_length)[0]
        spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sr, hop_length=hop_length, n_bands=5)

        # Pad or truncate spectral features
        # Assuming all spectral features have the same number of frames
        if spectral_centroid.shape[0] > n_frames:
            spectral_centroid = spectral_centroid[:n_frames]
            spectral_rolloff = spectral_rolloff[:n_frames]
            spectral_contrast = spectral_contrast[:, :n_frames]
        elif spectral_centroid.shape[0] < n_frames:
            spectral_centroid = np.pad(spectral_centroid, (0, n_frames - spectral_centroid.shape[0]), mode='constant')
            spectral_rolloff = np.pad(spectral_rolloff, (0, n_frames - spectral_rolloff.shape[0]), mode='constant')
            spectral_contrast = np.pad(spectral_contrast, ((0, 0), (0, n_frames - spectral_contrast.shape[1])), mode='constant')
        spectral_features = np.vstack([spectral_centroid, spectral_rolloff, spectral_contrast])

        # Temporal features
        voiced_frames = librosa.effects.split(audio, top_db=20)
        speech_rate = len(voiced_frames) / (duration if duration > 0 else 1)
        pauses = len(voiced_frames) - 1 if len(voiced_frames) > 1 else 0
        temporal_features_single = np.array([speech_rate, pauses])
        temporal_features = np.tile(temporal_features_single, (n_frames, 1)).T

        features = np.concatenate([
            mfcc_features, # Now includes delta and delta-delta
            pitch_features,
            energy_features,
            zcr_features,
            chroma,
            spectral_features,
            temporal_features
        ], axis=0)

        return np.expand_dims(features, axis=-1)

    except Exception as e:
        print(f"Error processing {audio_path}: {e}")
        return None

# Build CNN model
def build_cnn_2d(input_shape=(55, 157, 1)):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Flatten(),
        layers.Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
        layers.Dropout(0.4),
        layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    model.summary()
    return model

# Add a function to calculate GLOBAL_PITCH_PARAMS
def calculate_global_pitch_params(audio_files, sample_rate=24200):
    all_pitches = []
    for audio_path in audio_files:
        try:
            audio, sr = librosa.load(audio_path, sr=sample_rate)
            pitches, magnitudes = librosa.piptrack(y=audio, sr=sr)
            pitches = pitches[pitches > 0]
            if len(pitches) > 0:
                all_pitches.extend(pitches)
        except Exception as e:
            print(f"Error calculating global pitch for {audio_path}: {e}")
            continue

    if len(all_pitches) == 0:
        print("Warning: No valid pitches found to calculate global parameters. Using default zeros.")
        return 0.0, 0.0, 0.0

    all_pitches = np.array(all_pitches)
    global_mean_pitch = np.mean(all_pitches)

    normalized_all_pitches = all_pitches - global_mean_pitch
    global_jitter = np.std(normalized_all_pitches) if len(normalized_all_pitches) > 0 else 0

    global_pitch_slope = 0.0

    global_mean_pitch = 0.0 if np.isnan(global_mean_pitch) or np.isinf(global_mean_pitch) else global_mean_pitch
    global_jitter = 0.0 if np.isnan(global_jitter) or np.isinf(global_jitter) else global_jitter
    global_pitch_slope = 0.0 if np.isnan(global_pitch_slope) or np.isinf(global_pitch_slope) else global_pitch_slope

    return global_mean_pitch, global_jitter, global_pitch_slope


# Function to prepare data with label mapping from directory
def prepare_training_data(audio_files, emotion_map, global_pitch_params):
    X, y = [], []
    augment_types = ['normal', 'noise', 'pitch', 'stretch', 'shift']
    skipped_files = 0
    processed_files = 0

    print(f"Total number of audio files: {len(audio_files)}")
    for audio_path in audio_files:
        folder_name = os.path.basename(os.path.dirname(audio_path))
        if folder_name not in emotion_map:
            skipped_files += 1
            continue
        emotion_idx = emotion_map[folder_name]

        for aug_type in augment_types:
            features = extract_features(str(audio_path), augment_type=aug_type, global_pitch_params=global_pitch_params)
            if features is None or np.all(features == 0):
                continue
            X.append(features)
            y.append(emotion_idx)
            processed_files += 1

    print(f"Processed: {processed_files} samples, skipped: {skipped_files} files.")
    if not X or not y:
        raise ValueError("No audio files were successfully processed. Please check the data path or emotion_map.")

    X = np.array(X)
    y = to_categorical(y, num_classes=NUM_CLASSES)
    print(f"Dataset shape: X={X.shape}, y={y.shape}")
    return X, y

# Function to prepare test data
def prepare_test_data(audio_files, emotion_map, global_pitch_params):
    X, y = [], []
    skipped_files = 0
    processed_files = 0

    print(f"Total number of test audio files: {len(audio_files)}")
    for audio_path in audio_files:
        folder_name = os.path.basename(os.path.dirname(audio_path))
        if folder_name not in emotion_map:
            skipped_files += 1
            continue
        emotion_idx = emotion_map[folder_name]
        features = extract_features(str(audio_path), augment_type='normal', global_pitch_params=global_pitch_params)
        if features is None or np.all(features == 0):
            continue
        X.append(features)
        y.append(emotion_idx)
        processed_files += 1

    print(f"Processed: {processed_files} samples, skipped: {skipped_files} files.")
    if not X or not y:
        raise ValueError("No test audio files were successfully processed.")

    X = np.array(X)
    y = to_categorical(y, num_classes=NUM_CLASSES)
    print(f"Test dataset shape: X={X.shape}, y={y.shape}")
    return X, y

# Evaluate the model using confusion matrix and F1 Score
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)

    print("\nSample prediction probabilities:")
    for i in range(min(5, len(X_test))):
        print(f"Sample {i+1}: True={EMOTIONS[y_true_classes[i]]}, Pred={EMOTIONS[y_pred_classes[i]]}, Prob={y_pred[i]}")

    cm = confusion_matrix(y_true_classes, y_pred_classes)
    plt.figure(figsize=(10, 8))
    sns_heatmap = sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=EMOTIONS, yticklabels=EMOTIONS)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    print("\nClassification Report:")
    print(classification_report(y_true_classes, y_pred_classes, target_names=EMOTIONS))

    print("\nEvaluation metric formulas:")
    print("1. Precision = TP / (TP + FP)")
    print("   - TP (True Positives): Number of samples correctly predicted for a class.")
    print("   - FP (False Positives): Number of samples incorrectly predicted as that class.")
    print("2. Recall = TP / (TP + FN)")
    print("   - FN (False Negatives): Number of samples that belong to the class but were incorrectly predicted.")
    print("3. F1 Score = 2 * (Precision * Recall) / (Precision + Recall)")

# Train and evaluate
def train_and_evaluate_model(model, X, y, epochs=200, batch_size=16, checkpoint_path='best_model.h5', class_weight=None, k_folds=5):
    if len(X) == 0 or len(y) == 0:
        raise ValueError("Training dataset is empty. Please check the input data.")

    kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)
    fold_no = 1
    val_losses = []
    val_accuracies = []
    best_model = None
    best_history = None
    best_val_loss = float('inf')
    X_val_last, y_val_last = None, None
    scaler = StandardScaler()

    for train_index, val_index in kf.split(X):
        print(f"\nTraining on fold {fold_no}/{k_folds}...")

        X_train, X_val = X[train_index], X[val_index]
        y_train, y_val = y[train_index], y[val_index]
        print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}")

        original_shape_train = X_train.shape
        X_train_2d = X_train.reshape(original_shape_train[0], -1)
        
        original_shape_val = X_val.shape
        X_val_2d = X_val.reshape(original_shape_val[0], -1)
        
        X_train_2d = scaler.fit_transform(X_train_2d)
        X_val_2d = scaler.transform(X_val_2d)
        
        X_train = X_train_2d.reshape(original_shape_train)
        X_val = X_val_2d.reshape(original_shape_val)

        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                      loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                      metrics=['accuracy'])

        early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=0.00001)
        checkpoint = ModelCheckpoint(f"{checkpoint_path}_fold_{fold_no}.h5", monitor='val_loss', save_best_only=True, mode='min', verbose=1)

        history = model.fit(X_train, y_train,
                            validation_data=(X_val, y_val),
                            epochs=epochs,
                            batch_size=batch_size,
                            callbacks=[early_stopping, reduce_lr, checkpoint],
                            class_weight=class_weight,
                            verbose=1)

        val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
        print(f"\nFold {fold_no} - Evaluation on validation set:")
        print(f" - Loss: {val_loss:.4f}")
        print(f" - Accuracy: {val_accuracy:.4f}")
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = model
            best_history = history
            X_val_last, y_val_last = X_val, y_val

        fold_no += 1

    print(f"\nAverage results across {k_folds} folds:")
    print(f" - Average Loss: {np.mean(val_losses):.4f}")
    print(f" - Average Accuracy: {np.mean(val_accuracies):.4f}")

    return best_model, best_history, X_val_last, y_val_last

# Direct prediction using CNN
def predict_emotion(audio_path, model, scaler, global_pitch_params):
    features = extract_features(audio_path, augment_type='normal', global_pitch_params=global_pitch_params)
    if features is None or np.all(features == 0):
        return "Prediction failed: Feature extraction error."

    features_2d = features.reshape(1, -1)
    features_2d = scaler.transform(features_2d)
    features = features_2d.reshape(features.shape)

    features = np.expand_dims(features, axis=0)
    prediction = model.predict(features, verbose=0)
    predicted_emotion_idx = np.argmax(prediction, axis=1)[0]

    print(f"Prediction probabilities for {audio_path}: {prediction[0]}")
    return EMOTIONS[predicted_emotion_idx]

# Plot Loss Chart
def plot_loss_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
	
if __name__ == "__main__":
    # Path to the data
    root_folder = DATA_PATH
    folders = [f for f in glob(os.path.join(root_folder, "*")) if os.path.isdir(f)]
    all_files = []
    for folder in folders:
        files = glob(os.path.join(folder, "**", "*.wav"), recursive=True)
        all_files.extend(files)
        print(f"Found {len(files)} files in folder: {os.path.basename(folder)}")

    if not all_files:
        raise ValueError("No audio files found in the training directory.")

    # Calculate GLOBAL_PITCH_PARAMS first
    print("Calculating GLOBAL_PITCH_PARAMS from training data...")
    GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE = calculate_global_pitch_params(all_files)
    print(f"GLOBAL_MEAN_PITCH: {GLOBAL_MEAN_PITCH:.4f}, GLOBAL_JITTER: {GLOBAL_JITTER:.4f}, GLOBAL_PITCH_SLOPE: {GLOBAL_PITCH_SLOPE:.4f}")

    # Ensure y_raw_train has valid labels before computing class weights
    y_raw = []
    for f in all_files:
        folder_name = os.path.basename(os.path.dirname(f))
        if folder_name in emotion_map:
            y_raw.append(emotion_map[folder_name])
    
    y_raw_train = np.array(y_raw)

    if len(y_raw_train) == 0:
        raise ValueError("No valid emotion labels found for class weight calculation. Check your data and emotion_map.")

    print("Original label distribution:", Counter([EMOTIONS[i] for i in y_raw_train]))

    # Compute class weights
    # Ensure classes are passed correctly as np.unique(y_raw_train)
    class_weights = compute_class_weight('balanced', classes=np.unique(y_raw_train), y=y_raw_train)
    class_weight_dict = dict(enumerate(class_weights))
    print("Class weights:", class_weight_dict)

    # Prepare data
    X, y = prepare_training_data(all_files, emotion_map, (GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE))
    print(f"X shape: {X.shape}")

    # Normalize features
    scaler = StandardScaler()
    original_shape = X.shape
    X_2d = X.reshape(original_shape[0], -1)
    X_2d = scaler.fit_transform(X_2d)
    X = X_2d.reshape(original_shape)

    calculated_input_dim0 = X.shape[1]
    cnn_input_shape = (calculated_input_dim0, X.shape[2], 1)
    print(f"Calculated CNN Input Shape: {cnn_input_shape}")

    # Build and train the model
    cnn_model = build_cnn_2d(input_shape=cnn_input_shape)
    cnn_model, history, X_test, y_test = train_and_evaluate_model(
        cnn_model, X, y,
        epochs=100,
        batch_size=16,
        checkpoint_path='best_cnn_2d_vesc.keras',
        class_weight=class_weight_dict,
        k_folds=5
    )

    # Save the final model
    cnn_model.save('final_cnn_2d_vesc.keras')
    evaluate_model(cnn_model, X_test, y_test)
    plot_loss_history(history)
# Out:
# Found 144 files in folder: Angry
# Found 164 files in folder: Neutral
# Found 109 files in folder: Anxiety
# Found 141 files in folder: Sad
# Found 114 files in folder: Happy
# Calculating GLOBAL_PITCH_PARAMS from training data...
# GLOBAL_MEAN_PITCH: 1314.3724, GLOBAL_JITTER: 1039.1417, GLOBAL_PITCH_SLOPE: 0.0000
# Original label distribution: Counter({'Neutral': 164, 'Angry': 144, 'Sad': 141, 'Happy': 114, 'Anxiety': 109})
# Class weights: {0: 0.9333333333333333, 1: 1.1789473684210525, 2: 1.2330275229357799, 3: 0.8195121951219512, 4: 0.9531914893617022}
# Total number of audio files: 672
# Processed: 3360 samples, skipped: 0 files.
# Dataset shape: X=(3360, 107, 157, 1), y=(3360, 5)
# X shape: (3360, 107, 157, 1)
# Calculated CNN Input Shape: (107, 157, 1)
# I0000 00:00:1753445765.442827      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 107, 157, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 107, 157, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 107, 157, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 107, 157, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 53, 78, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 53, 78, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 53, 78, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 53, 78, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 26, 39, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 26, 39, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 26, 39, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 26, 39, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 19, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 13, 19, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 31616)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     8,093,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,198,181 (31.27 MB)
#  Trainable params: 8,197,669 (31.27 MB)
#  Non-trainable params: 512 (2.00 KB)
# Training on fold 1/5...
# Train shape: (2688, 107, 157, 1), Val shape: (672, 107, 157, 1)
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753445773.341787      89 service.cc:148] XLA service 0x7f3b58015b60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753445773.342659      89 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1753445773.877592      89 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  13/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.1963 - loss: 5.9480
# I0000 00:00:1753445779.701950      89 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3089 - loss: 3.8166
# Epoch 1: val_loss improved from inf to 6.22899, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - accuracy: 0.3092 - loss: 3.8109 - val_accuracy: 0.2500 - val_loss: 6.2290 - learning_rate: 1.0000e-04
# Epoch 2/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4205 - loss: 2.1347
# Epoch 2: val_loss improved from 6.22899 to 3.04865, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.4206 - loss: 2.1344 - val_accuracy: 0.4345 - val_loss: 3.0486 - learning_rate: 1.0000e-04
# Epoch 3/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4787 - loss: 2.0027
# Epoch 3: val_loss improved from 3.04865 to 2.14782, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.4789 - loss: 2.0027 - val_accuracy: 0.5417 - val_loss: 2.1478 - learning_rate: 1.0000e-04
# Epoch 4/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5334 - loss: 1.9246
# Epoch 4: val_loss improved from 2.14782 to 2.03054, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5333 - loss: 1.9247 - val_accuracy: 0.5833 - val_loss: 2.0305 - learning_rate: 1.0000e-04
# Epoch 5/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5549 - loss: 1.8615
# Epoch 5: val_loss improved from 2.03054 to 1.96601, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5552 - loss: 1.8611 - val_accuracy: 0.6116 - val_loss: 1.9660 - learning_rate: 1.0000e-04
# Epoch 6/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5961 - loss: 1.7923
# Epoch 6: val_loss improved from 1.96601 to 1.83603, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5964 - loss: 1.7919 - val_accuracy: 0.6622 - val_loss: 1.8360 - learning_rate: 1.0000e-04
# Epoch 7/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6288 - loss: 1.7341
# Epoch 7: val_loss improved from 1.83603 to 1.80440, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6289 - loss: 1.7340 - val_accuracy: 0.6771 - val_loss: 1.8044 - learning_rate: 1.0000e-04
# Epoch 8/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6715 - loss: 1.6770
# Epoch 8: val_loss improved from 1.80440 to 1.77229, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6719 - loss: 1.6763 - val_accuracy: 0.6696 - val_loss: 1.7723 - learning_rate: 1.0000e-04
# Epoch 9/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6885 - loss: 1.6350
# Epoch 9: val_loss improved from 1.77229 to 1.69525, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6886 - loss: 1.6348 - val_accuracy: 0.7054 - val_loss: 1.6952 - learning_rate: 1.0000e-04
# Epoch 10/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7155 - loss: 1.5748
# Epoch 10: val_loss improved from 1.69525 to 1.55718, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7156 - loss: 1.5747 - val_accuracy: 0.7351 - val_loss: 1.5572 - learning_rate: 1.0000e-04
# Epoch 11/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7108 - loss: 1.5400
# Epoch 11: val_loss improved from 1.55718 to 1.47994, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7111 - loss: 1.5399 - val_accuracy: 0.7679 - val_loss: 1.4799 - learning_rate: 1.0000e-04
# Epoch 12/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7665 - loss: 1.4661
# Epoch 12: val_loss improved from 1.47994 to 1.41687, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7665 - loss: 1.4660 - val_accuracy: 0.7812 - val_loss: 1.4169 - learning_rate: 1.0000e-04
# Epoch 13/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7815 - loss: 1.4103
# Epoch 13: val_loss improved from 1.41687 to 1.37271, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7815 - loss: 1.4106 - val_accuracy: 0.7887 - val_loss: 1.3727 - learning_rate: 1.0000e-04
# Epoch 14/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7841 - loss: 1.4146
# Epoch 14: val_loss improved from 1.37271 to 1.37226, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7844 - loss: 1.4140 - val_accuracy: 0.7961 - val_loss: 1.3723 - learning_rate: 1.0000e-04
# Epoch 15/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8209 - loss: 1.3520
# Epoch 15: val_loss improved from 1.37226 to 1.27407, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8209 - loss: 1.3520 - val_accuracy: 0.8378 - val_loss: 1.2741 - learning_rate: 1.0000e-04
# Epoch 16/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8374 - loss: 1.2976
# Epoch 16: val_loss improved from 1.27407 to 1.24526, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8373 - loss: 1.2978 - val_accuracy: 0.8616 - val_loss: 1.2453 - learning_rate: 1.0000e-04
# Epoch 17/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8409 - loss: 1.2748
# Epoch 17: val_loss did not improve from 1.24526
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8409 - loss: 1.2747 - val_accuracy: 0.8557 - val_loss: 1.2464 - learning_rate: 1.0000e-04
# Epoch 18/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8391 - loss: 1.2419
# Epoch 18: val_loss improved from 1.24526 to 1.21212, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8391 - loss: 1.2420 - val_accuracy: 0.8690 - val_loss: 1.2121 - learning_rate: 1.0000e-04
# Epoch 19/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8543 - loss: 1.2144
# Epoch 19: val_loss improved from 1.21212 to 1.18646, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8544 - loss: 1.2144 - val_accuracy: 0.8780 - val_loss: 1.1865 - learning_rate: 1.0000e-04
# Epoch 20/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8748 - loss: 1.1707
# Epoch 20: val_loss improved from 1.18646 to 1.11347, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8748 - loss: 1.1706 - val_accuracy: 0.8988 - val_loss: 1.1135 - learning_rate: 1.0000e-04
# Epoch 21/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8796 - loss: 1.1602
# Epoch 21: val_loss improved from 1.11347 to 1.08487, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8795 - loss: 1.1602 - val_accuracy: 0.9003 - val_loss: 1.0849 - learning_rate: 1.0000e-04
# Epoch 22/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8704 - loss: 1.1373
# Epoch 22: val_loss improved from 1.08487 to 1.06359, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8706 - loss: 1.1370 - val_accuracy: 0.9122 - val_loss: 1.0636 - learning_rate: 1.0000e-04
# Epoch 23/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8976 - loss: 1.0977
# Epoch 23: val_loss improved from 1.06359 to 1.01007, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8976 - loss: 1.0977 - val_accuracy: 0.9330 - val_loss: 1.0101 - learning_rate: 1.0000e-04
# Epoch 24/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9054 - loss: 1.0640
# Epoch 24: val_loss improved from 1.01007 to 1.00373, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9055 - loss: 1.0640 - val_accuracy: 0.9301 - val_loss: 1.0037 - learning_rate: 1.0000e-04
# Epoch 25/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8874 - loss: 1.0625
# Epoch 25: val_loss improved from 1.00373 to 0.96986, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8876 - loss: 1.0624 - val_accuracy: 0.9375 - val_loss: 0.9699 - learning_rate: 1.0000e-04
# Epoch 26/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9311 - loss: 1.0123
# Epoch 26: val_loss improved from 0.96986 to 0.94937, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9309 - loss: 1.0125 - val_accuracy: 0.9435 - val_loss: 0.9494 - learning_rate: 1.0000e-04
# Epoch 27/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9283 - loss: 1.0057
# Epoch 27: val_loss improved from 0.94937 to 0.93175, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9281 - loss: 1.0059 - val_accuracy: 0.9420 - val_loss: 0.9318 - learning_rate: 1.0000e-04
# Epoch 28/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9247 - loss: 0.9869
# Epoch 28: val_loss improved from 0.93175 to 0.89822, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9247 - loss: 0.9869 - val_accuracy: 0.9464 - val_loss: 0.8982 - learning_rate: 1.0000e-04
# Epoch 29/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9269 - loss: 0.9784
# Epoch 29: val_loss did not improve from 0.89822
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9268 - loss: 0.9783 - val_accuracy: 0.9435 - val_loss: 0.9150 - learning_rate: 1.0000e-04
# Epoch 30/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9330 - loss: 0.9506
# Epoch 30: val_loss improved from 0.89822 to 0.89180, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9331 - loss: 0.9505 - val_accuracy: 0.9494 - val_loss: 0.8918 - learning_rate: 1.0000e-04
# Epoch 31/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9316 - loss: 0.9442
# Epoch 31: val_loss improved from 0.89180 to 0.86510, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9316 - loss: 0.9442 - val_accuracy: 0.9539 - val_loss: 0.8651 - learning_rate: 1.0000e-04
# Epoch 32/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9331 - loss: 0.9303
# Epoch 32: val_loss improved from 0.86510 to 0.82762, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9332 - loss: 0.9302 - val_accuracy: 0.9628 - val_loss: 0.8276 - learning_rate: 1.0000e-04
# Epoch 33/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9313 - loss: 0.9203
# Epoch 33: val_loss did not improve from 0.82762
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9314 - loss: 0.9202 - val_accuracy: 0.9509 - val_loss: 0.8480 - learning_rate: 1.0000e-04
# Epoch 34/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9347 - loss: 0.9023
# Epoch 34: val_loss improved from 0.82762 to 0.82245, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9348 - loss: 0.9022 - val_accuracy: 0.9568 - val_loss: 0.8225 - learning_rate: 1.0000e-04
# Epoch 35/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9421 - loss: 0.8940
# Epoch 35: val_loss did not improve from 0.82245
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9422 - loss: 0.8938 - val_accuracy: 0.9568 - val_loss: 0.8245 - learning_rate: 1.0000e-04
# Epoch 36/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9458 - loss: 0.8729
# Epoch 36: val_loss improved from 0.82245 to 0.78915, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9459 - loss: 0.8728 - val_accuracy: 0.9658 - val_loss: 0.7892 - learning_rate: 1.0000e-04
# Epoch 37/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9713 - loss: 0.8429
# Epoch 37: val_loss improved from 0.78915 to 0.77805, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9712 - loss: 0.8428 - val_accuracy: 0.9673 - val_loss: 0.7781 - learning_rate: 1.0000e-04
# Epoch 38/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9570 - loss: 0.8365
# Epoch 38: val_loss improved from 0.77805 to 0.77627, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9570 - loss: 0.8365 - val_accuracy: 0.9598 - val_loss: 0.7763 - learning_rate: 1.0000e-04
# Epoch 39/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9552 - loss: 0.8433
# Epoch 39: val_loss improved from 0.77627 to 0.76712, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9551 - loss: 0.8432 - val_accuracy: 0.9643 - val_loss: 0.7671 - learning_rate: 1.0000e-04
# Epoch 40/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9646 - loss: 0.8222
# Epoch 40: val_loss improved from 0.76712 to 0.76170, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9644 - loss: 0.8222 - val_accuracy: 0.9658 - val_loss: 0.7617 - learning_rate: 1.0000e-04
# Epoch 41/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9627 - loss: 0.8152
# Epoch 41: val_loss improved from 0.76170 to 0.75357, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9627 - loss: 0.8151 - val_accuracy: 0.9673 - val_loss: 0.7536 - learning_rate: 1.0000e-04
# Epoch 42/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9640 - loss: 0.8028
# Epoch 42: val_loss did not improve from 0.75357
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9639 - loss: 0.8028 - val_accuracy: 0.9613 - val_loss: 0.7645 - learning_rate: 1.0000e-04
# Epoch 43/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9627 - loss: 0.8061
# Epoch 43: val_loss improved from 0.75357 to 0.74263, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9627 - loss: 0.8061 - val_accuracy: 0.9702 - val_loss: 0.7426 - learning_rate: 1.0000e-04
# Epoch 44/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9671 - loss: 0.7895
# Epoch 44: val_loss improved from 0.74263 to 0.73891, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9671 - loss: 0.7896 - val_accuracy: 0.9762 - val_loss: 0.7389 - learning_rate: 1.0000e-04
# Epoch 45/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9699 - loss: 0.7944
# Epoch 45: val_loss improved from 0.73891 to 0.73106, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9698 - loss: 0.7943 - val_accuracy: 0.9732 - val_loss: 0.7311 - learning_rate: 1.0000e-04
# Epoch 46/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9702 - loss: 0.7878
# Epoch 46: val_loss improved from 0.73106 to 0.72947, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9702 - loss: 0.7878 - val_accuracy: 0.9688 - val_loss: 0.7295 - learning_rate: 1.0000e-04
# Epoch 47/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9727 - loss: 0.7772
# Epoch 47: val_loss improved from 0.72947 to 0.72331, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9727 - loss: 0.7772 - val_accuracy: 0.9688 - val_loss: 0.7233 - learning_rate: 1.0000e-04
# Epoch 48/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9714 - loss: 0.7695
# Epoch 48: val_loss improved from 0.72331 to 0.72218, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9713 - loss: 0.7695 - val_accuracy: 0.9673 - val_loss: 0.7222 - learning_rate: 1.0000e-04
# Epoch 49/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9710 - loss: 0.7642
# Epoch 49: val_loss improved from 0.72218 to 0.71751, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9710 - loss: 0.7642 - val_accuracy: 0.9732 - val_loss: 0.7175 - learning_rate: 1.0000e-04
# Epoch 50/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9663 - loss: 0.7644
# Epoch 50: val_loss improved from 0.71751 to 0.71570, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9664 - loss: 0.7643 - val_accuracy: 0.9673 - val_loss: 0.7157 - learning_rate: 1.0000e-04
# Epoch 51/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9810 - loss: 0.7466
# Epoch 51: val_loss improved from 0.71570 to 0.71094, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9810 - loss: 0.7467 - val_accuracy: 0.9762 - val_loss: 0.7109 - learning_rate: 1.0000e-04
# Epoch 52/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9798 - loss: 0.7462
# Epoch 52: val_loss improved from 0.71094 to 0.69789, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9798 - loss: 0.7462 - val_accuracy: 0.9747 - val_loss: 0.6979 - learning_rate: 1.0000e-04
# Epoch 53/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9762 - loss: 0.7498
# Epoch 53: val_loss did not improve from 0.69789
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9762 - loss: 0.7497 - val_accuracy: 0.9732 - val_loss: 0.7074 - learning_rate: 1.0000e-04
# Epoch 54/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9728 - loss: 0.7404
# Epoch 54: val_loss did not improve from 0.69789
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9728 - loss: 0.7404 - val_accuracy: 0.9717 - val_loss: 0.7010 - learning_rate: 1.0000e-04
# Epoch 55/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9687 - loss: 0.7503
# Epoch 55: val_loss did not improve from 0.69789
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9688 - loss: 0.7502 - val_accuracy: 0.9702 - val_loss: 0.7100 - learning_rate: 1.0000e-04
# Epoch 56/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9815 - loss: 0.7200
# Epoch 56: val_loss did not improve from 0.69789
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9814 - loss: 0.7203 - val_accuracy: 0.9673 - val_loss: 0.7050 - learning_rate: 1.0000e-04
# Epoch 57/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9820 - loss: 0.7224
# Epoch 57: val_loss did not improve from 0.69789
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9820 - loss: 0.7224 - val_accuracy: 0.9747 - val_loss: 0.7016 - learning_rate: 1.0000e-04
# Epoch 58/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9742 - loss: 0.7339
# Epoch 58: val_loss improved from 0.69789 to 0.68144, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9743 - loss: 0.7338 - val_accuracy: 0.9777 - val_loss: 0.6814 - learning_rate: 1.0000e-04
# Epoch 59/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9816 - loss: 0.7164
# Epoch 59: val_loss did not improve from 0.68144
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9816 - loss: 0.7165 - val_accuracy: 0.9762 - val_loss: 0.6883 - learning_rate: 1.0000e-04
# Epoch 60/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9876 - loss: 0.7102
# Epoch 60: val_loss did not improve from 0.68144
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9875 - loss: 0.7103 - val_accuracy: 0.9673 - val_loss: 0.7008 - learning_rate: 1.0000e-04
# Epoch 61/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9781 - loss: 0.7115
# Epoch 61: val_loss improved from 0.68144 to 0.67816, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9782 - loss: 0.7116 - val_accuracy: 0.9792 - val_loss: 0.6782 - learning_rate: 1.0000e-04
# Epoch 62/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9792 - loss: 0.7116
# Epoch 62: val_loss did not improve from 0.67816
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9792 - loss: 0.7116 - val_accuracy: 0.9777 - val_loss: 0.6794 - learning_rate: 1.0000e-04
# Epoch 63/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9826 - loss: 0.6961
# Epoch 63: val_loss improved from 0.67816 to 0.67437, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9826 - loss: 0.6962 - val_accuracy: 0.9777 - val_loss: 0.6744 - learning_rate: 1.0000e-04
# Epoch 64/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9843 - loss: 0.7048
# Epoch 64: val_loss did not improve from 0.67437
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9843 - loss: 0.7048 - val_accuracy: 0.9717 - val_loss: 0.6837 - learning_rate: 1.0000e-04
# Epoch 65/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9856 - loss: 0.7026
# Epoch 65: val_loss improved from 0.67437 to 0.66529, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9857 - loss: 0.7024 - val_accuracy: 0.9792 - val_loss: 0.6653 - learning_rate: 1.0000e-04
# Epoch 66/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9902 - loss: 0.6977
# Epoch 66: val_loss improved from 0.66529 to 0.66171, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9901 - loss: 0.6977 - val_accuracy: 0.9866 - val_loss: 0.6617 - learning_rate: 1.0000e-04
# Epoch 67/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9890 - loss: 0.6890
# Epoch 67: val_loss did not improve from 0.66171
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9890 - loss: 0.6890 - val_accuracy: 0.9807 - val_loss: 0.6658 - learning_rate: 1.0000e-04
# Epoch 68/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9899 - loss: 0.6840
# Epoch 68: val_loss improved from 0.66171 to 0.65472, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9899 - loss: 0.6841 - val_accuracy: 0.9836 - val_loss: 0.6547 - learning_rate: 1.0000e-04
# Epoch 69/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9902 - loss: 0.6819
# Epoch 69: val_loss did not improve from 0.65472
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9902 - loss: 0.6819 - val_accuracy: 0.9836 - val_loss: 0.6626 - learning_rate: 1.0000e-04
# Epoch 70/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9895 - loss: 0.6809
# Epoch 70: val_loss did not improve from 0.65472
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9895 - loss: 0.6810 - val_accuracy: 0.9777 - val_loss: 0.6578 - learning_rate: 1.0000e-04
# Epoch 71/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9933 - loss: 0.6758
# Epoch 71: val_loss did not improve from 0.65472
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9933 - loss: 0.6757 - val_accuracy: 0.9702 - val_loss: 0.6781 - learning_rate: 1.0000e-04
# Epoch 72/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9907 - loss: 0.6710
# Epoch 72: val_loss improved from 0.65472 to 0.65204, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9907 - loss: 0.6711 - val_accuracy: 0.9836 - val_loss: 0.6520 - learning_rate: 1.0000e-04
# Epoch 73/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9953 - loss: 0.6695
# Epoch 73: val_loss improved from 0.65204 to 0.64782, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9953 - loss: 0.6694 - val_accuracy: 0.9866 - val_loss: 0.6478 - learning_rate: 1.0000e-04
# Epoch 74/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9943 - loss: 0.6619
# Epoch 74: val_loss improved from 0.64782 to 0.64190, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9943 - loss: 0.6619 - val_accuracy: 0.9836 - val_loss: 0.6419 - learning_rate: 1.0000e-04
# Epoch 75/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9903 - loss: 0.6700
# Epoch 75: val_loss did not improve from 0.64190
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9903 - loss: 0.6698 - val_accuracy: 0.9762 - val_loss: 0.6540 - learning_rate: 1.0000e-04
# Epoch 76/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9938 - loss: 0.6578
# Epoch 76: val_loss did not improve from 0.64190
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9938 - loss: 0.6578 - val_accuracy: 0.9807 - val_loss: 0.6425 - learning_rate: 1.0000e-04
# Epoch 77/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9864 - loss: 0.6541
# Epoch 77: val_loss did not improve from 0.64190
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9864 - loss: 0.6542 - val_accuracy: 0.9807 - val_loss: 0.6435 - learning_rate: 1.0000e-04
# Epoch 78/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9947 - loss: 0.6581
# Epoch 78: val_loss did not improve from 0.64190
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9946 - loss: 0.6582 - val_accuracy: 0.9821 - val_loss: 0.6527 - learning_rate: 1.0000e-04
# Epoch 79/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9925 - loss: 0.6543
# Epoch 79: val_loss improved from 0.64190 to 0.63418, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9925 - loss: 0.6542 - val_accuracy: 0.9821 - val_loss: 0.6342 - learning_rate: 1.0000e-04
# Epoch 80/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9941 - loss: 0.6462
# Epoch 80: val_loss did not improve from 0.63418
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9941 - loss: 0.6462 - val_accuracy: 0.9821 - val_loss: 0.6343 - learning_rate: 1.0000e-04
# Epoch 81/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9958 - loss: 0.6436
# Epoch 81: val_loss improved from 0.63418 to 0.62976, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9958 - loss: 0.6437 - val_accuracy: 0.9777 - val_loss: 0.6298 - learning_rate: 1.0000e-04
# Epoch 82/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9914 - loss: 0.6495
# Epoch 82: val_loss did not improve from 0.62976
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9915 - loss: 0.6493 - val_accuracy: 0.9792 - val_loss: 0.6350 - learning_rate: 1.0000e-04
# Epoch 83/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9914 - loss: 0.6482
# Epoch 83: val_loss improved from 0.62976 to 0.62117, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9914 - loss: 0.6481 - val_accuracy: 0.9851 - val_loss: 0.6212 - learning_rate: 1.0000e-04
# Epoch 84/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9957 - loss: 0.6326
# Epoch 84: val_loss did not improve from 0.62117
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9956 - loss: 0.6326 - val_accuracy: 0.9747 - val_loss: 0.6311 - learning_rate: 1.0000e-04
# Epoch 85/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9973 - loss: 0.6342
# Epoch 85: val_loss did not improve from 0.62117
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9973 - loss: 0.6342 - val_accuracy: 0.9762 - val_loss: 0.6244 - learning_rate: 1.0000e-04
# Epoch 86/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9946 - loss: 0.6327
# Epoch 86: val_loss improved from 0.62117 to 0.61013, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9946 - loss: 0.6326 - val_accuracy: 0.9836 - val_loss: 0.6101 - learning_rate: 1.0000e-04
# Epoch 87/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9955 - loss: 0.6307
# Epoch 87: val_loss did not improve from 0.61013
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9955 - loss: 0.6306 - val_accuracy: 0.9777 - val_loss: 0.6231 - learning_rate: 1.0000e-04
# Epoch 88/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9966 - loss: 0.6218
# Epoch 88: val_loss did not improve from 0.61013
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9966 - loss: 0.6218 - val_accuracy: 0.9792 - val_loss: 0.6193 - learning_rate: 1.0000e-04
# Epoch 89/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9983 - loss: 0.6116
# Epoch 89: val_loss did not improve from 0.61013
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9983 - loss: 0.6116 - val_accuracy: 0.9836 - val_loss: 0.6173 - learning_rate: 1.0000e-04
# Epoch 90/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9953 - loss: 0.6169
# Epoch 90: val_loss did not improve from 0.61013
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9953 - loss: 0.6170 - val_accuracy: 0.9792 - val_loss: 0.6151 - learning_rate: 1.0000e-04
# Epoch 91/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9933 - loss: 0.6163
# Epoch 91: val_loss improved from 0.61013 to 0.60693, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9933 - loss: 0.6162 - val_accuracy: 0.9777 - val_loss: 0.6069 - learning_rate: 1.0000e-04
# Epoch 92/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9953 - loss: 0.6222
# Epoch 92: val_loss did not improve from 0.60693
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9953 - loss: 0.6221 - val_accuracy: 0.9762 - val_loss: 0.6086 - learning_rate: 1.0000e-04
# Epoch 93/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9969 - loss: 0.6079
# Epoch 93: val_loss improved from 0.60693 to 0.60223, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9969 - loss: 0.6079 - val_accuracy: 0.9821 - val_loss: 0.6022 - learning_rate: 1.0000e-04
# Epoch 94/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9988 - loss: 0.6004
# Epoch 94: val_loss did not improve from 0.60223
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9988 - loss: 0.6005 - val_accuracy: 0.9777 - val_loss: 0.6155 - learning_rate: 1.0000e-04
# Epoch 95/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9963 - loss: 0.6036
# Epoch 95: val_loss improved from 0.60223 to 0.59630, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9963 - loss: 0.6036 - val_accuracy: 0.9851 - val_loss: 0.5963 - learning_rate: 1.0000e-04
# Epoch 96/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9941 - loss: 0.6008
# Epoch 96: val_loss did not improve from 0.59630
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9942 - loss: 0.6008 - val_accuracy: 0.9762 - val_loss: 0.6005 - learning_rate: 1.0000e-04
# Epoch 97/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9951 - loss: 0.5974
# Epoch 97: val_loss did not improve from 0.59630
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9951 - loss: 0.5974 - val_accuracy: 0.9792 - val_loss: 0.6038 - learning_rate: 1.0000e-04
# Epoch 98/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9975 - loss: 0.5945
# Epoch 98: val_loss improved from 0.59630 to 0.59381, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9975 - loss: 0.5946 - val_accuracy: 0.9807 - val_loss: 0.5938 - learning_rate: 1.0000e-04
# Epoch 99/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9982 - loss: 0.5926
# Epoch 99: val_loss did not improve from 0.59381
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9982 - loss: 0.5926 - val_accuracy: 0.9807 - val_loss: 0.5959 - learning_rate: 1.0000e-04
# Epoch 100/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9988 - loss: 0.5918
# Epoch 100: val_loss improved from 0.59381 to 0.59322, saving model to best_cnn_2d_vesc.keras_fold_1.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9988 - loss: 0.5918 - val_accuracy: 0.9777 - val_loss: 0.5932 - learning_rate: 1.0000e-04
#
# Fold 1 - Evaluation on validation set:
#  - Loss: 0.5932
#  - Accuracy: 0.9777
#
# Training on fold 2/5...
# Train shape: (2688, 107, 157, 1), Val shape: (672, 107, 157, 1)
# Epoch 1/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9844 - loss: 0.6232
# Epoch 1: val_loss improved from inf to 0.53492, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.9844 - loss: 0.6232 - val_accuracy: 1.0000 - val_loss: 0.5349 - learning_rate: 1.0000e-04
# Epoch 2/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9968 - loss: 0.6005
# Epoch 2: val_loss improved from 0.53492 to 0.52759, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9968 - loss: 0.6005 - val_accuracy: 1.0000 - val_loss: 0.5276 - learning_rate: 1.0000e-04
# Epoch 3/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9967 - loss: 0.5990
# Epoch 3: val_loss did not improve from 0.52759
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9967 - loss: 0.5990 - val_accuracy: 1.0000 - val_loss: 0.5374 - learning_rate: 1.0000e-04
# Epoch 4/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9956 - loss: 0.5890
# Epoch 4: val_loss did not improve from 0.52759
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9956 - loss: 0.5889 - val_accuracy: 1.0000 - val_loss: 0.5294 - learning_rate: 1.0000e-04
# Epoch 5/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9957 - loss: 0.5965
# Epoch 5: val_loss did not improve from 0.52759
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9957 - loss: 0.5965 - val_accuracy: 1.0000 - val_loss: 0.5299 - learning_rate: 1.0000e-04
# Epoch 6/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9982 - loss: 0.5930
# Epoch 6: val_loss improved from 0.52759 to 0.52437, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9982 - loss: 0.5929 - val_accuracy: 1.0000 - val_loss: 0.5244 - learning_rate: 1.0000e-04
# Epoch 7/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9990 - loss: 0.5793
# Epoch 7: val_loss did not improve from 0.52437
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9990 - loss: 0.5793 - val_accuracy: 1.0000 - val_loss: 0.5246 - learning_rate: 1.0000e-04
# Epoch 8/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9947 - loss: 0.5869
# Epoch 8: val_loss did not improve from 0.52437
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9947 - loss: 0.5868 - val_accuracy: 1.0000 - val_loss: 0.5312 - learning_rate: 1.0000e-04
# Epoch 9/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9986 - loss: 0.5850
# Epoch 9: val_loss did not improve from 0.52437
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9986 - loss: 0.5850 - val_accuracy: 1.0000 - val_loss: 0.5293 - learning_rate: 1.0000e-04
# Epoch 10/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9971 - loss: 0.5793
# Epoch 10: val_loss did not improve from 0.52437
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9971 - loss: 0.5793 - val_accuracy: 1.0000 - val_loss: 0.5252 - learning_rate: 1.0000e-04
# Epoch 11/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9976 - loss: 0.5856
# Epoch 11: val_loss did not improve from 0.52437
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9976 - loss: 0.5855 - val_accuracy: 1.0000 - val_loss: 0.5295 - learning_rate: 1.0000e-04
# Epoch 12/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9960 - loss: 0.5833
# Epoch 12: val_loss improved from 0.52437 to 0.51863, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9960 - loss: 0.5832 - val_accuracy: 1.0000 - val_loss: 0.5186 - learning_rate: 1.0000e-04
# Epoch 13/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9981 - loss: 0.5755
# Epoch 13: val_loss improved from 0.51863 to 0.51816, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9981 - loss: 0.5755 - val_accuracy: 1.0000 - val_loss: 0.5182 - learning_rate: 1.0000e-04
# Epoch 14/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.5737
# Epoch 14: val_loss did not improve from 0.51816
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9996 - loss: 0.5737 - val_accuracy: 1.0000 - val_loss: 0.5244 - learning_rate: 1.0000e-04
# Epoch 15/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9986 - loss: 0.5705
# Epoch 15: val_loss improved from 0.51816 to 0.51620, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9986 - loss: 0.5705 - val_accuracy: 1.0000 - val_loss: 0.5162 - learning_rate: 1.0000e-04
# Epoch 16/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9990 - loss: 0.5658
# Epoch 16: val_loss did not improve from 0.51620
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9990 - loss: 0.5659 - val_accuracy: 1.0000 - val_loss: 0.5163 - learning_rate: 1.0000e-04
# Epoch 17/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9970 - loss: 0.5707
# Epoch 17: val_loss did not improve from 0.51620
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9970 - loss: 0.5707 - val_accuracy: 1.0000 - val_loss: 0.5182 - learning_rate: 1.0000e-04
# Epoch 18/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9981 - loss: 0.5701
# Epoch 18: val_loss improved from 0.51620 to 0.51516, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9982 - loss: 0.5701 - val_accuracy: 1.0000 - val_loss: 0.5152 - learning_rate: 1.0000e-04
# Epoch 19/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9993 - loss: 0.5673
# Epoch 19: val_loss improved from 0.51516 to 0.51211, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9993 - loss: 0.5672 - val_accuracy: 1.0000 - val_loss: 0.5121 - learning_rate: 1.0000e-04
# Epoch 20/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9980 - loss: 0.5628
# Epoch 20: val_loss did not improve from 0.51211
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9980 - loss: 0.5628 - val_accuracy: 1.0000 - val_loss: 0.5143 - learning_rate: 1.0000e-04
# Epoch 21/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9983 - loss: 0.5574
# Epoch 21: val_loss did not improve from 0.51211
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9983 - loss: 0.5574 - val_accuracy: 1.0000 - val_loss: 0.5213 - learning_rate: 1.0000e-04
# Epoch 22/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9984 - loss: 0.5618
# Epoch 22: val_loss improved from 0.51211 to 0.51166, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9984 - loss: 0.5618 - val_accuracy: 1.0000 - val_loss: 0.5117 - learning_rate: 1.0000e-04
# Epoch 23/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9973 - loss: 0.5579
# Epoch 23: val_loss improved from 0.51166 to 0.51107, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9973 - loss: 0.5579 - val_accuracy: 1.0000 - val_loss: 0.5111 - learning_rate: 1.0000e-04
# Epoch 24/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9997 - loss: 0.5561
# Epoch 24: val_loss improved from 0.51107 to 0.50982, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9997 - loss: 0.5561 - val_accuracy: 1.0000 - val_loss: 0.5098 - learning_rate: 1.0000e-04
# Epoch 25/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9992 - loss: 0.5516
# Epoch 25: val_loss did not improve from 0.50982
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9992 - loss: 0.5516 - val_accuracy: 1.0000 - val_loss: 0.5122 - learning_rate: 1.0000e-04
# Epoch 26/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.5526
# Epoch 26: val_loss did not improve from 0.50982
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9996 - loss: 0.5526 - val_accuracy: 1.0000 - val_loss: 0.5109 - learning_rate: 1.0000e-04
# Epoch 27/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.5548
# Epoch 27: val_loss did not improve from 0.50982
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9999 - loss: 0.5548 - val_accuracy: 0.9985 - val_loss: 0.5109 - learning_rate: 1.0000e-04
# Epoch 28/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9998 - loss: 0.5464
# Epoch 28: val_loss did not improve from 0.50982
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9998 - loss: 0.5464 - val_accuracy: 1.0000 - val_loss: 0.5145 - learning_rate: 1.0000e-04
# Epoch 29/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9997 - loss: 0.5493
# Epoch 29: val_loss improved from 0.50982 to 0.50658, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9997 - loss: 0.5493 - val_accuracy: 1.0000 - val_loss: 0.5066 - learning_rate: 1.0000e-04
# Epoch 30/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9997 - loss: 0.5468
# Epoch 30: val_loss improved from 0.50658 to 0.50559, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9997 - loss: 0.5468 - val_accuracy: 0.9985 - val_loss: 0.5056 - learning_rate: 1.0000e-04
# Epoch 31/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.5479
# Epoch 31: val_loss improved from 0.50559 to 0.50290, saving model to best_cnn_2d_vesc.keras_fold_2.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - loss: 0.5478 - val_accuracy: 1.0000 - val_loss: 0.5029 - learning_rate: 1.0000e-04
# Epoch 32/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9987 - loss: 0.5484
# Epoch 32: val_loss did not improve from 0.50290
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9987 - loss: 0.5483 - val_accuracy: 1.0000 - val_loss: 0.5060 - learning_rate: 1.0000e-04
# Epoch 33/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9962 - loss: 0.5484
# Epoch 33: val_loss did not improve from 0.50290
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9962 - loss: 0.5483 - val_accuracy: 1.0000 - val_loss: 0.5088 - learning_rate: 1.0000e-04
# Epoch 34/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9998 - loss: 0.5442
# Epoch 34: val_loss did not improve from 0.50290
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9998 - loss: 0.5443 - val_accuracy: 0.9970 - val_loss: 0.5098 - learning_rate: 1.0000e-04
# Epoch 35/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5480
# Epoch 35: val_loss did not improve from 0.50290
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5480 - val_accuracy: 0.9985 - val_loss: 0.5123 - learning_rate: 1.0000e-04
# Epoch 36/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5421
# Epoch 36: val_loss did not improve from 0.50290
# ...
# Epoch 52: val_loss did not improve from 0.42815
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4438 - val_accuracy: 1.0000 - val_loss: 0.4285 - learning_rate: 2.0000e-05
# Epoch 53/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4476
# Epoch 53: val_loss improved from 0.42815 to 0.42735, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.4475 - val_accuracy: 1.0000 - val_loss: 0.4274 - learning_rate: 2.0000e-05
# Epoch 54/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4422
# Epoch 54: val_loss did not improve from 0.42735
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4422 - val_accuracy: 1.0000 - val_loss: 0.4283 - learning_rate: 2.0000e-05
# Epoch 55/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4448
# Epoch 55: val_loss did not improve from 0.42735
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4448 - val_accuracy: 1.0000 - val_loss: 0.4284 - learning_rate: 2.0000e-05
# Epoch 56/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4446
# Epoch 56: val_loss did not improve from 0.42735
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4446 - val_accuracy: 1.0000 - val_loss: 0.4279 - learning_rate: 2.0000e-05
# Epoch 57/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4437
# Epoch 57: val_loss did not improve from 0.42735
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4437 - val_accuracy: 1.0000 - val_loss: 0.4281 - learning_rate: 2.0000e-05
# Epoch 58/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4440
# Epoch 58: val_loss improved from 0.42735 to 0.42666, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.4440 - val_accuracy: 1.0000 - val_loss: 0.4267 - learning_rate: 2.0000e-05
# Epoch 59/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4436
# Epoch 59: val_loss did not improve from 0.42666
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4436 - val_accuracy: 1.0000 - val_loss: 0.4290 - learning_rate: 2.0000e-05
# Epoch 60/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4464
# Epoch 60: val_loss improved from 0.42666 to 0.42632, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.4463 - val_accuracy: 1.0000 - val_loss: 0.4263 - learning_rate: 2.0000e-05
# Epoch 61/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4436
# Epoch 61: val_loss did not improve from 0.42632
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4436 - val_accuracy: 0.9985 - val_loss: 0.4269 - learning_rate: 2.0000e-05
# Epoch 62/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4427
# Epoch 62: val_loss did not improve from 0.42632
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4427 - val_accuracy: 1.0000 - val_loss: 0.4265 - learning_rate: 2.0000e-05
# Epoch 63/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4434
# Epoch 63: val_loss did not improve from 0.42632
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4434 - val_accuracy: 1.0000 - val_loss: 0.4275 - learning_rate: 2.0000e-05
# Epoch 64/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4445
# Epoch 64: val_loss did not improve from 0.42632
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4445 - val_accuracy: 1.0000 - val_loss: 0.4267 - learning_rate: 2.0000e-05
# Epoch 65/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4397
# Epoch 65: val_loss did not improve from 0.42632
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4398 - val_accuracy: 0.9985 - val_loss: 0.4277 - learning_rate: 2.0000e-05
# Epoch 66/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4445
# Epoch 66: val_loss improved from 0.42632 to 0.42494, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.4445 - val_accuracy: 0.9985 - val_loss: 0.4249 - learning_rate: 2.0000e-05
# Epoch 67/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4422
# Epoch 67: val_loss did not improve from 0.42494
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4421 - val_accuracy: 1.0000 - val_loss: 0.4270 - learning_rate: 2.0000e-05
# Epoch 68/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4410
# Epoch 68: val_loss did not improve from 0.42494
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4410 - val_accuracy: 1.0000 - val_loss: 0.4259 - learning_rate: 2.0000e-05
# Epoch 69/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4417
# Epoch 69: val_loss did not improve from 0.42494
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4417 - val_accuracy: 1.0000 - val_loss: 0.4262 - learning_rate: 2.0000e-05
# Epoch 70/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4404
# Epoch 70: val_loss did not improve from 0.42494
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4404 - val_accuracy: 1.0000 - val_loss: 0.4264 - learning_rate: 2.0000e-05
# Epoch 71/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4432
# Epoch 71: val_loss did not improve from 0.42494
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4432 - val_accuracy: 1.0000 - val_loss: 0.4257 - learning_rate: 2.0000e-05
# Epoch 72/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4394
# Epoch 72: val_loss did not improve from 0.42494
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4394 - val_accuracy: 0.9985 - val_loss: 0.4256 - learning_rate: 2.0000e-05
# Epoch 73/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4398
# Epoch 73: val_loss did not improve from 0.42494
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4398 - val_accuracy: 0.9985 - val_loss: 0.4260 - learning_rate: 2.0000e-05
# Epoch 74/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4400
# Epoch 74: val_loss improved from 0.42494 to 0.42457, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.4400 - val_accuracy: 1.0000 - val_loss: 0.4246 - learning_rate: 2.0000e-05
# Epoch 75/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4400
# Epoch 75: val_loss improved from 0.42457 to 0.42384, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.4400 - val_accuracy: 1.0000 - val_loss: 0.4238 - learning_rate: 2.0000e-05
# Epoch 76/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4385
# Epoch 76: val_loss did not improve from 0.42384
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4385 - val_accuracy: 1.0000 - val_loss: 0.4261 - learning_rate: 2.0000e-05
# Epoch 77/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4425
# Epoch 77: val_loss did not improve from 0.42384
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4424 - val_accuracy: 1.0000 - val_loss: 0.4241 - learning_rate: 2.0000e-05
# Epoch 78/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4401
# Epoch 78: val_loss did not improve from 0.42384
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4401 - val_accuracy: 1.0000 - val_loss: 0.4241 - learning_rate: 2.0000e-05
# Epoch 79/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4389
# Epoch 79: val_loss did not improve from 0.42384
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4389 - val_accuracy: 1.0000 - val_loss: 0.4240 - learning_rate: 2.0000e-05
# Epoch 80/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4381
# Epoch 80: val_loss did not improve from 0.42384
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4381 - val_accuracy: 1.0000 - val_loss: 0.4243 - learning_rate: 2.0000e-05
# Epoch 81/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4391
# Epoch 81: val_loss did not improve from 0.42384
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4391 - val_accuracy: 0.9985 - val_loss: 0.4256 - learning_rate: 2.0000e-05
# Epoch 82/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4380
# Epoch 82: val_loss improved from 0.42384 to 0.42370, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.4381 - val_accuracy: 0.9985 - val_loss: 0.4237 - learning_rate: 2.0000e-05
# Epoch 83/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4392
# Epoch 83: val_loss did not improve from 0.42370
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4392 - val_accuracy: 1.0000 - val_loss: 0.4262 - learning_rate: 2.0000e-05
# Epoch 84/100
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4367
# Epoch 84: val_loss improved from 0.42370 to 0.42341, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.4367 - val_accuracy: 1.0000 - val_loss: 0.4234 - learning_rate: 2.0000e-05
# Epoch 85/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4376
# Epoch 85: val_loss improved from 0.42341 to 0.42332, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.4376 - val_accuracy: 1.0000 - val_loss: 0.4233 - learning_rate: 2.0000e-05
# Epoch 86/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4378
# Epoch 86: val_loss improved from 0.42332 to 0.42230, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.4379 - val_accuracy: 1.0000 - val_loss: 0.4223 - learning_rate: 2.0000e-05
# Epoch 87/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4383
# Epoch 87: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4383 - val_accuracy: 1.0000 - val_loss: 0.4236 - learning_rate: 2.0000e-05
# Epoch 88/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4382
# Epoch 88: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4382 - val_accuracy: 1.0000 - val_loss: 0.4236 - learning_rate: 2.0000e-05
# Epoch 89/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4387
# Epoch 89: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4387 - val_accuracy: 0.9985 - val_loss: 0.4230 - learning_rate: 2.0000e-05
# Epoch 90/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4374
# Epoch 90: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4374 - val_accuracy: 0.9985 - val_loss: 0.4239 - learning_rate: 2.0000e-05
# Epoch 91/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4394
# Epoch 91: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4393 - val_accuracy: 0.9985 - val_loss: 0.4235 - learning_rate: 2.0000e-05
# Epoch 92/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4365
# Epoch 92: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4365 - val_accuracy: 0.9985 - val_loss: 0.4228 - learning_rate: 2.0000e-05
# Epoch 93/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4369
# Epoch 93: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4369 - val_accuracy: 0.9985 - val_loss: 0.4235 - learning_rate: 2.0000e-05
# Epoch 94/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4376
# Epoch 94: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4376 - val_accuracy: 1.0000 - val_loss: 0.4230 - learning_rate: 2.0000e-05
# Epoch 95/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4386
# Epoch 95: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.4386 - val_accuracy: 0.9985 - val_loss: 0.4226 - learning_rate: 2.0000e-05
# Epoch 96/100
# 164/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4348
# Epoch 96: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4348 - val_accuracy: 1.0000 - val_loss: 0.4236 - learning_rate: 2.0000e-05
# Epoch 97/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4359
# Epoch 97: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4359 - val_accuracy: 0.9985 - val_loss: 0.4228 - learning_rate: 1.0000e-05
# Epoch 98/100
# 166/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4348
# Epoch 98: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4348 - val_accuracy: 1.0000 - val_loss: 0.4224 - learning_rate: 1.0000e-05
# Epoch 99/100
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.4370
# Epoch 99: val_loss did not improve from 0.42230
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.4369 - val_accuracy: 1.0000 - val_loss: 0.4230 - learning_rate: 1.0000e-05
# Epoch 100/100
# 165/168 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.4359
# Epoch 100: val_loss improved from 0.42230 to 0.42123, saving model to best_cnn_2d_vesc.keras_fold_5.h5
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 0.4359 - val_accuracy: 0.9985 - val_loss: 0.4212 - learning_rate: 1.0000e-05
#
# Fold 5 - Evaluation on validation set:
#  - Loss: 0.4212
#  - Accuracy: 0.9985
#
# Average results across 5 folds:
#  - Average Loss: 0.4721
#  - Average Accuracy: 0.9943
#
# Sample prediction probabilities:
# Sample 1: True=Angry, Pred=Angry, Prob=[0.93714565 0.01117994 0.01838782 0.01947067 0.01381592]
# Sample 2: True=Angry, Pred=Angry, Prob=[0.89568454 0.0252771  0.02422191 0.02822628 0.02659007]
# Sample 3: True=Angry, Pred=Angry, Prob=[0.9368649  0.01213145 0.01458353 0.01921518 0.01720488]
# Sample 4: True=Angry, Pred=Angry, Prob=[0.8034969  0.04968053 0.04627863 0.0299836  0.07056027]
# Sample 5: True=Angry, Pred=Angry, Prob=[0.96313286 0.00808179 0.01177567 0.00948001 0.00752969]
# Classification Report:
#               precision    recall  f1-score   support
#
#        Angry       1.00      1.00      1.00       131
#        Happy       1.00      1.00      1.00       129
#      Anxiety       1.00      0.99      1.00       108
#      Neutral       1.00      1.00      1.00       174
#          Sad       0.99      1.00      1.00       130
#
#     accuracy                           1.00       672
#    macro avg       1.00      1.00      1.00       672
# weighted avg       1.00      1.00      1.00       672
#
#
# Evaluation metric formulas:
# 1. Precision = TP / (TP + FP)
#    - TP (True Positives): Number of samples correctly predicted for a class.
#    - FP (False Positives): Number of samples incorrectly predicted as that class.
# 2. Recall = TP / (TP + FN)
#    - FN (False Negatives): Number of samples that belong to the class but were incorrectly predicted.
# 3. F1 Score = 2 * (Precision * Recall) / (Precision + Recall)

# %% [markdown]
# Test Part

# %%
    best_model = tf.keras.models.load_model('final_cnn_2d_vesc.keras')
    best_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                       loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                       metrics=['accuracy'])

    # Prepare test data
    root_folder_test = "/kaggle/input/speech-emotion-10/VESC_test/VESC_test"
    folders_test = [f for f in glob(os.path.join(root_folder_test, "*")) if os.path.isdir(f)]
    all_files_test = []
    for folder in folders_test:
        files = glob(os.path.join(folder, "**", "*.wav"), recursive=True)
        all_files_test.extend(files)
        print(f"Found {len(files)} files in folder: {os.path.basename(folder)}")

    if not all_files_test:
        raise ValueError("No audio files found in the test directory.")

    print(f"Total test files: {len(all_files_test)}")

    y_raw_test = [emotion_map.get(os.path.basename(os.path.dirname(f)), -1) for f in all_files_test]
    print("Original label distribution (test):", Counter([EMOTIONS[i] for i in y_raw_test if i != -1]))
    print(f"GLOBAL_MEAN_PITCH: {GLOBAL_MEAN_PITCH:.4f}, GLOBAL_JITTER: {GLOBAL_JITTER:.4f}, GLOBAL_PITCH_SLOPE: {GLOBAL_PITCH_SLOPE:.4f}")
    X_test, y_test = prepare_test_data(all_files_test, emotion_map, (GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE))

    # Normalize features for the test set
    X_test_2d = X_test.reshape(X_test.shape[0], -1)
    X_test_2d = scaler.transform(X_test_2d)
    X_test = X_test_2d.reshape(X_test.shape)

    evaluate_model(best_model, X_test, y_test)

    print("\nPredictions on test files:")
    for test_path in all_files_test:
        predicted_emotion = predict_emotion(test_path, best_model, scaler, (GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE))
        print(f"Predicted emotion for {os.path.basename(test_path)} (best model): {predicted_emotion}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 22 variables whereas the saved optimizer has 42 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Found 37 files in folder: Angry
# Found 32 files in folder: Neutral
# Found 20 files in folder: Anxiety
# Found 99 files in folder: Sad
# Found 44 files in folder: Happy
# Total test files: 232
# Original label distribution (test): Counter({'Sad': 99, 'Happy': 44, 'Angry': 37, 'Neutral': 32, 'Anxiety': 20})
# GLOBAL_MEAN_PITCH: 1314.3724, GLOBAL_JITTER: 1039.1417, GLOBAL_PITCH_SLOPE: 0.0000
# Total number of test audio files: 232
# Processed: 232 samples, skipped: 0 files.
# Test dataset shape: X=(232, 107, 157, 1), y=(232, 5)
#
# Sample prediction probabilities:
# Sample 1: True=Angry, Pred=Angry, Prob=[0.83870494 0.03648647 0.04995855 0.04516743 0.02968271]
# Sample 2: True=Angry, Pred=Angry, Prob=[0.7263329  0.07505246 0.0517465  0.07603867 0.07082954]
# Sample 3: True=Angry, Pred=Angry, Prob=[0.7962067  0.06502307 0.07686011 0.03525641 0.02665375]
# Sample 4: True=Angry, Pred=Angry, Prob=[0.9658066  0.01079701 0.00596074 0.00890085 0.0085348 ]
# Sample 5: True=Angry, Pred=Angry, Prob=[0.94120276 0.01241279 0.01686707 0.01643733 0.01308008]
# Classification Report:
#               precision    recall  f1-score   support
#
#        Angry       0.97      0.97      0.97        37
#        Happy       0.93      0.91      0.92        44
#      Anxiety       0.84      0.80      0.82        20
#      Neutral       1.00      1.00      1.00        32
#          Sad       0.95      0.97      0.96        99
#
#     accuracy                           0.95       232
#    macro avg       0.94      0.93      0.93       232
# weighted avg       0.95      0.95      0.95       232
#
#
# Evaluation metric formulas:
# 1. Precision = TP / (TP + FP)
#    - TP (True Positives): Number of samples correctly predicted for a class.
#    - FP (False Positives): Number of samples incorrectly predicted as that class.
# 2. Recall = TP / (TP + FN)
#    - FN (False Negatives): Number of samples that belong to the class but were incorrectly predicted.
# 3. F1 Score = 2 * (Precision * Recall) / (Precision + Recall)
#
# Predictions on test files:
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p02_M2_12147_12151.wav: [0.83870494 0.03648647 0.04995854 0.04516741 0.02968269]
# Predicted emotion for angry_p02_M2_12147_12151.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p02_M3_11533_11539.wav: [0.7263327  0.07505246 0.05174651 0.07603868 0.07082954]
# Predicted emotion for angry_p02_M3_11533_11539.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2616_2622.wav: [0.7962067  0.06502306 0.07686011 0.03525641 0.02665376]
# Predicted emotion for angry_p06_F10_2616_2622.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p03_t4_F4_4547_4552.wav: [0.9658066  0.01079701 0.00596075 0.00890085 0.0085348 ]
# Predicted emotion for angry_p03_t4_F4_4547_4552.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2743_2747.wav: [0.94120276 0.01241279 0.01686707 0.01643733 0.01308008]
# Predicted emotion for angry_p06_F10_2743_2747.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_F1_2433_2436.wav: [0.8922524  0.03261324 0.03091888 0.02411118 0.02010436]
# Predicted emotion for angry_p01_F1_2433_2436.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F7_12809_12811.wav: [0.25531015 0.5627893  0.0791535  0.04931341 0.05343361]
# Predicted emotion for angry_p04_F7_12809_12811.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_322_328.wav: [0.85110825 0.03526049 0.03047059 0.03423158 0.04892911]
# Predicted emotion for angry_p01_M2_322_328.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_2634_2629.wav: [0.92602956 0.01666808 0.02214519 0.01782145 0.01733576]
# Predicted emotion for angry_p01_M2_2634_2629.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p03_t4_F4_1340_1350.wav: [0.86190856 0.03210668 0.02962658 0.03615084 0.04020731]
# Predicted emotion for angry_p03_t4_F4_1340_1350.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p03_t11_M5_1325_1332.wav: [0.49360538 0.05615151 0.0866143  0.30341005 0.06021879]
# Predicted emotion for angry_p03_t11_M5_1325_1332.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_F1_2639_2622.wav: [0.95073265 0.01762519 0.0081851  0.01491022 0.00854691]
# Predicted emotion for angry_p01_F1_2639_2622.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F9_4125_4130.wav: [0.916816   0.02281226 0.01791723 0.02238443 0.02007003]
# Predicted emotion for angry_p06_F9_4125_4130.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p02_M2_12026_12029.wav: [0.8990667  0.02365667 0.01844593 0.02494142 0.03388925]
# Predicted emotion for angry_p02_M2_12026_12029.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2652_2657.wav: [0.91985244 0.01809276 0.01557929 0.02409162 0.02238383]
# Predicted emotion for angry_p06_F10_2652_2657.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F7_12835_12837.wav: [0.73105556 0.12377638 0.050818   0.05345586 0.04089426]
# Predicted emotion for angry_p04_F7_12835_12837.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_M20_4257_4304.wav: [0.6295762  0.10024853 0.07052325 0.08304315 0.11660883]
# Predicted emotion for angry_p06_M20_4257_4304.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_M20_3004_3008.wav: [0.8366821  0.06034625 0.02896258 0.03775919 0.03624994]
# Predicted emotion for angry_p06_M20_3004_3008.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F8_152_154.wav: [0.8710613  0.04423698 0.02638539 0.02907153 0.02924481]
# Predicted emotion for angry_p04_F8_152_154.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_M17_10415_10420_vocals.wav: [0.8723677  0.04214422 0.0310233  0.02856571 0.02589914]
# Predicted emotion for angry_p04_M17_10415_10420_vocals.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F8_2523_2526.wav: [0.7470658  0.12089928 0.03956319 0.04827848 0.04419326]
# Predicted emotion for angry_p04_F8_2523_2526.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F8_5042_5046.wav: [0.34294885 0.2306277  0.28865713 0.10153978 0.03622658]
# Predicted emotion for angry_p04_F8_5042_5046.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p03_t11_M5_1049_1056.wav: [0.75102204 0.04338146 0.02555565 0.13259913 0.04744175]
# Predicted emotion for angry_p03_t11_M5_1049_1056.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_3034_3037.wav: [0.8432362  0.03763955 0.05185966 0.03968713 0.02757745]
# Predicted emotion for angry_p01_M2_3034_3037.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p02_M1_4754_4756.wav: [0.87786007 0.0324388  0.01927109 0.03619688 0.03423312]
# Predicted emotion for angry_p02_M1_4754_4756.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_322_328_vocals.wav: [0.8535866  0.02726205 0.0332211  0.03162847 0.05430184]
# Predicted emotion for angry_p01_M2_322_328_vocals.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_M17_10350_10400_vocals.wav: [0.7235689  0.06876378 0.04492382 0.0670894  0.09565409]
# Predicted emotion for angry_p04_M17_10350_10400_vocals.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p02_M3_11614_11617.wav: [0.83443594 0.05694918 0.04220264 0.03451389 0.03189835]
# Predicted emotion for angry_p02_M3_11614_11617.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p03_t11_M5_1301_1308.wav: [0.96781856 0.00426576 0.00985917 0.00810022 0.00995626]
# Predicted emotion for angry_p03_t11_M5_1301_1308.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2634_2637_vocals.wav: [0.877082   0.02403043 0.03848179 0.03371351 0.02669227]
# Predicted emotion for angry_p06_F10_2634_2637_vocals.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_3011_3016.wav: [0.9436928  0.01703891 0.01525954 0.01416598 0.00984284]
# Predicted emotion for angry_p06_F10_3011_3016.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_2620_2625.wav: [0.9380839  0.01536443 0.01420181 0.01640364 0.01594618]
# Predicted emotion for angry_p01_M2_2620_2625.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_4225_4231.wav: [0.9577075  0.011541   0.00924418 0.01218606 0.00932136]
# Predicted emotion for angry_p06_F10_4225_4231.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2737_2741.wav: [0.94698477 0.01838961 0.0079034  0.01441421 0.0123081 ]
# Predicted emotion for angry_p06_F10_2737_2741.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p04_F7_12820_12822.wav: [0.56658095 0.2793455  0.05177724 0.06443184 0.03786447]
# Predicted emotion for angry_p04_F7_12820_12822.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p06_F10_2817_2820.wav: [0.9510897  0.01178443 0.01272315 0.01434891 0.01005388]
# Predicted emotion for angry_p06_F10_2817_2820.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Angry/angry_p01_M2_2230_2235.wav: [0.73577964 0.04266677 0.10078578 0.07345422 0.04731357]
# Predicted emotion for angry_p01_M2_2230_2235.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F35_3033_3038.wav: [0.03355391 0.02893848 0.03158552 0.87673265 0.02918933]
# Predicted emotion for neutral_p12_F35_3033_3038.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M31_2615_2620.wav: [0.04237717 0.02547969 0.02631404 0.8648159  0.04101317]
# Predicted emotion for neutral_p12_M31_2615_2620.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F34_26552657.wav: [0.04528631 0.04625387 0.03862796 0.82509726 0.04473456]
# Predicted emotion for neutral_p12_F34_26552657.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_2907_2910.wav: [0.01239717 0.01453437 0.01683077 0.94642234 0.00981532]
# Predicted emotion for neutral_p12_M30_2907_2910.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3236_3239.wav: [0.04793022 0.03142887 0.06348354 0.8166409  0.04051645]
# Predicted emotion for neutral_p12_M30_3236_3239.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3253_3256.wav: [0.01203229 0.01174811 0.01485222 0.95042545 0.01094195]
# Predicted emotion for neutral_p12_M30_3253_3256.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F36_3133_3137.wav: [0.04356483 0.05918923 0.0524136  0.79616684 0.04866553]
# Predicted emotion for neutral_p12_F36_3133_3137.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3230_3233.wav: [0.01406619 0.01533138 0.01471667 0.94286543 0.01302031]
# Predicted emotion for neutral_p12_M30_3230_3233.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3147_3151.wav: [0.01800625 0.02230168 0.03508782 0.8911059  0.03349835]
# Predicted emotion for neutral_p12_M30_3147_3151.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M31_2620_2624.wav: [0.04657767 0.04695649 0.04085201 0.8226587  0.04295506]
# Predicted emotion for neutral_p12_M31_2620_2624.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_2910_2914.wav: [0.01236688 0.01115063 0.01106044 0.9535322  0.01188991]
# Predicted emotion for neutral_p12_M30_2910_2914.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_2914_2919.wav: [0.02572875 0.02351822 0.02755265 0.89358294 0.02961747]
# Predicted emotion for neutral_p12_M30_2914_2919.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3248_3251.wav: [0.02915546 0.02503313 0.02779434 0.8890509  0.02896611]
# Predicted emotion for neutral_p12_M30_3248_3251.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F35_3028_3032.wav: [0.02011821 0.02175389 0.02084985 0.9197742  0.01750398]
# Predicted emotion for neutral_p12_F35_3028_3032.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3152_3155.wav: [0.02966886 0.02482494 0.03984538 0.8806758  0.02498496]
# Predicted emotion for neutral_p12_M30_3152_3155.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M31_2607_2610.wav: [0.02207102 0.0197862  0.02463214 0.91406465 0.01944597]
# Predicted emotion for neutral_p12_M31_2607_2610.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3233_3235.wav: [0.08457802 0.06342202 0.04522572 0.74450725 0.06226702]
# Predicted emotion for neutral_p12_M30_3233_3235.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3144_3147.wav: [0.01501483 0.02072307 0.02558778 0.921397   0.0172774 ]
# Predicted emotion for neutral_p12_M30_3144_3147.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_719_722.wav: [0.02663429 0.0215479  0.01592419 0.9153837  0.02050994]
# Predicted emotion for neutral_p12_M30_719_722.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F34_2819_2822.wav: [0.0108199  0.00932138 0.00720341 0.9645881  0.00806721]
# Predicted emotion for neutral_p12_F34_2819_2822.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M31_1457_1500.wav: [0.05602768 0.07403802 0.05435827 0.7365203  0.07905567]
# Predicted emotion for neutral_p12_M31_1457_1500.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3222_3227.wav: [0.03424981 0.03572579 0.05083787 0.8225707  0.05661576]
# Predicted emotion for neutral_p12_M30_3222_3227.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3227_3229.wav: [0.01572158 0.01590762 0.01924594 0.93669057 0.01243435]
# Predicted emotion for neutral_p12_M30_3227_3229.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F34_2825_2828.wav: [0.05460316 0.05428124 0.05666136 0.79864615 0.03580808]
# Predicted emotion for neutral_p12_F34_2825_2828.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F37_1449_1453.wav: [0.02273435 0.0217578  0.01716215 0.91260463 0.025741  ]
# Predicted emotion for neutral_p12_F37_1449_1453.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3250_3252.wav: [0.02333442 0.02437142 0.02400869 0.9030678  0.02521769]
# Predicted emotion for neutral_p12_M30_3250_3252.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M31_2610_2614.wav: [0.03510759 0.0447406  0.04248956 0.8344512  0.04321106]
# Predicted emotion for neutral_p12_M31_2610_2614.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_3240_3242.wav: [0.03161664 0.09344364 0.37132022 0.4085553  0.09506414]
# Predicted emotion for neutral_p12_M30_3240_3242.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_714_718.wav: [0.04951219 0.05832471 0.04223255 0.76234514 0.08758536]
# Predicted emotion for neutral_p12_M30_714_718.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_2903_2906.wav: [0.01567841 0.01462024 0.01488418 0.9434335  0.01138374]
# Predicted emotion for neutral_p12_M30_2903_2906.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_F34_2820_2824.wav: [0.01474566 0.01330186 0.0129941  0.94698125 0.01197718]
# Predicted emotion for neutral_p12_F34_2820_2824.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Neutral/neutral_p12_M30_2901_2903.wav: [0.04729744 0.05001739 0.04250103 0.79777527 0.0624088 ]
# Predicted emotion for neutral_p12_M30_2901_2903.wav (best model): Neutral
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p09_M25_2459_2505.wav: [0.02551934 0.04853093 0.7856963  0.04530261 0.09495084]
# Predicted emotion for anxiety_p09_M25_2459_2505.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p03_F12_4635_4639_vocals.wav: [0.01805234 0.01896578 0.92925274 0.01847053 0.01525866]
# Predicted emotion for anxiety_p03_F12_4635_4639_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p02_F3_10129_10132.wav: [0.06419954 0.21374238 0.55633765 0.06514375 0.10057668]
# Predicted emotion for anxiety_p02_F3_10129_10132.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p03_t2_F14_4730_4731_vocals.wav: [0.01539172 0.0169021  0.9314127  0.0201858  0.01610768]
# Predicted emotion for anxiety_p03_t2_F14_4730_4731_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F7_5326_5233.wav: [0.0732887  0.13096747 0.3107232  0.05160858 0.43341205]
# Predicted emotion for anxiety_p04_F7_5326_5233.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p03_t2_M16_4723_4726_vocals.wav: [0.01973017 0.02929307 0.89203453 0.02281449 0.03612775]
# Predicted emotion for anxiety_p03_t2_M16_4723_4726_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F7_3259_3303.wav: [0.04322315 0.23569244 0.558811   0.06917378 0.09309956]
# Predicted emotion for anxiety_p04_F7_3259_3303.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p03_t3_M14_457_502_vocals.wav: [0.02345417 0.03988581 0.8652875  0.03852636 0.03284626]
# Predicted emotion for anxiety_p03_t3_M14_457_502_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F8_4154_4157.wav: [0.01205071 0.02443491 0.93326086 0.01481947 0.01543395]
# Predicted emotion for anxiety_p04_F8_4154_4157.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p03_M6_3137_3139_vocals.wav: [0.01465471 0.01868698 0.93719006 0.01647177 0.01299653]
# Predicted emotion for anxiety_p03_M6_3137_3139_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/auxiety_p07_F24_13005_13011_vocals.wav: [0.05863217 0.06702488 0.30634847 0.08761305 0.48038143]
# Predicted emotion for auxiety_p07_F24_13005_13011_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p06_F18_1624_1632_vocals.wav: [0.3794602  0.12877014 0.36907896 0.08055184 0.04213879]
# Predicted emotion for anxiety_p06_F18_1624_1632_vocals.wav (best model): Angry
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/auxiety_p07_F24_12923_12929.wav: [0.06950449 0.05970307 0.4950057  0.05264482 0.323142  ]
# Predicted emotion for auxiety_p07_F24_12923_12929.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p06_F9_2550_2553.wav: [0.11557847 0.09691305 0.6004334  0.13391317 0.05316192]
# Predicted emotion for anxiety_p06_F9_2550_2553.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_M17_3054_3058.wav: [0.0210939  0.0330642  0.88139546 0.03100882 0.03343762]
# Predicted emotion for anxiety_p04_M17_3054_3058.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F8_4150_4154_vocals.wav: [0.02111373 0.02776655 0.9127661  0.02117168 0.01718197]
# Predicted emotion for anxiety_p04_F8_4150_4154_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F7_2420_2422.wav: [0.0120412  0.018221   0.945517   0.01372277 0.01049798]
# Predicted emotion for anxiety_p04_F7_2420_2422.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p06_F18_3315_3320_vocals.wav: [0.23954712 0.07707064 0.29160574 0.09431715 0.2974594 ]
# Predicted emotion for anxiety_p06_F18_3315_3320_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F7_2214_2216.wav: [0.09693746 0.22195204 0.551347   0.0603474  0.06941614]
# Predicted emotion for anxiety_p04_F7_2214_2216.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Anxiety/anxiety_p04_F15_12316_12320.wav: [0.02860484 0.17280315 0.68209857 0.04344121 0.07305229]
# Predicted emotion for anxiety_p04_F15_12316_12320.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_3232_3237.wav: [0.05211549 0.03515859 0.12486444 0.04654488 0.74131656]
# Predicted emotion for sad_p06_F9_3232_3237.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_1918_1925.wav: [0.05046141 0.04087061 0.03797731 0.03849115 0.8321995 ]
# Predicted emotion for sad_p06_F9_1918_1925.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_2728_2733.wav: [0.02730338 0.03741048 0.02182295 0.02465221 0.888811  ]
# Predicted emotion for sad_p06_F9_2728_2733.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_13223_13236.wav: [0.07646311 0.2083614  0.0972046  0.11882602 0.49914482]
# Predicted emotion for sad_p07_M19_13223_13236.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F17_13405_13413.wav: [0.0142082  0.00980175 0.01015575 0.01278848 0.9530458 ]
# Predicted emotion for sad_p07_F17_13405_13413.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F17_13320_13328.wav: [0.09825586 0.06620353 0.04032487 0.04977821 0.74543756]
# Predicted emotion for sad_p07_F17_13320_13328.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1629_1635.wav: [0.01325839 0.01810994 0.00994375 0.01224628 0.9464417 ]
# Predicted emotion for sad_p09_F21_1629_1635.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F29_331_335_vocals.wav: [0.04822555 0.06172545 0.02424638 0.02785178 0.83795077]
# Predicted emotion for sad_p10_F29_331_335_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F17_5132_5140.wav: [0.01260128 0.02387734 0.01293246 0.0168663  0.9337226 ]
# Predicted emotion for sad_p07_F17_5132_5140.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p04_F8_13806_13810.wav: [0.02653318 0.12498084 0.04804642 0.03150133 0.76893824]
# Predicted emotion for sad_p04_F8_13806_13810.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_5048_5055.wav: [0.02328614 0.03941865 0.02662513 0.03809049 0.87257963]
# Predicted emotion for sad_p07_M19_5048_5055.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_2308_2311.wav: [0.02342015 0.02522801 0.02587993 0.02579497 0.899677  ]
# Predicted emotion for sad_p07_M19_2308_2311.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F19_1831_1836_vocals.wav: [0.02269268 0.01309933 0.01257679 0.01257377 0.93905747]
# Predicted emotion for sad_p09_F19_1831_1836_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_2628_2633.wav: [0.11291735 0.07398295 0.14211574 0.23245762 0.4385264 ]
# Predicted emotion for sad_p06_F9_2628_2633.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_12429_12436.wav: [0.03633914 0.02360475 0.01977471 0.02339187 0.89688957]
# Predicted emotion for sad_p07_M19_12429_12436.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_2329_2333.wav: [0.01650577 0.02072146 0.02663921 0.02407368 0.9120599 ]
# Predicted emotion for sad_p07_F33_2329_2333.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F43_11712_11717.wav: [0.07658111 0.05025892 0.03662342 0.0352185  0.8013181 ]
# Predicted emotion for sad_p07_F43_11712_11717.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_336_341_vocals.wav: [0.02476604 0.02563137 0.02251402 0.02610709 0.9009815 ]
# Predicted emotion for sad_p10_F28_336_341_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F29_428_434_vocals.wav: [0.05989598 0.10291398 0.09297498 0.09514892 0.64906615]
# Predicted emotion for sad_p10_F29_428_434_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_258_204_vocals.wav: [0.05492151 0.08273479 0.04663235 0.05081514 0.7648963 ]
# Predicted emotion for sad_p10_F28_258_204_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_2607_2611.wav: [0.09592619 0.09656894 0.06581996 0.08220623 0.65947866]
# Predicted emotion for sad_p06_F9_2607_2611.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_M25_2507_2511_vocals.wav: [0.02811974 0.02920046 0.03956582 0.02643586 0.87667805]
# Predicted emotion for sad_p09_M25_2507_2511_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12409_12412_vocals.wav: [0.0145723  0.01423174 0.01966795 0.01661435 0.93491364]
# Predicted emotion for sad_p07_F33_12409_12412_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M2_12015_12023.wav: [0.02348124 0.09114129 0.04774788 0.04426874 0.7933608 ]
# Predicted emotion for sad_p02_M2_12015_12023.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_1052_1057.wav: [0.02341069 0.01932288 0.02225967 0.01991611 0.9150907 ]
# Predicted emotion for sad_p07_M19_1052_1057.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1552_1558_vocals.wav: [0.01783841 0.02009072 0.0169591  0.01885825 0.92625356]
# Predicted emotion for sad_p09_F21_1552_1558_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_3227_3230.wav: [0.01694318 0.01779353 0.0181726  0.01727395 0.9298168 ]
# Predicted emotion for sad_p07_M19_3227_3230.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3909_3917_vocals.wav: [0.06011492 0.22271734 0.1926177  0.07901563 0.44553444]
# Predicted emotion for sad_p10_F28_3909_3917_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p04_F8_13745_13749.wav: [0.03761335 0.47709507 0.05045939 0.03231308 0.40251923]
# Predicted emotion for sad_p04_F8_13745_13749.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_F1_2611_2615.wav: [0.05937276 0.03691252 0.03009476 0.04330233 0.8303177 ]
# Predicted emotion for sad_p01_F1_2611_2615.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1638_1644.wav: [0.01185482 0.01336129 0.01543126 0.01382158 0.9455311 ]
# Predicted emotion for sad_p09_F21_1638_1644.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3401_3410_vocals.wav: [0.02301186 0.02394057 0.02527408 0.02454217 0.9032313 ]
# Predicted emotion for sad_p10_F28_3401_3410_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F22_2140_2144.wav: [0.10645606 0.04486648 0.5023374  0.08625849 0.26008147]
# Predicted emotion for sad_p09_F22_2140_2144.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_F38_2811_2816.wav: [0.01584807 0.01856712 0.01870151 0.01892426 0.9279591 ]
# Predicted emotion for sad_p01_F38_2811_2816.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_F2_5705_5712.wav: [0.03909051 0.03030058 0.02917353 0.02215741 0.87927794]
# Predicted emotion for sad_p02_F2_5705_5712.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F44_12540_12544.wav: [0.03177677 0.04925235 0.0500964  0.03624022 0.83263427]
# Predicted emotion for sad_p07_F44_12540_12544.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3744_3750_vocals.wav: [0.06921617 0.05292467 0.05707674 0.05309501 0.76768744]
# Predicted emotion for sad_p10_F28_3744_3750_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_2406_2412_vocals.wav: [0.01425228 0.00972672 0.01040311 0.01031511 0.9553028 ]
# Predicted emotion for sad_p09_F21_2406_2412_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_406_413.wav: [0.0424047  0.0613953  0.03554943 0.04162857 0.81902206]
# Predicted emotion for sad_p06_F9_406_413.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_M32_806_809_vocals.wav: [0.05183732 0.02563235 0.06419853 0.02583547 0.83249635]
# Predicted emotion for sad_p09_M32_806_809_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_2530_2536.wav: [0.02404406 0.03743086 0.07795984 0.04586519 0.81470007]
# Predicted emotion for sad_p07_M19_2530_2536.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_1715_1722.wav: [0.0394196  0.03756233 0.04848048 0.03727309 0.8372645 ]
# Predicted emotion for sad_p07_M19_1715_1722.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_3320_3327_vocals.wav: [0.01555093 0.01459838 0.02314822 0.01654909 0.9301534 ]
# Predicted emotion for sad_p09_F21_3320_3327_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M1_12031_12036.wav: [0.03324863 0.03549645 0.02997899 0.02693813 0.87433773]
# Predicted emotion for sad_p02_M1_12031_12036.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12253_12300.wav: [0.01820024 0.02378612 0.0216906  0.02331819 0.9130048 ]
# Predicted emotion for sad_p07_F33_12253_12300.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_12417_12421.wav: [0.01659344 0.02769239 0.01611251 0.01989289 0.9197088 ]
# Predicted emotion for sad_p07_M19_12417_12421.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F29_402_406_vocals.wav: [0.07018472 0.06384291 0.03687152 0.06055478 0.76854604]
# Predicted emotion for sad_p10_F29_402_406_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_414_417_vocals.wav: [0.02254206 0.04734733 0.040564   0.02627407 0.8632725 ]
# Predicted emotion for sad_p10_F28_414_417_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1708_1714_vocals.wav: [0.02724143 0.02898509 0.04121909 0.0433361  0.85921824]
# Predicted emotion for sad_p09_F21_1708_1714_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3753_3800_vocals.wav: [0.08074456 0.11796214 0.08740373 0.06595558 0.647934  ]
# Predicted emotion for sad_p10_F28_3753_3800_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12225_12232.wav: [0.02247435 0.023704   0.02857334 0.02454278 0.9007055 ]
# Predicted emotion for sad_p07_F33_12225_12232.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_314_318_vocals.wav: [0.02791792 0.03687211 0.023067   0.0296621  0.88248086]
# Predicted emotion for sad_p10_F28_314_318_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_eb_M36_1953_1957.wav: [0.08345951 0.0661597  0.09136018 0.1054154  0.6536052 ]
# Predicted emotion for sad_p06_eb_M36_1953_1957.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12447_12452.wav: [0.01671308 0.02044227 0.02541287 0.01535263 0.9220792 ]
# Predicted emotion for sad_p07_F33_12447_12452.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3352_3401.wav: [0.02261874 0.038833   0.02958336 0.02808286 0.880882  ]
# Predicted emotion for sad_p10_F28_3352_3401.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_M35_1933_1937.wav: [0.01730759 0.01188704 0.01226679 0.01204187 0.94649667]
# Predicted emotion for sad_p01_M35_1933_1937.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12459_12505.wav: [0.02373482 0.0209945  0.045625   0.03433894 0.8753067 ]
# Predicted emotion for sad_p07_F33_12459_12505.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_M20_4343_4348.wav: [0.0650321  0.11107454 0.16221151 0.08111614 0.5805657 ]
# Predicted emotion for sad_p06_M20_4343_4348.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_5028_5035.wav: [0.02075711 0.02124793 0.02346673 0.02177114 0.91275704]
# Predicted emotion for sad_p07_M19_5028_5035.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_13934_13940.wav: [0.03331285 0.05901326 0.034368   0.02620979 0.8470961 ]
# Predicted emotion for sad_p07_F33_13934_13940.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F29_349_353_vocals.wav: [0.02823533 0.04030723 0.02387775 0.02869258 0.87888706]
# Predicted emotion for sad_p10_F29_349_353_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M2_12051_12053.wav: [0.03071986 0.01981164 0.02566114 0.03318578 0.8906216 ]
# Predicted emotion for sad_p02_M2_12051_12053.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_2339_2337.wav: [0.01975795 0.03011193 0.02107229 0.02209843 0.9069594 ]
# Predicted emotion for sad_p07_F33_2339_2337.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_M35_2303_2306.wav: [0.02533815 0.02353564 0.03052829 0.02794611 0.8926518 ]
# Predicted emotion for sad_p01_M35_2303_2306.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3352_3401_vocals.wav: [0.08755112 0.11847637 0.13244049 0.07799094 0.5835411 ]
# Predicted emotion for sad_p10_F28_3352_3401_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F17_13456_13502.wav: [0.03847808 0.02168555 0.04949005 0.02846477 0.86188155]
# Predicted emotion for sad_p07_F17_13456_13502.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3437_3442_vocals.wav: [0.03704466 0.11584023 0.17066132 0.08459817 0.59185565]
# Predicted emotion for sad_p10_F28_3437_3442_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_M35_3047_3051.wav: [0.0754869  0.06546221 0.05912974 0.08419287 0.7157283 ]
# Predicted emotion for sad_p01_M35_3047_3051.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3717_3725_vocals.wav: [0.05621543 0.08978384 0.09608035 0.06212786 0.69579256]
# Predicted emotion for sad_p10_F28_3717_3725_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F19_1811_1816_vocals.wav: [0.02238531 0.01535058 0.01699096 0.01939059 0.9258826 ]
# Predicted emotion for sad_p09_F19_1811_1816_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M2_12051_12100.wav: [0.01703198 0.01723791 0.01301541 0.01892365 0.93379104]
# Predicted emotion for sad_p02_M2_12051_12100.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_F1_2616_2619.wav: [0.04678592 0.05046453 0.04100223 0.06801818 0.7937291 ]
# Predicted emotion for sad_p01_F1_2616_2619.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_5038_5046.wav: [0.01553351 0.01236508 0.01835685 0.01854633 0.9351982 ]
# Predicted emotion for sad_p07_M19_5038_5046.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F27_458_504_vocals.wav: [0.04546067 0.03594466 0.05136018 0.03757482 0.8296597 ]
# Predicted emotion for sad_p10_F27_458_504_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F19_1837_1843_vocals.wav: [0.22105847 0.08433798 0.04114522 0.03840251 0.61505586]
# Predicted emotion for sad_p09_F19_1837_1843_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1805_1808_vocals.wav: [0.01524899 0.01478389 0.01467049 0.01487014 0.94042647]
# Predicted emotion for sad_p09_F21_1805_1808_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_2234_2247.wav: [0.01762242 0.01836182 0.0168281  0.0136262  0.93356144]
# Predicted emotion for sad_p07_M19_2234_2247.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_12421_12425_vocals.wav: [0.05119373 0.04252457 0.03797819 0.03396801 0.8343355 ]
# Predicted emotion for sad_p07_M19_12421_12425_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M1_4801_4807.wav: [0.02453901 0.02531748 0.02243614 0.02122796 0.90647936]
# Predicted emotion for sad_p02_M1_4801_4807.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p01_F1_2844_2849.wav: [0.08349717 0.0519604  0.04104355 0.05965267 0.7638462 ]
# Predicted emotion for sad_p01_F1_2844_2849.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_F39_5028_5032.wav: [0.03435569 0.18081473 0.04705826 0.0375361  0.70023525]
# Predicted emotion for sad_p02_F39_5028_5032.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F27_448_458_vocals.wav: [0.0317937  0.05800016 0.07627118 0.05308244 0.7808525 ]
# Predicted emotion for sad_p10_F27_448_458_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_2644_2649.wav: [0.04310149 0.04207909 0.03092902 0.03490378 0.8489867 ]
# Predicted emotion for sad_p07_M19_2644_2649.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_13352_13356.wav: [0.02241437 0.0278214  0.04352203 0.02092842 0.88531375]
# Predicted emotion for sad_p07_M19_13352_13356.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_2824_2829.wav: [0.02626766 0.04040971 0.01819838 0.02144743 0.8936768 ]
# Predicted emotion for sad_p06_F9_2824_2829.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_2331_2335.wav: [0.07531647 0.40002358 0.12860401 0.08376502 0.31229088]
# Predicted emotion for sad_p10_F28_2331_2335.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_F3_10139_10144.wav: [0.00688855 0.0108549  0.01106366 0.01181147 0.95938146]
# Predicted emotion for sad_p02_F3_10139_10144.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_1045_1051.wav: [0.025276   0.03581645 0.03524787 0.02515541 0.8785043 ]
# Predicted emotion for sad_p07_M19_1045_1051.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p06_F9_1934_1941.wav: [0.11689536 0.02448887 0.04760621 0.05948485 0.75152475]
# Predicted emotion for sad_p06_F9_1934_1941.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F29_354_359_vocals.wav: [0.03666357 0.03030242 0.02119934 0.02631663 0.885518  ]
# Predicted emotion for sad_p10_F29_354_359_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_4008_4015_vocals.wav: [0.05608004 0.05638552 0.07088848 0.05516871 0.7614773 ]
# Predicted emotion for sad_p10_F28_4008_4015_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_5750_5757.wav: [0.03065841 0.05246119 0.03804817 0.0364937  0.8423385 ]
# Predicted emotion for sad_p07_F33_5750_5757.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p09_F21_1732_1735_vocals.wav: [0.01436076 0.01883312 0.03307118 0.03248011 0.90125483]
# Predicted emotion for sad_p09_F21_1732_1735_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_3736_3743_vocals.wav: [0.05824796 0.04584946 0.06772899 0.05432303 0.77385056]
# Predicted emotion for sad_p10_F28_3736_3743_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_440_445_vocals.wav: [0.0571305  0.03887941 0.065809   0.04039444 0.7977866 ]
# Predicted emotion for sad_p10_F28_440_445_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p02_M1_4819_4821.wav: [0.01975202 0.01871835 0.01860344 0.01777572 0.9251505 ]
# Predicted emotion for sad_p02_M1_4819_4821.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p10_F28_2316_2321_vocals.wav: [0.0478819  0.01430108 0.01646093 0.01864242 0.9027136 ]
# Predicted emotion for sad_p10_F28_2316_2321_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_M19_12306_12311.wav: [0.03205362 0.05304136 0.03684768 0.03284154 0.8452158 ]
# Predicted emotion for sad_p07_M19_12306_12311.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Sad/sad_p07_F33_12359_12405.wav: [0.01823305 0.02475421 0.01504808 0.01702073 0.9249439 ]
# Predicted emotion for sad_p07_F33_12359_12405.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_2518_2522.wav: [0.01329803 0.94144064 0.01401337 0.01410352 0.01714435]
# Predicted emotion for happy_p04_M18_2518_2522.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F28_t10_14_19_vocals.wav: [0.2631058  0.43216795 0.06759753 0.08756578 0.14956291]
# Predicted emotion for happy_p10_F28_t10_14_19_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_5016_5017.wav: [0.01355833 0.93881977 0.01579329 0.01461379 0.01721488]
# Predicted emotion for happy_p04_M18_5016_5017.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_123_128_vocals.wav: [0.09878504 0.38669884 0.16681844 0.15353285 0.19416478]
# Predicted emotion for happy_p04_M18_123_128_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_1804_1807_vocals.wav: [0.2384499  0.597654   0.06546469 0.05567753 0.04275388]
# Predicted emotion for happy_p11_M2_1804_1807_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_1856_1902_vocals.wav: [0.04178196 0.8707201  0.02597667 0.02564685 0.0358744 ]
# Predicted emotion for happy_p11_M2_1856_1902_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_4826_4831_vocals.wav: [0.02949336 0.7668231  0.09720085 0.05451884 0.05196387]
# Predicted emotion for happy_p11_M2_4826_4831_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_3434_3438_vocals.wav: [0.05694942 0.7088031  0.1139515  0.05587697 0.06441898]
# Predicted emotion for happy_p11_M2_3434_3438_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F28_2733_2737.wav: [0.05298835 0.69252926 0.10726587 0.05067777 0.09653877]
# Predicted emotion for happy_p10_F28_2733_2737.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F27_2104_2107_vocals.wav: [0.1730119  0.1840921  0.4034256  0.10919955 0.13027085]
# Predicted emotion for happy_p10_F27_2104_2107_vocals.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M27_1728_1731.wav: [0.01623329 0.8967875  0.02873269 0.02488277 0.03336382]
# Predicted emotion for happy_p11_M27_1728_1731.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_10305_10310.wav: [0.06490398 0.7499419  0.06007776 0.05502063 0.07005573]
# Predicted emotion for happy_p04_M18_10305_10310.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F27_2028_2034_vocals.wav: [0.10812683 0.504471   0.12911433 0.09775071 0.16053706]
# Predicted emotion for happy_p10_F27_2028_2034_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_F31_4545_4550.wav: [0.01053835 0.9534571  0.01172838 0.01248591 0.01179038]
# Predicted emotion for happy_p04_F31_4545_4550.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p02_F2_10717_10721.wav: [0.02006064 0.9331479  0.0187525  0.01521787 0.0128211 ]
# Predicted emotion for happy_p02_F2_10717_10721.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F28_1531_1535_vocals.wav: [0.03821459 0.8845838  0.02080993 0.02564413 0.03074765]
# Predicted emotion for happy_p10_F28_1531_1535_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M27_3239_3243_vocals.wav: [0.11358508 0.6930319  0.04884719 0.04164257 0.10289326]
# Predicted emotion for happy_p11_M27_3239_3243_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p07_F33_2650_2656_vocals.wav: [0.03332332 0.64452165 0.16943944 0.07429682 0.07841881]
# Predicted emotion for happy_p07_F33_2650_2656_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_2359_2404.wav: [0.0514347  0.66805536 0.09293377 0.05103374 0.13654245]
# Predicted emotion for happy_p04_M18_2359_2404.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_2612_2615.wav: [0.01367206 0.92739844 0.02076788 0.02070956 0.01745214]
# Predicted emotion for happy_p04_M18_2612_2615.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F27_2043_22048_vocals.wav: [0.02753918 0.8545029  0.04070158 0.03472501 0.04253124]
# Predicted emotion for happy_p10_F27_2043_22048_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_1549_1553.wav: [0.05953602 0.8480038  0.02624334 0.02857294 0.03764382]
# Predicted emotion for happy_p04_M18_1549_1553.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F29_3623_3630_vocals.wav: [0.18859464 0.16186365 0.08248022 0.12433533 0.4427261 ]
# Predicted emotion for happy_p10_F29_3623_3630_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_1856_1902.wav: [0.04859862 0.76551706 0.06273599 0.04773016 0.07541818]
# Predicted emotion for happy_p11_M2_1856_1902.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F27_2050_2054_vocals.wav: [0.05698872 0.73000216 0.05038435 0.06494475 0.09768001]
# Predicted emotion for happy_p10_F27_2050_2054_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M27_1934_1936_vocals.wav: [0.02082966 0.91141903 0.01745624 0.01958393 0.03071125]
# Predicted emotion for happy_p11_M27_1934_1936_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_34273429_vocals.wav: [0.07371575 0.745856   0.04319449 0.06205581 0.07517795]
# Predicted emotion for happy_p11_M2_34273429_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_1058_1100.wav: [0.2391371  0.49053863 0.05102161 0.05803872 0.16126391]
# Predicted emotion for happy_p04_M18_1058_1100.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_F8_10221_10224.wav: [0.04910371 0.8167105  0.03695155 0.0569759  0.04025837]
# Predicted emotion for happy_p04_F8_10221_10224.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p10_F28_3202_3208.wav: [0.05137728 0.67933065 0.10263066 0.05516868 0.11149266]
# Predicted emotion for happy_p10_F28_3202_3208.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_1858_1859_vocals.wav: [0.01622584 0.9403421  0.01369375 0.01509495 0.01464336]
# Predicted emotion for happy_p11_M2_1858_1859_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M17_4635_4640.wav: [0.00865056 0.9512753  0.01483131 0.0134078  0.01183497]
# Predicted emotion for happy_p04_M17_4635_4640.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_1804_1807.wav: [0.14888512 0.73413235 0.0478223  0.03783187 0.03132841]
# Predicted emotion for happy_p11_M2_1804_1807.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M17_4536_4543.wav: [0.04248898 0.2339356  0.56314176 0.04974985 0.11068381]
# Predicted emotion for happy_p04_M17_4536_4543.wav (best model): Anxiety
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p07_F33_2610_2614_vocals.wav: [0.01691124 0.91109306 0.02829763 0.02312612 0.02057184]
# Predicted emotion for happy_p07_F33_2610_2614_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_3444_3450_vocals.wav: [0.03969893 0.85588825 0.03817533 0.0324241  0.03381344]
# Predicted emotion for happy_p11_M2_3444_3450_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M27_1924_1927_vocals.wav: [0.14291771 0.5195284  0.05200983 0.13637559 0.14916845]
# Predicted emotion for happy_p11_M27_1924_1927_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p07_M19_2615_2619_vocals.wav: [0.01445846 0.9012739  0.03458576 0.0208764  0.02880544]
# Predicted emotion for happy_p07_M19_2615_2619_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_eb_F30_10006_10010.wav: [0.02896435 0.90616417 0.02181057 0.02205012 0.02101087]
# Predicted emotion for happy_p04_eb_F30_10006_10010.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_3414_3417_vocals.wav: [0.08731626 0.56332433 0.13735743 0.11405687 0.09794513]
# Predicted emotion for happy_p11_M2_3414_3417_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p04_M18_130_133.wav: [0.03935696 0.8739074  0.03131545 0.02813634 0.02728389]
# Predicted emotion for happy_p04_M18_130_133.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p07_eb_F32_1442_1447_vocals.wav: [0.11472939 0.25249687 0.13466594 0.09774614 0.40036157]
# Predicted emotion for happy_p07_eb_F32_1442_1447_vocals.wav (best model): Sad
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M27_1921_1923_vocals.wav: [0.08634457 0.7004118  0.08720654 0.06850799 0.0575291 ]
# Predicted emotion for happy_p11_M27_1921_1923_vocals.wav (best model): Happy
# Prediction probabilities for /kaggle/input/speech-emotion-10/VESC_test/VESC_test/Happy/happy_p11_M2_3139_3143_vocals.wav: [0.02194762 0.9076814  0.02661987 0.02537991 0.01837124]
# Predicted emotion for happy_p11_M2_3139_3143_vocals.wav (best model): Happy

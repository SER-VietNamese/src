# %% [markdown]
# Prepare data train/test

# %%
import os
import glob
import numpy as np
import tensorflow as tf
import joblib
import math
import random
from collections import Counter, defaultdict
import pandas as pd # <-- Thêm import

# Thư viện cho việc xử lý dữ liệu
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
# Out:
# 2025-09-04 10:02:32.186859: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756980152.427274      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756980152.498642      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# --- prepare data ---
def split_data_by_prefix(all_files, emotion_map, test_ratio=0.1, output_excel_path=None):
    """
    Chia dữ liệu với điều kiện mới: cụm < 10 file sẽ không được lấy vào tập test.
    """
    # Bước 1: Nhóm tất cả các file theo (nhãn, 2-ký-tự-đầu)
    grouped_files = defaultdict(lambda: defaultdict(list))
    for file_path in all_files:
        try:
            folder_name = os.path.basename(os.path.dirname(file_path))
            label = emotion_map[folder_name]
            filename = os.path.basename(file_path)
            prefix = filename[:2]
            grouped_files[label][prefix].append(file_path)
        except (KeyError, IndexError):
            print(f"Bỏ qua file không hợp lệ hoặc không có trong emotion_map: {file_path}")
            continue

    # Bước 2: Duyệt qua từng cụm đã nhóm và chia train/test
    data_train = []
    data_test = []

    for label in grouped_files:
        for prefix in grouped_files[label]:
            file_cluster = grouped_files[label][prefix]
            
            # --- THAY ĐỔI LOGIC TẠI ĐÂY ---
            # Nếu cụm có ít hơn 10 file, đưa tất cả vào tập train
            if len(file_cluster) < 7:
                data_train.extend(file_cluster)
            else:
                # Nếu cụm có từ 10 file trở lên, áp dụng quy tắc chia cũ
                random.shuffle(file_cluster)
                n_test = math.ceil(len(file_cluster) * test_ratio)
                
                test_files = file_cluster[:n_test]
                train_files = file_cluster[n_test:]
                
                data_test.extend(test_files)
                data_train.extend(train_files)


    # Xuất ra file Excel nếu có yêu cầu
    if output_excel_path:
        try:
            df_train = pd.DataFrame(data_train, columns=['filepath'])
            df_test = pd.DataFrame(data_test, columns=['filepath'])
            with pd.ExcelWriter(output_excel_path) as writer:
                df_train.to_excel(writer, sheet_name='data_train', index=False)
                df_test.to_excel(writer, sheet_name='data_test', index=False)
            print(f"Đã xuất danh sách train và test ra file: {output_excel_path}")
        except Exception as e:
            print(f"Lỗi khi xuất file Excel: {e}")

    return data_train, data_test

# %%
data_train = ""
data_test = ""

# %%
import pandas as pd

def load_split_data_from_excel(excel_path):
    
    try:
        
        df_train = pd.read_excel(excel_path, sheet_name='data_train')
        df_test = pd.read_excel(excel_path, sheet_name='data_test')

        data_train_paths = df_train['filepath'].tolist()
        data_test_paths = df_test['filepath'].tolist()
        
        print(f"Load {len(data_train_paths)} path file train.")
        print(f"Load {len(data_test_paths)} path file test.")
        
        return data_train_paths, data_test_paths

    except FileNotFoundError:
        print(f"Error: file not found  '{excel_path}'")
        return None, None
    except Exception as e:
        print(f"Error read file Excel: {e}")
        return None, None

# %%
EMOTIONS = ['Angry', 'Happy', 'Fear', 'Neutral', 'Sad', 'Boredom', 'Disgust']
NUM_CLASSES = len(EMOTIONS)
emotion_map = {
    'Angry': 0, 
    'Happy': 1, 
    'Fear': 2, 
    'Neutral': 3, 
    'Sad': 4, 
    'Boredom': 5, 
    'Disgust': 6
}

# --- Bước 1: Tải và phân chia dữ liệu ---
#root_folder = '/kaggle/input/speech-emotion-10/EmoDB/EmoDB'
#folders = [f for f in glob.glob(os.path.join(root_folder, "*")) if os.path.isdir(f)]
#all_files = []
#for folder in folders:
#    files = glob.glob(os.path.join(folder, "**", "*.wav"), recursive=True)
#    all_files.extend(files)

#if not all_files:
#    raise ValueError("No audio files found in the source directory.")

#print(f"Total files found: {len(all_files)}")

# Sử dụng hàm chia dữ liệu tùy chỉnh theo quy tắc mới
#print("Splitting data based on custom prefix rule...")
#data_train, data_test = split_data_by_prefix(all_files, emotion_map, test_ratio=0.1, output_excel_path='data_split_results.xlsx')

# %% [markdown]
# //OrionNet

# %%
import os
from glob import glob
import numpy as np
import librosa
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, StratifiedKFold
import joblib

# %%
#EMO_DB = True

#if EMO_DB:
#    EMOTIONS = ['Angry', 'Happy', 'Fear', 'Neutral', 'Sad', 'Boredom', 'Disgust']
#    NUM_CLASSES = len(EMOTIONS)
#    emotion_map = {
#        'Angry': 0, 
#        'Happy': 1, 
#        'Fear': 2, 
#        'Neutral': 3, 
#        'Sad': 4, 
#        'Boredom': 5, 
#        'Disgust': 6
#    }
#    DATA_PATH = '/kaggle/input/speech-emotion-10/EmoDB/EmoDB'
#else:
#    EMOTIONS = ['Angry', 'Happy', 'Anxiety', 'Neutral', 'Sad']
#    NUM_CLASSES = len(EMOTIONS)
#    emotion_map = {
#        'Angry': 0, 'Happy': 1, 'Anxiety': 2, 'Neutral': 3, 'Sad': 4
#    }
#    DATA_PATH = '/kaggle/input/speech-emotion-10/VESC/VESC'

# Actual calculation needed from the data
GLOBAL_MEAN_PITCH = 0.0
GLOBAL_JITTER = 0.0
GLOBAL_PITCH_SLOPE = 0.0

# Function to add noise
def add_noise(audio, noise_factor=0.01):
    noise = np.random.randn(len(audio))
    return audio + noise_factor * noise

# Function to change pitch
def pitch_shift(audio, sr, n_steps=2): # Random n_steps
    return librosa.effects.pitch_shift(audio, sr=sr, n_steps=n_steps)

# Function to apply time stretching
def time_stretch(audio, rate=0.95): # Random rate
    return librosa.effects.time_stretch(audio, rate=rate)

# Function to apply time shifting
def time_shift(audio, shift_max=0.15, sr= 16000):
    shift = int(np.random.uniform(-shift_max, shift_max) * sr)
    return np.roll(audio, shift)

# Function to normalize pitch
def normalize_pitch(pitches):
    pitches = pitches[pitches > 0]
    if len(pitches) == 0:
        return GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE

    mean_pitch = np.mean(pitches)
    normalized_pitches = pitches - mean_pitch
    jitter = np.std(normalized_pitches) if len(normalized_pitches) > 0 else 0

    if len(pitches) > 1:
        slope = np.polyfit(np.arange(len(pitches)), pitches, 1)[0]
    else:
        slope = 0

    if np.isnan(mean_pitch): mean_pitch = GLOBAL_MEAN_PITCH
    if np.isnan(jitter): jitter = GLOBAL_JITTER
    if np.isnan(slope): slope = GLOBAL_PITCH_SLOPE

    return mean_pitch, jitter, slope

# Feature extraction
def extract_features(audio_path, sample_rate= 16000, duration=8, n_mfcc=26, n_frames=157, augment_type='normal', global_pitch_params=None):
    try:
        audio, sr = librosa.load(audio_path, sr=sample_rate)
        target_length = sample_rate * duration

        if len(audio) < target_length:
            audio = np.pad(audio, (0, target_length - len(audio)), mode='constant')
        else:
            audio = audio[:target_length]

        if augment_type == 'noise':
            audio = add_noise(audio)
        elif augment_type == 'pitch':
            audio = pitch_shift(audio, sr)
        elif augment_type == 'stretch':
            audio = time_stretch(audio)
        elif augment_type == 'shift':
            audio = time_shift(audio)

        hop_length = target_length // (n_frames - 1)

        # MFCCs + Delta + Delta-Delta
        mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length, n_fft=2048)
        mfcc_delta = librosa.feature.delta(mfcc)
        mfcc_delta2 = librosa.feature.delta(mfcc, order=2)
        mfcc_features = np.concatenate((mfcc, mfcc_delta, mfcc_delta2), axis=0)

        # Pad or truncate MFCCs
        if mfcc_features.shape[1] > n_frames:
            mfcc_features = mfcc_features[:, :n_frames]
        elif mfcc_features.shape[1] < n_frames:
            mfcc_features = np.pad(mfcc_features, ((0, 0), (0, n_frames - mfcc_features.shape[1])), mode='constant')

        # Pitch features
        pitches, magnitudes = librosa.piptrack(y=audio, sr=sr, hop_length=hop_length)
        if global_pitch_params:
            mean_pitch, jitter, pitch_slope = normalize_pitch(pitches)
            if mean_pitch == 0 and jitter == 0 and pitch_slope == 0:
                mean_pitch, jitter, pitch_slope = global_pitch_params
        else:
            mean_pitch, jitter, pitch_slope = normalize_pitch(pitches) # Will use current GLOBAL_*

        pitch_features_single = np.array([mean_pitch, jitter, pitch_slope])
        pitch_features = np.tile(pitch_features_single, (n_frames, 1)).T # Tile to match n_frames

        # Energy features (RMS + mean and std)
        energy = librosa.feature.rms(y=audio, hop_length=hop_length)[0]
        if len(energy) > n_frames:
            energy = energy[:n_frames]
        elif len(energy) < n_frames:
            energy = np.pad(energy, (0, n_frames - len(energy)), mode='constant')

        mean_energy = np.mean(energy)
        shimmer = np.std(energy) if len(energy) > 0 else 0
        energy_features = np.array([energy, np.full(n_frames, mean_energy), np.full(n_frames, shimmer)])

        # Zero-Crossing Rate
        zcr = librosa.feature.zero_crossing_rate(y=audio, hop_length=hop_length)[0]
        if len(zcr) > n_frames:
            zcr = zcr[:n_frames]
        elif len(zcr) < n_frames:
            zcr = np.pad(zcr, (0, n_frames - len(zcr)), mode='constant')
        zcr_features = zcr[np.newaxis, :]

        # Chroma features
        chroma = librosa.feature.chroma_stft(y=audio, sr=sr, hop_length=hop_length, n_chroma=12)
        if chroma.shape[1] > n_frames:
            chroma = chroma[:, :n_frames]
        elif chroma.shape[1] < n_frames:
            chroma = np.pad(chroma, ((0, 0), (0, n_frames - chroma.shape[1])), mode='constant')

        # Spectral features
        spectral_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr, hop_length=hop_length)[0]
        spectral_rolloff = librosa.feature.spectral_rolloff(y=audio, sr=sr, hop_length=hop_length)[0]
        spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sr, hop_length=hop_length, n_bands=5)

        # Pad or truncate spectral features
        # Assuming all spectral features have the same number of frames
        if spectral_centroid.shape[0] > n_frames:
            spectral_centroid = spectral_centroid[:n_frames]
            spectral_rolloff = spectral_rolloff[:n_frames]
            spectral_contrast = spectral_contrast[:, :n_frames]
        elif spectral_centroid.shape[0] < n_frames:
            spectral_centroid = np.pad(spectral_centroid, (0, n_frames - spectral_centroid.shape[0]), mode='constant')
            spectral_rolloff = np.pad(spectral_rolloff, (0, n_frames - spectral_rolloff.shape[0]), mode='constant')
            spectral_contrast = np.pad(spectral_contrast, ((0, 0), (0, n_frames - spectral_contrast.shape[1])), mode='constant')
        spectral_features = np.vstack([spectral_centroid, spectral_rolloff, spectral_contrast])

        # Temporal features
        voiced_frames = librosa.effects.split(audio, top_db=20)
        speech_rate = len(voiced_frames) / (duration if duration > 0 else 1)
        pauses = len(voiced_frames) - 1 if len(voiced_frames) > 1 else 0
        temporal_features_single = np.array([speech_rate, pauses])
        temporal_features = np.tile(temporal_features_single, (n_frames, 1)).T

        features = np.concatenate([
            mfcc_features, # Now includes delta and delta-delta
            pitch_features,
            energy_features,
            zcr_features,
            chroma,
            spectral_features,
            temporal_features
        ], axis=0)

        return np.expand_dims(features, axis=-1)

    except Exception as e:
        print(f"Error processing {audio_path}: {e}")
        return None

# Build CNN model
def build_cnn_2d(input_shape=(55, 157, 1)):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Flatten(),
        layers.Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
        layers.Dropout(0.4),
        layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    model.summary()
    return model

# Add a function to calculate GLOBAL_PITCH_PARAMS
def calculate_global_pitch_params(audio_files, sample_rate= 16000): #24200
    all_pitches = []
    for audio_path in audio_files:
        try:
            audio, sr = librosa.load(audio_path, sr=sample_rate)
            pitches, magnitudes = librosa.piptrack(y=audio, sr=sr)
            pitches = pitches[pitches > 0]
            if len(pitches) > 0:
                all_pitches.extend(pitches)
        except Exception as e:
            print(f"Error calculating global pitch for {audio_path}: {e}")
            continue

    if len(all_pitches) == 0:
        print("Warning: No valid pitches found to calculate global parameters. Using default zeros.")
        return 0.0, 0.0, 0.0

    all_pitches = np.array(all_pitches)
    global_mean_pitch = np.mean(all_pitches)

    normalized_all_pitches = all_pitches - global_mean_pitch
    global_jitter = np.std(normalized_all_pitches) if len(normalized_all_pitches) > 0 else 0

    global_pitch_slope = 0.0

    global_mean_pitch = 0.0 if np.isnan(global_mean_pitch) or np.isinf(global_mean_pitch) else global_mean_pitch
    global_jitter = 0.0 if np.isnan(global_jitter) or np.isinf(global_jitter) else global_jitter
    global_pitch_slope = 0.0 if np.isnan(global_pitch_slope) or np.isinf(global_pitch_slope) else global_pitch_slope

    return global_mean_pitch, global_jitter, global_pitch_slope


# Function to prepare data with label mapping from directory
def prepare_training_data(audio_files, emotion_map, global_pitch_params):
    X, y = [], []
    augment_types = ['normal', 'noise', 'pitch', 'stretch', 'shift']
    skipped_files = 0
    processed_files = 0

    print(f"Total number of audio files: {len(audio_files)}")
    for audio_path in audio_files:
        folder_name = os.path.basename(os.path.dirname(audio_path))
        if folder_name not in emotion_map:
            skipped_files += 1
            continue
        emotion_idx = emotion_map[folder_name]

        for aug_type in augment_types:
            features = extract_features(str(audio_path), augment_type=aug_type, global_pitch_params=global_pitch_params)
            if features is None or np.all(features == 0):
                continue
            X.append(features)
            y.append(emotion_idx)
            processed_files += 1

    print(f"Processed: {processed_files} samples, skipped: {skipped_files} files.")
    if not X or not y:
        raise ValueError("No audio files were successfully processed. Please check the data path or emotion_map.")

    X = np.array(X)
    y = to_categorical(y, num_classes=NUM_CLASSES)
    print(f"Dataset shape: X={X.shape}, y={y.shape}")
    return X, y

# Function to prepare test data
def prepare_test_data(audio_files, emotion_map, global_pitch_params):
    X, y = [], []
    skipped_files = 0
    processed_files = 0

    print(f"Total number of test audio files: {len(audio_files)}")
    for audio_path in audio_files:
        folder_name = os.path.basename(os.path.dirname(audio_path))
        if folder_name not in emotion_map:
            skipped_files += 1
            continue
        emotion_idx = emotion_map[folder_name]
        features = extract_features(str(audio_path), augment_type='normal', global_pitch_params=global_pitch_params)
        if features is None or np.all(features == 0):
            continue
        X.append(features)
        y.append(emotion_idx)
        processed_files += 1

    print(f"Processed: {processed_files} samples, skipped: {skipped_files} files.")
    if not X or not y:
        raise ValueError("No test audio files were successfully processed.")

    X = np.array(X)
    y = to_categorical(y, num_classes=NUM_CLASSES)
    print(f"Test dataset shape: X={X.shape}, y={y.shape}")
    return X, y

# Evaluate the model using confusion matrix and F1 Score
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test, verbose=0)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)

    print("\nSample prediction probabilities:")
    for i in range(min(5, len(X_test))):
        print(f"Sample {i+1}: True={EMOTIONS[y_true_classes[i]]}, Pred={EMOTIONS[y_pred_classes[i]]}, Prob={y_pred[i]}")

    cm = confusion_matrix(y_true_classes, y_pred_classes)
    plt.figure(figsize=(10, 8))
    sns_heatmap = sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=EMOTIONS, yticklabels=EMOTIONS)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    print("\nClassification Report:")
    print(classification_report(y_true_classes, y_pred_classes, target_names=EMOTIONS))

    print("\nEvaluation metric formulas:")
    print("1. Precision = TP / (TP + FP)")
    print("   - TP (True Positives): Number of samples correctly predicted for a class.")
    print("   - FP (False Positives): Number of samples incorrectly predicted as that class.")
    print("2. Recall = TP / (TP + FN)")
    print("   - FN (False Negatives): Number of samples that belong to the class but were incorrectly predicted.")
    print("3. F1 Score = 2 * (Precision * Recall) / (Precision + Recall)")

# Train and evaluate
def train_and_evaluate_model(model, X, y, epochs=200, batch_size=16, checkpoint_path='best_model.h5', class_weight=None, k_folds=5):
    if len(X) == 0 or len(y) == 0:
        raise ValueError("Training dataset is empty. Please check the input data.")

    kf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)
    fold_no = 1
    val_losses = []
    val_accuracies = []
    best_model = None
    best_history = None
    best_val_loss = float('inf')
    X_val_last, y_val_last = None, None
    scaler = StandardScaler()
    y_indices = np.argmax(y, axis=1)
    for train_index, val_index in kf.split(X, y_indices):
        print(f"\nTraining on fold {fold_no}/{k_folds}...")

        X_train, X_val = X[train_index], X[val_index]
        y_train, y_val = y[train_index], y[val_index]
        print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}")

        original_shape_train = X_train.shape
        X_train_2d = X_train.reshape(original_shape_train[0], -1)
        
        original_shape_val = X_val.shape
        X_val_2d = X_val.reshape(original_shape_val[0], -1)
        
        X_train_2d = scaler.fit_transform(X_train_2d)
        X_val_2d = scaler.transform(X_val_2d)
        
        X_train = X_train_2d.reshape(original_shape_train)
        X_val = X_val_2d.reshape(original_shape_val)

        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                      loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
                      metrics=['accuracy'])

        early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=0.00001)
        checkpoint = ModelCheckpoint(f"{checkpoint_path}_fold_{fold_no}.h5", monitor='val_loss', save_best_only=True, mode='min', verbose=1)

        history = model.fit(X_train, y_train,
                            validation_data=(X_val, y_val),
                            epochs=epochs,
                            batch_size=batch_size,
                            callbacks=[early_stopping, reduce_lr, checkpoint],
                            class_weight=class_weight,
                            verbose=1)

        val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
        print(f"\nFold {fold_no} - Evaluation on validation set:")
        print(f" - Loss: {val_loss:.4f}")
        print(f" - Accuracy: {val_accuracy:.4f}")
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = model
            best_history = history
            X_val_last, y_val_last = X_val, y_val

        fold_no += 1

    print(f"\nAverage results across {k_folds} folds:")
    print(f" - Average Loss: {np.mean(val_losses):.4f}")
    print(f" - Average Accuracy: {np.mean(val_accuracies):.4f}")

    return best_model, best_history, X_val_last, y_val_last

# Direct prediction using CNN
def predict_emotion(audio_path, model, scaler, global_pitch_params):
    features = extract_features(audio_path, augment_type='normal', global_pitch_params=global_pitch_params)
    if features is None or np.all(features == 0):
        return "Prediction failed: Feature extraction error."

    features_2d = features.reshape(1, -1)
    features_2d = scaler.transform(features_2d)
    features = features_2d.reshape(features.shape)

    features = np.expand_dims(features, axis=0)
    prediction = model.predict(features, verbose=0)
    predicted_emotion_idx = np.argmax(prediction, axis=1)[0]

    print(f"Prediction probabilities for {audio_path}: {prediction[0]}")
    return EMOTIONS[predicted_emotion_idx]

# Plot Loss Chart
def plot_loss_history(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
if __name__ == "__main__":
    # --- Bước 1: Tải và phân chia dữ liệu ---
    #root_folder = DATA_PATH
    #folders = [f for f in glob.glob(os.path.join(root_folder, "*")) if os.path.isdir(f)]
    #all_files = []
    #for folder in folders:
    #    files = glob.glob(os.path.join(folder, "**", "*.wav"), recursive=True)
    #    all_files.extend(files)

    #if not all_files:
    #    raise ValueError("No audio files found in the source directory.")
    
    #print(f"Total files found: {len(all_files)}")

    # Sử dụng hàm chia dữ liệu tùy chỉnh theo quy tắc mới
    #print("Splitting data based on custom prefix rule...")
    #data_train, data_test = split_data_by_prefix(all_files, emotion_map, test_ratio=0.1, output_excel_path='data_split_results.xlsx')
    
    print(f"Split data into {len(data_train)} training files and {len(data_test)} testing files.")
    print("-" * 30)

    # --- Bước 2: Huấn luyện (chỉ sử dụng data_train) ---
    print("Calculating GLOBAL_PITCH_PARAMS from training data...")
    GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE = calculate_global_pitch_params(data_train)
    print(f"GLOBAL_MEAN_PITCH: {GLOBAL_MEAN_PITCH:.4f}, GLOBAL_JITTER: {GLOBAL_JITTER:.4f}, GLOBAL_PITCH_SLOPE: {GLOBAL_PITCH_SLOPE:.4f}")

    y_raw = [emotion_map.get(os.path.basename(os.path.dirname(f))) for f in data_train if os.path.basename(os.path.dirname(f)) in emotion_map]
    y_raw_train = np.array(y_raw)
    print("Training label distribution:", Counter([EMOTIONS[i] for i in y_raw_train]))
    
    class_weights = compute_class_weight('balanced', classes=np.unique(y_raw_train), y=y_raw_train)
    class_weight_dict = dict(enumerate(class_weights))
    print("Class weights:", class_weight_dict)

    X, y = prepare_training_data(data_train, emotion_map, (GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE))
    print(f"Training data X shape: {X.shape}")

    scaler = StandardScaler()
    original_shape = X.shape
    X_2d = X.reshape(original_shape[0], -1)
    X_2d = scaler.fit_transform(X_2d)
    X = X_2d.reshape(original_shape)

    cnn_input_shape = (X.shape[1], X.shape[2], 1)
    print(f"Calculated CNN Input Shape: {cnn_input_shape}")
    
    cnn_model = build_cnn_2d(input_shape=cnn_input_shape)
    cnn_model, history, _, _ = train_and_evaluate_model(
        cnn_model, X, y,
        epochs=100,
        batch_size=16,
        checkpoint_path='best_cnn_2d_model.keras',
        class_weight=class_weight_dict,
        k_folds=5
    )
    
    # Lưu scaler và mô hình đã huấn luyện
    joblib.dump(scaler, 'final_scaler.pkl')
    cnn_model.save('final_model.keras')
    plot_loss_history(history)
    print("-" * 30)

    # --- Bước 3: Đánh giá cuối cùng (chỉ sử dụng data_test) ---
    print("\n--- Evaluating on the held-out test set ---")
    
    # Tải mô hình và scaler tốt nhất
    best_model = tf.keras.models.load_model('final_model.keras')
    scaler = joblib.load('final_scaler.pkl')

    # Chuẩn bị dữ liệu test
    X_test, y_test = prepare_test_data(data_test, emotion_map, (GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE))

    # Chuẩn hóa dữ liệu test với scaler đã fit từ dữ liệu training
    X_test_2d = X_test.reshape(X_test.shape[0], -1)
    X_test_2d = scaler.transform(X_test_2d) # Chỉ dùng TRANSFORM
    X_test = X_test_2d.reshape(X_test.shape)
    
    # Đánh giá hiệu năng cuối cùng
    print("\nFinal Test Set Performance:")
    evaluate_model(best_model, X_test, y_test)

    # --- Bước 4: Dự đoán trên các file test đơn lẻ ---
    print("\n--- Predictions on individual test files ---")
    for test_path in data_test[:5]: # Dự đoán trên 5 file đầu tiên của tập test
        predicted_emotion = predict_emotion(test_path, best_model, scaler, (GLOBAL_MEAN_PITCH, GLOBAL_JITTER, GLOBAL_PITCH_SLOPE))
        true_emotion_label = EMOTIONS[emotion_map.get(os.path.basename(os.path.dirname(test_path)))]
        print(f"File: {os.path.basename(test_path)} | True: {true_emotion_label} | Predicted: {predicted_emotion}")
# Out:
# Split data into 474 training files and 61 testing files.
# ------------------------------
# Calculating GLOBAL_PITCH_PARAMS from training data...
# GLOBAL_MEAN_PITCH: 1688.6304, GLOBAL_JITTER: 1159.1036, GLOBAL_PITCH_SLOPE: 0.0000
# Training label distribution: Counter({'Angry': 108, 'Boredom': 73, 'Neutral': 70, 'Happy': 63, 'Fear': 62, 'Sad': 57, 'Disgust': 41})
# Class weights: {0: 0.626984126984127, 1: 1.0748299319727892, 2: 1.0921658986175116, 3: 0.9673469387755103, 4: 1.1879699248120301, 5: 0.9275929549902152, 6: 1.651567944250871}
# Total number of audio files: 474
# Processed: 2370 samples, skipped: 0 files.
# Dataset shape: X=(2370, 107, 157, 1), y=(2370, 7)
# Training data X shape: (2370, 107, 157, 1)
# Calculated CNN Input Shape: (107, 157, 1)
# I0000 00:00:1756980499.408396      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 107, 157, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 107, 157, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 107, 157, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 107, 157, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 53, 78, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 53, 78, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 53, 78, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 53, 78, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 26, 39, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 26, 39, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 26, 39, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 26, 39, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 19, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 13, 19, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 31616)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     8,093,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,198,695 (31.28 MB)
#  Trainable params: 8,198,183 (31.27 MB)
#  Non-trainable params: 512 (2.00 KB)
# Training on fold 1/5...
# Train shape: (1896, 107, 157, 1), Val shape: (474, 107, 157, 1)
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1756980507.098191      89 service.cc:148] XLA service 0x7a0074016440 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1756980507.099213      89 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1756980507.705873      89 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  14/119 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.1902 - loss: 5.6843
# I0000 00:00:1756980513.614347      89 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2330 - loss: 3.9880
# Epoch 1: val_loss improved from inf to 5.07300, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 21s 78ms/step - accuracy: 0.2332 - loss: 3.9809 - val_accuracy: 0.1793 - val_loss: 5.0730 - learning_rate: 1.0000e-04
# Epoch 2/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3454 - loss: 2.3953
# Epoch 2: val_loss improved from 5.07300 to 3.46766, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3459 - loss: 2.3941 - val_accuracy: 0.2616 - val_loss: 3.4677 - learning_rate: 1.0000e-04
# Epoch 3/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4416 - loss: 2.2492
# Epoch 3: val_loss improved from 3.46766 to 2.53141, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4417 - loss: 2.2481 - val_accuracy: 0.4219 - val_loss: 2.5314 - learning_rate: 1.0000e-04
# Epoch 4/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4618 - loss: 2.1632
# Epoch 4: val_loss improved from 2.53141 to 2.12457, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4618 - loss: 2.1634 - val_accuracy: 0.5675 - val_loss: 2.1246 - learning_rate: 1.0000e-04
# Epoch 5/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4981 - loss: 2.0876
# Epoch 5: val_loss improved from 2.12457 to 2.08141, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4993 - loss: 2.0863 - val_accuracy: 0.5253 - val_loss: 2.0814 - learning_rate: 1.0000e-04
# Epoch 6/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5542 - loss: 2.0288
# Epoch 6: val_loss did not improve from 2.08141
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5542 - loss: 2.0280 - val_accuracy: 0.5591 - val_loss: 2.0889 - learning_rate: 1.0000e-04
# Epoch 7/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6055 - loss: 1.8951
# Epoch 7: val_loss improved from 2.08141 to 1.81201, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6054 - loss: 1.8958 - val_accuracy: 0.6878 - val_loss: 1.8120 - learning_rate: 1.0000e-04
# Epoch 8/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6370 - loss: 1.8871
# Epoch 8: val_loss did not improve from 1.81201
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6370 - loss: 1.8867 - val_accuracy: 0.6350 - val_loss: 1.8366 - learning_rate: 1.0000e-04
# Epoch 9/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6220 - loss: 1.8262
# Epoch 9: val_loss improved from 1.81201 to 1.67209, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6227 - loss: 1.8254 - val_accuracy: 0.7532 - val_loss: 1.6721 - learning_rate: 1.0000e-04
# Epoch 10/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6873 - loss: 1.7468
# Epoch 10: val_loss did not improve from 1.67209
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6870 - loss: 1.7465 - val_accuracy: 0.7194 - val_loss: 1.7164 - learning_rate: 1.0000e-04
# Epoch 11/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7041 - loss: 1.7127
# Epoch 11: val_loss did not improve from 1.67209
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7044 - loss: 1.7122 - val_accuracy: 0.7300 - val_loss: 1.6729 - learning_rate: 1.0000e-04
# Epoch 12/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7522 - loss: 1.6480
# Epoch 12: val_loss improved from 1.67209 to 1.62693, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7522 - loss: 1.6481 - val_accuracy: 0.7321 - val_loss: 1.6269 - learning_rate: 1.0000e-04
# Epoch 13/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7178 - loss: 1.6435
# Epoch 13: val_loss improved from 1.62693 to 1.60201, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7182 - loss: 1.6432 - val_accuracy: 0.7426 - val_loss: 1.6020 - learning_rate: 1.0000e-04
# Epoch 14/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7523 - loss: 1.5943
# Epoch 14: val_loss improved from 1.60201 to 1.52579, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7528 - loss: 1.5936 - val_accuracy: 0.7890 - val_loss: 1.5258 - learning_rate: 1.0000e-04
# Epoch 15/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7980 - loss: 1.5298
# Epoch 15: val_loss improved from 1.52579 to 1.48697, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7976 - loss: 1.5298 - val_accuracy: 0.7975 - val_loss: 1.4870 - learning_rate: 1.0000e-04
# Epoch 16/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7712 - loss: 1.5188
# Epoch 16: val_loss improved from 1.48697 to 1.42872, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7714 - loss: 1.5185 - val_accuracy: 0.8165 - val_loss: 1.4287 - learning_rate: 1.0000e-04
# Epoch 17/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8346 - loss: 1.4560
# Epoch 17: val_loss improved from 1.42872 to 1.41362, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8345 - loss: 1.4558 - val_accuracy: 0.8228 - val_loss: 1.4136 - learning_rate: 1.0000e-04
# Epoch 18/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8207 - loss: 1.4548
# Epoch 18: val_loss did not improve from 1.41362
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8209 - loss: 1.4545 - val_accuracy: 0.8207 - val_loss: 1.4270 - learning_rate: 1.0000e-04
# Epoch 19/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8215 - loss: 1.4344
# Epoch 19: val_loss improved from 1.41362 to 1.35636, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8217 - loss: 1.4340 - val_accuracy: 0.8270 - val_loss: 1.3564 - learning_rate: 1.0000e-04
# Epoch 20/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8470 - loss: 1.3804
# Epoch 20: val_loss improved from 1.35636 to 1.28605, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8468 - loss: 1.3805 - val_accuracy: 0.8797 - val_loss: 1.2860 - learning_rate: 1.0000e-04
# Epoch 21/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8620 - loss: 1.3436
# Epoch 21: val_loss improved from 1.28605 to 1.22977, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8619 - loss: 1.3437 - val_accuracy: 0.9093 - val_loss: 1.2298 - learning_rate: 1.0000e-04
# Epoch 22/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8832 - loss: 1.2985
# Epoch 22: val_loss did not improve from 1.22977
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8829 - loss: 1.2991 - val_accuracy: 0.8861 - val_loss: 1.2623 - learning_rate: 1.0000e-04
# Epoch 23/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8676 - loss: 1.3078
# Epoch 23: val_loss improved from 1.22977 to 1.19610, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8677 - loss: 1.3079 - val_accuracy: 0.9156 - val_loss: 1.1961 - learning_rate: 1.0000e-04
# Epoch 24/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8674 - loss: 1.3036
# Epoch 24: val_loss did not improve from 1.19610
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8678 - loss: 1.3030 - val_accuracy: 0.9177 - val_loss: 1.1967 - learning_rate: 1.0000e-04
# Epoch 25/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8738 - loss: 1.2715
# Epoch 25: val_loss improved from 1.19610 to 1.17563, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8742 - loss: 1.2712 - val_accuracy: 0.9156 - val_loss: 1.1756 - learning_rate: 1.0000e-04
# Epoch 26/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9047 - loss: 1.2401
# Epoch 26: val_loss improved from 1.17563 to 1.13316, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9045 - loss: 1.2399 - val_accuracy: 0.9177 - val_loss: 1.1332 - learning_rate: 1.0000e-04
# Epoch 27/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8785 - loss: 1.2575
# Epoch 27: val_loss improved from 1.13316 to 1.11817, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8786 - loss: 1.2573 - val_accuracy: 0.9346 - val_loss: 1.1182 - learning_rate: 1.0000e-04
# Epoch 28/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8970 - loss: 1.2038
# Epoch 28: val_loss improved from 1.11817 to 1.07599, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8973 - loss: 1.2039 - val_accuracy: 0.9494 - val_loss: 1.0760 - learning_rate: 1.0000e-04
# Epoch 29/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9114 - loss: 1.1886
# Epoch 29: val_loss improved from 1.07599 to 1.06798, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9111 - loss: 1.1888 - val_accuracy: 0.9536 - val_loss: 1.0680 - learning_rate: 1.0000e-04
# Epoch 30/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9072 - loss: 1.1860
# Epoch 30: val_loss improved from 1.06798 to 1.05800, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9069 - loss: 1.1861 - val_accuracy: 0.9515 - val_loss: 1.0580 - learning_rate: 1.0000e-04
# Epoch 31/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9244 - loss: 1.1592
# Epoch 31: val_loss improved from 1.05800 to 1.05589, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9243 - loss: 1.1588 - val_accuracy: 0.9451 - val_loss: 1.0559 - learning_rate: 1.0000e-04
# Epoch 32/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9273 - loss: 1.1429
# Epoch 32: val_loss improved from 1.05589 to 1.01568, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9274 - loss: 1.1422 - val_accuracy: 0.9578 - val_loss: 1.0157 - learning_rate: 1.0000e-04
# Epoch 33/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9231 - loss: 1.1217
# Epoch 33: val_loss improved from 1.01568 to 1.01087, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9230 - loss: 1.1218 - val_accuracy: 0.9536 - val_loss: 1.0109 - learning_rate: 1.0000e-04
# Epoch 34/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9295 - loss: 1.1326
# Epoch 34: val_loss improved from 1.01087 to 0.99432, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9295 - loss: 1.1320 - val_accuracy: 0.9578 - val_loss: 0.9943 - learning_rate: 1.0000e-04
# Epoch 35/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9326 - loss: 1.0879
# Epoch 35: val_loss did not improve from 0.99432
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9326 - loss: 1.0879 - val_accuracy: 0.9578 - val_loss: 0.9968 - learning_rate: 1.0000e-04
# Epoch 36/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9207 - loss: 1.0995
# Epoch 36: val_loss improved from 0.99432 to 0.98137, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9209 - loss: 1.0991 - val_accuracy: 0.9536 - val_loss: 0.9814 - learning_rate: 1.0000e-04
# Epoch 37/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9357 - loss: 1.0652
# Epoch 37: val_loss improved from 0.98137 to 0.94634, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9360 - loss: 1.0646 - val_accuracy: 0.9684 - val_loss: 0.9463 - learning_rate: 1.0000e-04
# Epoch 38/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9498 - loss: 1.0402
# Epoch 38: val_loss improved from 0.94634 to 0.93140, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9496 - loss: 1.0403 - val_accuracy: 0.9705 - val_loss: 0.9314 - learning_rate: 1.0000e-04
# Epoch 39/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9458 - loss: 1.0395
# Epoch 39: val_loss did not improve from 0.93140
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9459 - loss: 1.0392 - val_accuracy: 0.9789 - val_loss: 0.9362 - learning_rate: 1.0000e-04
# Epoch 40/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9356 - loss: 1.0424
# Epoch 40: val_loss improved from 0.93140 to 0.92001, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9357 - loss: 1.0421 - val_accuracy: 0.9726 - val_loss: 0.9200 - learning_rate: 1.0000e-04
# Epoch 41/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9555 - loss: 0.9959
# Epoch 41: val_loss improved from 0.92001 to 0.91641, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9554 - loss: 0.9959 - val_accuracy: 0.9705 - val_loss: 0.9164 - learning_rate: 1.0000e-04
# Epoch 42/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9448 - loss: 1.0060
# Epoch 42: val_loss improved from 0.91641 to 0.90586, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9449 - loss: 1.0060 - val_accuracy: 0.9662 - val_loss: 0.9059 - learning_rate: 1.0000e-04
# Epoch 43/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9450 - loss: 1.0041
# Epoch 43: val_loss improved from 0.90586 to 0.88586, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9450 - loss: 1.0041 - val_accuracy: 0.9810 - val_loss: 0.8859 - learning_rate: 1.0000e-04
# Epoch 44/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9569 - loss: 0.9817
# Epoch 44: val_loss improved from 0.88586 to 0.87632, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9571 - loss: 0.9812 - val_accuracy: 0.9726 - val_loss: 0.8763 - learning_rate: 1.0000e-04
# Epoch 45/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9566 - loss: 0.9794
# Epoch 45: val_loss improved from 0.87632 to 0.86815, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9566 - loss: 0.9788 - val_accuracy: 0.9705 - val_loss: 0.8681 - learning_rate: 1.0000e-04
# Epoch 46/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9514 - loss: 0.9631
# Epoch 46: val_loss did not improve from 0.86815
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9514 - loss: 0.9631 - val_accuracy: 0.9768 - val_loss: 0.8686 - learning_rate: 1.0000e-04
# Epoch 47/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9624 - loss: 0.9478
# Epoch 47: val_loss did not improve from 0.86815
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9621 - loss: 0.9477 - val_accuracy: 0.9705 - val_loss: 0.8701 - learning_rate: 1.0000e-04
# Epoch 48/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9552 - loss: 0.9450
# Epoch 48: val_loss improved from 0.86815 to 0.86262, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9553 - loss: 0.9449 - val_accuracy: 0.9705 - val_loss: 0.8626 - learning_rate: 1.0000e-04
# Epoch 49/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9640 - loss: 0.9395
# Epoch 49: val_loss improved from 0.86262 to 0.83368, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9639 - loss: 0.9394 - val_accuracy: 0.9831 - val_loss: 0.8337 - learning_rate: 1.0000e-04
# Epoch 50/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9596 - loss: 0.9272
# Epoch 50: val_loss did not improve from 0.83368
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9598 - loss: 0.9270 - val_accuracy: 0.9705 - val_loss: 0.8495 - learning_rate: 1.0000e-04
# Epoch 51/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9532 - loss: 0.9237
# Epoch 51: val_loss improved from 0.83368 to 0.82650, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9533 - loss: 0.9236 - val_accuracy: 0.9831 - val_loss: 0.8265 - learning_rate: 1.0000e-04
# Epoch 52/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9801 - loss: 0.9013
# Epoch 52: val_loss improved from 0.82650 to 0.82156, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9799 - loss: 0.9012 - val_accuracy: 0.9895 - val_loss: 0.8216 - learning_rate: 1.0000e-04
# Epoch 53/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9622 - loss: 0.9049
# Epoch 53: val_loss improved from 0.82156 to 0.81995, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9622 - loss: 0.9050 - val_accuracy: 0.9768 - val_loss: 0.8200 - learning_rate: 1.0000e-04
# Epoch 54/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9597 - loss: 0.9079
# Epoch 54: val_loss improved from 0.81995 to 0.81758, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9597 - loss: 0.9079 - val_accuracy: 0.9747 - val_loss: 0.8176 - learning_rate: 1.0000e-04
# Epoch 55/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9620 - loss: 0.9037
# Epoch 55: val_loss did not improve from 0.81758
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9622 - loss: 0.9033 - val_accuracy: 0.9768 - val_loss: 0.8191 - learning_rate: 1.0000e-04
# Epoch 56/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9662 - loss: 0.8925
# Epoch 56: val_loss improved from 0.81758 to 0.80506, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9660 - loss: 0.8925 - val_accuracy: 0.9789 - val_loss: 0.8051 - learning_rate: 1.0000e-04
# Epoch 57/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9697 - loss: 0.8757
# Epoch 57: val_loss improved from 0.80506 to 0.78687, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9697 - loss: 0.8757 - val_accuracy: 0.9873 - val_loss: 0.7869 - learning_rate: 1.0000e-04
# Epoch 58/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9651 - loss: 0.8982
# Epoch 58: val_loss did not improve from 0.78687
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9652 - loss: 0.8974 - val_accuracy: 0.9810 - val_loss: 0.7947 - learning_rate: 1.0000e-04
# Epoch 59/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9773 - loss: 0.8549
# Epoch 59: val_loss improved from 0.78687 to 0.77311, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9772 - loss: 0.8550 - val_accuracy: 0.9852 - val_loss: 0.7731 - learning_rate: 1.0000e-04
# Epoch 60/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9748 - loss: 0.8555
# Epoch 60: val_loss did not improve from 0.77311
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9748 - loss: 0.8554 - val_accuracy: 0.9852 - val_loss: 0.7805 - learning_rate: 1.0000e-04
# Epoch 61/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9845 - loss: 0.8596
# Epoch 61: val_loss improved from 0.77311 to 0.76099, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9844 - loss: 0.8590 - val_accuracy: 0.9852 - val_loss: 0.7610 - learning_rate: 1.0000e-04
# Epoch 62/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9635 - loss: 0.8566
# Epoch 62: val_loss did not improve from 0.76099
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9637 - loss: 0.8565 - val_accuracy: 0.9873 - val_loss: 0.7667 - learning_rate: 1.0000e-04
# Epoch 63/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9723 - loss: 0.8461
# Epoch 63: val_loss did not improve from 0.76099
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9722 - loss: 0.8464 - val_accuracy: 0.9831 - val_loss: 0.7691 - learning_rate: 1.0000e-04
# Epoch 64/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9719 - loss: 0.8388
# Epoch 64: val_loss improved from 0.76099 to 0.75046, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9719 - loss: 0.8389 - val_accuracy: 0.9895 - val_loss: 0.7505 - learning_rate: 1.0000e-04
# Epoch 65/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9773 - loss: 0.8455
# Epoch 65: val_loss did not improve from 0.75046
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9772 - loss: 0.8453 - val_accuracy: 0.9852 - val_loss: 0.7607 - learning_rate: 1.0000e-04
# Epoch 66/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9784 - loss: 0.8327
# Epoch 66: val_loss did not improve from 0.75046
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9781 - loss: 0.8330 - val_accuracy: 0.9768 - val_loss: 0.7616 - learning_rate: 1.0000e-04
# Epoch 67/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9853 - loss: 0.8166
# Epoch 67: val_loss improved from 0.75046 to 0.73397, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9852 - loss: 0.8167 - val_accuracy: 0.9937 - val_loss: 0.7340 - learning_rate: 1.0000e-04
# Epoch 68/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9669 - loss: 0.8426
# Epoch 68: val_loss improved from 0.73397 to 0.72745, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9671 - loss: 0.8422 - val_accuracy: 0.9937 - val_loss: 0.7274 - learning_rate: 1.0000e-04
# Epoch 69/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9673 - loss: 0.8424
# Epoch 69: val_loss did not improve from 0.72745
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9673 - loss: 0.8422 - val_accuracy: 0.9916 - val_loss: 0.7433 - learning_rate: 1.0000e-04
# Epoch 70/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9760 - loss: 0.8261
# Epoch 70: val_loss did not improve from 0.72745
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9761 - loss: 0.8260 - val_accuracy: 0.9852 - val_loss: 0.7421 - learning_rate: 1.0000e-04
# Epoch 71/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9763 - loss: 0.8207
# Epoch 71: val_loss improved from 0.72745 to 0.72471, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9763 - loss: 0.8207 - val_accuracy: 0.9958 - val_loss: 0.7247 - learning_rate: 1.0000e-04
# Epoch 72/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9733 - loss: 0.8222
# Epoch 72: val_loss improved from 0.72471 to 0.71756, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9735 - loss: 0.8219 - val_accuracy: 0.9958 - val_loss: 0.7176 - learning_rate: 1.0000e-04
# Epoch 73/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9841 - loss: 0.8059
# Epoch 73: val_loss did not improve from 0.71756
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9840 - loss: 0.8059 - val_accuracy: 0.9937 - val_loss: 0.7206 - learning_rate: 1.0000e-04
# Epoch 74/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9817 - loss: 0.8050
# Epoch 74: val_loss did not improve from 0.71756
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9817 - loss: 0.8050 - val_accuracy: 0.9895 - val_loss: 0.7247 - learning_rate: 1.0000e-04
# Epoch 75/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9815 - loss: 0.8066
# Epoch 75: val_loss did not improve from 0.71756
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9815 - loss: 0.8067 - val_accuracy: 0.9916 - val_loss: 0.7190 - learning_rate: 1.0000e-04
# Epoch 76/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9742 - loss: 0.8085
# Epoch 76: val_loss did not improve from 0.71756
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9743 - loss: 0.8085 - val_accuracy: 0.9895 - val_loss: 0.7295 - learning_rate: 1.0000e-04
# Epoch 77/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9805 - loss: 0.8006
# Epoch 77: val_loss did not improve from 0.71756
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9805 - loss: 0.8007 - val_accuracy: 0.9916 - val_loss: 0.7179 - learning_rate: 1.0000e-04
# Epoch 78/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9834 - loss: 0.7957
# Epoch 78: val_loss improved from 0.71756 to 0.71562, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9834 - loss: 0.7961 - val_accuracy: 0.9916 - val_loss: 0.7156 - learning_rate: 1.0000e-04
# Epoch 79/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9842 - loss: 0.7994
# Epoch 79: val_loss did not improve from 0.71562
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9843 - loss: 0.7989 - val_accuracy: 0.9895 - val_loss: 0.7244 - learning_rate: 1.0000e-04
# Epoch 80/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9864 - loss: 0.7885
# Epoch 80: val_loss improved from 0.71562 to 0.71232, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9864 - loss: 0.7884 - val_accuracy: 0.9916 - val_loss: 0.7123 - learning_rate: 1.0000e-04
# Epoch 81/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9877 - loss: 0.7753
# Epoch 81: val_loss did not improve from 0.71232
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9876 - loss: 0.7757 - val_accuracy: 0.9831 - val_loss: 0.7274 - learning_rate: 1.0000e-04
# Epoch 82/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9835 - loss: 0.7929
# Epoch 82: val_loss did not improve from 0.71232
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9834 - loss: 0.7929 - val_accuracy: 0.9873 - val_loss: 0.7168 - learning_rate: 1.0000e-04
# Epoch 83/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9893 - loss: 0.7896
# Epoch 83: val_loss improved from 0.71232 to 0.70178, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9892 - loss: 0.7893 - val_accuracy: 0.9937 - val_loss: 0.7018 - learning_rate: 1.0000e-04
# Epoch 84/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9865 - loss: 0.7783
# Epoch 84: val_loss did not improve from 0.70178
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9864 - loss: 0.7784 - val_accuracy: 0.9895 - val_loss: 0.7083 - learning_rate: 1.0000e-04
# Epoch 85/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9866 - loss: 0.7869
# Epoch 85: val_loss did not improve from 0.70178
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9866 - loss: 0.7868 - val_accuracy: 0.9937 - val_loss: 0.7209 - learning_rate: 1.0000e-04
# Epoch 86/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9773 - loss: 0.7976
# Epoch 86: val_loss did not improve from 0.70178
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9775 - loss: 0.7975 - val_accuracy: 0.9916 - val_loss: 0.7094 - learning_rate: 1.0000e-04
# Epoch 87/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9912 - loss: 0.7688
# Epoch 87: val_loss improved from 0.70178 to 0.69326, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9912 - loss: 0.7689 - val_accuracy: 0.9958 - val_loss: 0.6933 - learning_rate: 1.0000e-04
# Epoch 88/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9827 - loss: 0.7746
# Epoch 88: val_loss did not improve from 0.69326
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9828 - loss: 0.7745 - val_accuracy: 0.9958 - val_loss: 0.7069 - learning_rate: 1.0000e-04
# Epoch 89/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9893 - loss: 0.7717
# Epoch 89: val_loss improved from 0.69326 to 0.68731, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9892 - loss: 0.7716 - val_accuracy: 0.9958 - val_loss: 0.6873 - learning_rate: 1.0000e-04
# Epoch 90/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9862 - loss: 0.7622
# Epoch 90: val_loss did not improve from 0.68731
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9862 - loss: 0.7623 - val_accuracy: 0.9958 - val_loss: 0.7048 - learning_rate: 1.0000e-04
# Epoch 91/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9864 - loss: 0.7585
# Epoch 91: val_loss did not improve from 0.68731
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9864 - loss: 0.7586 - val_accuracy: 0.9958 - val_loss: 0.6961 - learning_rate: 1.0000e-04
# Epoch 92/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9876 - loss: 0.7652
# Epoch 92: val_loss improved from 0.68731 to 0.68685, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9877 - loss: 0.7652 - val_accuracy: 0.9958 - val_loss: 0.6869 - learning_rate: 1.0000e-04
# Epoch 93/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9872 - loss: 0.7574
# Epoch 93: val_loss did not improve from 0.68685
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9872 - loss: 0.7574 - val_accuracy: 0.9937 - val_loss: 0.6953 - learning_rate: 1.0000e-04
# Epoch 94/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9935 - loss: 0.7458
# Epoch 94: val_loss did not improve from 0.68685
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9934 - loss: 0.7460 - val_accuracy: 0.9916 - val_loss: 0.7015 - learning_rate: 1.0000e-04
# Epoch 95/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9936 - loss: 0.7506
# Epoch 95: val_loss improved from 0.68685 to 0.67618, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9935 - loss: 0.7508 - val_accuracy: 0.9958 - val_loss: 0.6762 - learning_rate: 1.0000e-04
# Epoch 96/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9878 - loss: 0.7476
# Epoch 96: val_loss did not improve from 0.67618
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9878 - loss: 0.7478 - val_accuracy: 0.9873 - val_loss: 0.6854 - learning_rate: 1.0000e-04
# Epoch 97/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9866 - loss: 0.7499
# Epoch 97: val_loss did not improve from 0.67618
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9866 - loss: 0.7500 - val_accuracy: 0.9916 - val_loss: 0.6827 - learning_rate: 1.0000e-04
# Epoch 98/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9905 - loss: 0.7471
# Epoch 98: val_loss did not improve from 0.67618
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9905 - loss: 0.7470 - val_accuracy: 0.9979 - val_loss: 0.6855 - learning_rate: 1.0000e-04
# Epoch 99/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9903 - loss: 0.7301
# Epoch 99: val_loss improved from 0.67618 to 0.67433, saving model to best_cnn_2d_model.keras_fold_1.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9903 - loss: 0.7304 - val_accuracy: 0.9979 - val_loss: 0.6743 - learning_rate: 1.0000e-04
# Epoch 100/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9893 - loss: 0.7456
# Epoch 100: val_loss did not improve from 0.67433
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9893 - loss: 0.7455 - val_accuracy: 0.9916 - val_loss: 0.6792 - learning_rate: 1.0000e-04
#
# Fold 1 - Evaluation on validation set:
#  - Loss: 0.6743
#  - Accuracy: 0.9979
#
# Training on fold 2/5...
# Train shape: (1896, 107, 157, 1), Val shape: (474, 107, 157, 1)
# Epoch 1/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9775 - loss: 0.7797
# Epoch 1: val_loss improved from inf to 0.69503, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 17s 64ms/step - accuracy: 0.9775 - loss: 0.7797 - val_accuracy: 0.9979 - val_loss: 0.6950 - learning_rate: 1.0000e-04
# Epoch 2/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9794 - loss: 0.7679
# Epoch 2: val_loss improved from 0.69503 to 0.64215, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9795 - loss: 0.7677 - val_accuracy: 1.0000 - val_loss: 0.6422 - learning_rate: 1.0000e-04
# Epoch 3/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9887 - loss: 0.7572
# Epoch 3: val_loss improved from 0.64215 to 0.63773, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9886 - loss: 0.7570 - val_accuracy: 1.0000 - val_loss: 0.6377 - learning_rate: 1.0000e-04
# Epoch 4/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9910 - loss: 0.7286
# Epoch 4: val_loss improved from 0.63773 to 0.63468, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9909 - loss: 0.7289 - val_accuracy: 1.0000 - val_loss: 0.6347 - learning_rate: 1.0000e-04
# Epoch 5/100
# 117/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9906 - loss: 0.7365
# Epoch 5: val_loss improved from 0.63468 to 0.63297, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9906 - loss: 0.7366 - val_accuracy: 1.0000 - val_loss: 0.6330 - learning_rate: 1.0000e-04
# Epoch 6/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9827 - loss: 0.7435
# Epoch 6: val_loss improved from 0.63297 to 0.62890, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9828 - loss: 0.7434 - val_accuracy: 1.0000 - val_loss: 0.6289 - learning_rate: 1.0000e-04
# Epoch 7/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9822 - loss: 0.7297
# Epoch 7: val_loss did not improve from 0.62890
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9824 - loss: 0.7299 - val_accuracy: 1.0000 - val_loss: 0.6314 - learning_rate: 1.0000e-04
# Epoch 8/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9922 - loss: 0.7449
# Epoch 8: val_loss did not improve from 0.62890
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9921 - loss: 0.7444 - val_accuracy: 1.0000 - val_loss: 0.6320 - learning_rate: 1.0000e-04
# Epoch 9/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9855 - loss: 0.7324
# Epoch 9: val_loss improved from 0.62890 to 0.62605, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9857 - loss: 0.7321 - val_accuracy: 1.0000 - val_loss: 0.6260 - learning_rate: 1.0000e-04
# Epoch 10/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9816 - loss: 0.7331
# Epoch 10: val_loss improved from 0.62605 to 0.62555, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9817 - loss: 0.7333 - val_accuracy: 1.0000 - val_loss: 0.6255 - learning_rate: 1.0000e-04
# Epoch 11/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9949 - loss: 0.7141
# Epoch 11: val_loss improved from 0.62555 to 0.62552, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9948 - loss: 0.7142 - val_accuracy: 1.0000 - val_loss: 0.6255 - learning_rate: 1.0000e-04
# Epoch 12/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9956 - loss: 0.7191
# Epoch 12: val_loss did not improve from 0.62552
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9955 - loss: 0.7193 - val_accuracy: 1.0000 - val_loss: 0.6267 - learning_rate: 1.0000e-04
# Epoch 13/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9926 - loss: 0.7337
# Epoch 13: val_loss improved from 0.62552 to 0.62126, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9926 - loss: 0.7332 - val_accuracy: 1.0000 - val_loss: 0.6213 - learning_rate: 1.0000e-04
# Epoch 14/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9951 - loss: 0.7167
# Epoch 14: val_loss improved from 0.62126 to 0.61716, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9951 - loss: 0.7166 - val_accuracy: 1.0000 - val_loss: 0.6172 - learning_rate: 1.0000e-04
# Epoch 15/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9926 - loss: 0.7203
# Epoch 15: val_loss did not improve from 0.61716
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9926 - loss: 0.7200 - val_accuracy: 1.0000 - val_loss: 0.6524 - learning_rate: 1.0000e-04
# Epoch 16/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9904 - loss: 0.7115
# Epoch 16: val_loss did not improve from 0.61716
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9905 - loss: 0.7117 - val_accuracy: 1.0000 - val_loss: 0.6201 - learning_rate: 1.0000e-04
# Epoch 17/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9938 - loss: 0.7198
# Epoch 17: val_loss did not improve from 0.61716
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9938 - loss: 0.7195 - val_accuracy: 1.0000 - val_loss: 0.6177 - learning_rate: 1.0000e-04
# Epoch 18/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9954 - loss: 0.7128
# Epoch 18: val_loss did not improve from 0.61716
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9953 - loss: 0.7129 - val_accuracy: 1.0000 - val_loss: 0.6218 - learning_rate: 1.0000e-04
# Epoch 19/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9961 - loss: 0.7074
# Epoch 19: val_loss did not improve from 0.61716
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9961 - loss: 0.7074 - val_accuracy: 1.0000 - val_loss: 0.6177 - learning_rate: 1.0000e-04
# Epoch 20/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9967 - loss: 0.7064
# Epoch 20: val_loss improved from 0.61716 to 0.61105, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9967 - loss: 0.7064 - val_accuracy: 1.0000 - val_loss: 0.6111 - learning_rate: 1.0000e-04
# Epoch 21/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9898 - loss: 0.7065
# Epoch 21: val_loss did not improve from 0.61105
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9899 - loss: 0.7064 - val_accuracy: 1.0000 - val_loss: 0.6130 - learning_rate: 1.0000e-04
# Epoch 22/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9916 - loss: 0.7017
# Epoch 22: val_loss did not improve from 0.61105
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9916 - loss: 0.7017 - val_accuracy: 1.0000 - val_loss: 0.6153 - learning_rate: 1.0000e-04
# Epoch 23/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9976 - loss: 0.6885
# Epoch 23: val_loss did not improve from 0.61105
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9976 - loss: 0.6889 - val_accuracy: 1.0000 - val_loss: 0.6143 - learning_rate: 1.0000e-04
# Epoch 24/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9886 - loss: 0.7047
# Epoch 24: val_loss did not improve from 0.61105
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9887 - loss: 0.7048 - val_accuracy: 1.0000 - val_loss: 0.6150 - learning_rate: 1.0000e-04
# Epoch 25/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9908 - loss: 0.7140
# Epoch 25: val_loss improved from 0.61105 to 0.60993, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9909 - loss: 0.7136 - val_accuracy: 1.0000 - val_loss: 0.6099 - learning_rate: 1.0000e-04
# Epoch 26/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9868 - loss: 0.6926
# Epoch 26: val_loss did not improve from 0.60993
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9870 - loss: 0.6927 - val_accuracy: 1.0000 - val_loss: 0.6250 - learning_rate: 1.0000e-04
# Epoch 27/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9932 - loss: 0.6975
# Epoch 27: val_loss did not improve from 0.60993
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9933 - loss: 0.6974 - val_accuracy: 1.0000 - val_loss: 0.6113 - learning_rate: 1.0000e-04
# Epoch 28/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - loss: 0.6946
# Epoch 28: val_loss improved from 0.60993 to 0.60880, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9915 - loss: 0.6944 - val_accuracy: 1.0000 - val_loss: 0.6088 - learning_rate: 1.0000e-04
# Epoch 29/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9957 - loss: 0.6916
# Epoch 29: val_loss did not improve from 0.60880
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9956 - loss: 0.6916 - val_accuracy: 1.0000 - val_loss: 0.6102 - learning_rate: 1.0000e-04
# Epoch 30/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9978 - loss: 0.6891
# Epoch 30: val_loss improved from 0.60880 to 0.60634, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9978 - loss: 0.6889 - val_accuracy: 1.0000 - val_loss: 0.6063 - learning_rate: 1.0000e-04
# Epoch 31/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9981 - loss: 0.6817
# Epoch 31: val_loss improved from 0.60634 to 0.60539, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9981 - loss: 0.6818 - val_accuracy: 1.0000 - val_loss: 0.6054 - learning_rate: 1.0000e-04
# Epoch 32/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9968 - loss: 0.6796
# Epoch 32: val_loss improved from 0.60539 to 0.60531, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9969 - loss: 0.6796 - val_accuracy: 1.0000 - val_loss: 0.6053 - learning_rate: 1.0000e-04
# Epoch 33/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9951 - loss: 0.6884
# Epoch 33: val_loss did not improve from 0.60531
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9951 - loss: 0.6883 - val_accuracy: 1.0000 - val_loss: 0.6146 - learning_rate: 1.0000e-04
# Epoch 34/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9938 - loss: 0.6841
# Epoch 34: val_loss improved from 0.60531 to 0.60114, saving model to best_cnn_2d_model.keras_fold_2.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9938 - loss: 0.6841 - val_accuracy: 1.0000 - val_loss: 0.6011 - learning_rate: 1.0000e-04
# Epoch 35/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9954 - loss: 0.6763
# Epoch 35: val_loss did not improve from 0.60114
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9955 - loss: 0.6762 - val_accuracy: 1.0000 - val_loss: 0.6305 - learning_rate: 1.0000e-04
# Epoch 36/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9960 - loss: 0.6763
# Epoch 36: val_loss did not improve from 0.60114
# ...
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5316 - val_accuracy: 1.0000 - val_loss: 0.4916 - learning_rate: 2.0000e-05
# Epoch 80/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5321
# Epoch 80: val_loss did not improve from 0.49113
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5320 - val_accuracy: 1.0000 - val_loss: 0.4922 - learning_rate: 2.0000e-05
# Epoch 81/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9999 - loss: 0.5251
# Epoch 81: val_loss did not improve from 0.49113
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9999 - loss: 0.5253 - val_accuracy: 1.0000 - val_loss: 0.4911 - learning_rate: 2.0000e-05
# Epoch 82/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5303
# Epoch 82: val_loss did not improve from 0.49113
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5302 - val_accuracy: 1.0000 - val_loss: 0.4943 - learning_rate: 2.0000e-05
# Epoch 83/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5291
# Epoch 83: val_loss improved from 0.49113 to 0.49077, saving model to best_cnn_2d_model.keras_fold_4.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 1.0000 - loss: 0.5291 - val_accuracy: 1.0000 - val_loss: 0.4908 - learning_rate: 2.0000e-05
# Epoch 84/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5304
# Epoch 84: val_loss did not improve from 0.49077
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5304 - val_accuracy: 1.0000 - val_loss: 0.4923 - learning_rate: 2.0000e-05
# Epoch 85/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5288
# Epoch 85: val_loss did not improve from 0.49077
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5288 - val_accuracy: 1.0000 - val_loss: 0.4911 - learning_rate: 2.0000e-05
# Epoch 86/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5286
# Epoch 86: val_loss did not improve from 0.49077
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5286 - val_accuracy: 1.0000 - val_loss: 0.4909 - learning_rate: 2.0000e-05
# Epoch 87/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5312
# Epoch 87: val_loss did not improve from 0.49077
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5312 - val_accuracy: 1.0000 - val_loss: 0.4909 - learning_rate: 2.0000e-05
# Epoch 88/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5315
# Epoch 88: val_loss did not improve from 0.49077
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5314 - val_accuracy: 1.0000 - val_loss: 0.4993 - learning_rate: 2.0000e-05
# Epoch 89/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5292
# Epoch 89: val_loss did not improve from 0.49077
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5291 - val_accuracy: 1.0000 - val_loss: 0.4998 - learning_rate: 2.0000e-05
# Epoch 90/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5272
# Epoch 90: val_loss improved from 0.49077 to 0.48991, saving model to best_cnn_2d_model.keras_fold_4.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 1.0000 - loss: 0.5272 - val_accuracy: 1.0000 - val_loss: 0.4899 - learning_rate: 2.0000e-05
# Epoch 91/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5259
# Epoch 91: val_loss improved from 0.48991 to 0.48947, saving model to best_cnn_2d_model.keras_fold_4.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 1.0000 - loss: 0.5259 - val_accuracy: 1.0000 - val_loss: 0.4895 - learning_rate: 2.0000e-05
# Epoch 92/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5205
# Epoch 92: val_loss did not improve from 0.48947
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5207 - val_accuracy: 1.0000 - val_loss: 0.4901 - learning_rate: 2.0000e-05
# Epoch 93/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5389
# Epoch 93: val_loss did not improve from 0.48947
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.5386 - val_accuracy: 1.0000 - val_loss: 0.4898 - learning_rate: 2.0000e-05
# Epoch 94/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5265
# Epoch 94: val_loss improved from 0.48947 to 0.48879, saving model to best_cnn_2d_model.keras_fold_4.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 1.0000 - loss: 0.5266 - val_accuracy: 1.0000 - val_loss: 0.4888 - learning_rate: 2.0000e-05
# Epoch 95/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5302
# Epoch 95: val_loss did not improve from 0.48879
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5302 - val_accuracy: 1.0000 - val_loss: 0.4891 - learning_rate: 2.0000e-05
# Epoch 96/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5306
# Epoch 96: val_loss improved from 0.48879 to 0.48876, saving model to best_cnn_2d_model.keras_fold_4.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 1.0000 - loss: 0.5305 - val_accuracy: 1.0000 - val_loss: 0.4888 - learning_rate: 2.0000e-05
# Epoch 97/100
# 117/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5310
# Epoch 97: val_loss did not improve from 0.48876
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5309 - val_accuracy: 1.0000 - val_loss: 0.4898 - learning_rate: 2.0000e-05
# Epoch 98/100
# 117/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5265
# Epoch 98: val_loss did not improve from 0.48876
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5265 - val_accuracy: 1.0000 - val_loss: 0.4910 - learning_rate: 2.0000e-05
# Epoch 99/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5281
# Epoch 99: val_loss did not improve from 0.48876
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5281 - val_accuracy: 1.0000 - val_loss: 0.4892 - learning_rate: 2.0000e-05
# Epoch 100/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5257
# Epoch 100: val_loss did not improve from 0.48876
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5258 - val_accuracy: 1.0000 - val_loss: 0.4893 - learning_rate: 2.0000e-05
#
# Fold 4 - Evaluation on validation set:
#  - Loss: 0.4888
#  - Accuracy: 1.0000
#
# Training on fold 5/5...
# Train shape: (1896, 107, 157, 1), Val shape: (474, 107, 157, 1)
# Epoch 1/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.5378
# Epoch 1: val_loss improved from inf to 0.49171, saving model to best_cnn_2d_model.keras_fold_5.h5
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 18s 67ms/step - accuracy: 1.0000 - loss: 0.5378 - val_accuracy: 1.0000 - val_loss: 0.4917 - learning_rate: 1.0000e-04
# Epoch 2/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5380
# Epoch 2: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5380 - val_accuracy: 1.0000 - val_loss: 0.4981 - learning_rate: 1.0000e-04
# Epoch 3/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5393
# Epoch 3: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5395 - val_accuracy: 0.9979 - val_loss: 0.7431 - learning_rate: 1.0000e-04
# Epoch 4/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5408
# Epoch 4: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5410 - val_accuracy: 1.0000 - val_loss: 0.5010 - learning_rate: 1.0000e-04
# Epoch 5/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9997 - loss: 0.5474
# Epoch 5: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9997 - loss: 0.5474 - val_accuracy: 1.0000 - val_loss: 0.6961 - learning_rate: 1.0000e-04
# Epoch 6/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5492
# Epoch 6: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5492 - val_accuracy: 1.0000 - val_loss: 0.5185 - learning_rate: 1.0000e-04
# Epoch 7/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5488
# Epoch 7: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5488 - val_accuracy: 1.0000 - val_loss: 0.5016 - learning_rate: 1.0000e-04
# Epoch 8/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5457
# Epoch 8: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5457 - val_accuracy: 1.0000 - val_loss: 0.5022 - learning_rate: 1.0000e-04
# Epoch 9/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5521
# Epoch 9: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5519 - val_accuracy: 1.0000 - val_loss: 0.5447 - learning_rate: 1.0000e-04
# Epoch 10/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5458
# Epoch 10: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5458 - val_accuracy: 1.0000 - val_loss: 0.5051 - learning_rate: 1.0000e-04
# Epoch 11/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5455
# Epoch 11: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5456 - val_accuracy: 1.0000 - val_loss: 0.5094 - learning_rate: 1.0000e-04
# Epoch 12/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5505
# Epoch 12: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5504 - val_accuracy: 1.0000 - val_loss: 0.5005 - learning_rate: 2.0000e-05
# Epoch 13/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5469
# Epoch 13: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5469 - val_accuracy: 1.0000 - val_loss: 0.4983 - learning_rate: 2.0000e-05
# Epoch 14/100
# 118/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5403
# Epoch 14: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5403 - val_accuracy: 1.0000 - val_loss: 0.4981 - learning_rate: 2.0000e-05
# Epoch 15/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5455
# Epoch 15: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5452 - val_accuracy: 1.0000 - val_loss: 0.4991 - learning_rate: 2.0000e-05
# Epoch 16/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5361
# Epoch 16: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5362 - val_accuracy: 1.0000 - val_loss: 0.5005 - learning_rate: 2.0000e-05
# Epoch 17/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5355
# Epoch 17: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5356 - val_accuracy: 1.0000 - val_loss: 0.4959 - learning_rate: 2.0000e-05
# Epoch 18/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9998 - loss: 0.5381
# Epoch 18: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9998 - loss: 0.5381 - val_accuracy: 1.0000 - val_loss: 0.4953 - learning_rate: 2.0000e-05
# Epoch 19/100
# 116/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5323
# Epoch 19: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5325 - val_accuracy: 1.0000 - val_loss: 0.4983 - learning_rate: 2.0000e-05
# Epoch 20/100
# 115/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5431
# Epoch 20: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5429 - val_accuracy: 1.0000 - val_loss: 0.4961 - learning_rate: 2.0000e-05
# Epoch 21/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.5416
# Epoch 21: val_loss did not improve from 0.49171
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 0.5415 - val_accuracy: 1.0000 - val_loss: 0.4944 - learning_rate: 2.0000e-05
#
# Fold 5 - Evaluation on validation set:
#  - Loss: 0.4917
#  - Accuracy: 1.0000
#
# Average results across 5 folds:
#  - Average Loss: 0.5448
#  - Average Accuracy: 0.9996
# ------------------------------
#
# --- Evaluating on the held-out test set ---
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 22 variables whereas the saved optimizer has 42 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Total number of test audio files: 61
# Processed: 61 samples, skipped: 0 files.
# Test dataset shape: X=(61, 107, 157, 1), y=(61, 7)
#
# Final Test Set Performance:
#
# Sample prediction probabilities:
# Sample 1: True=Fear, Pred=Fear, Prob=[0.11050532 0.04099517 0.6436565  0.10500804 0.02834419 0.04234979
#  0.02914098]
# Sample 2: True=Fear, Pred=Fear, Prob=[0.02531813 0.03611145 0.84352183 0.03607442 0.01810805 0.02241723
#  0.01844889]
# Sample 3: True=Fear, Pred=Fear, Prob=[0.07069461 0.0626443  0.36656308 0.32171524 0.04977407 0.05770046
#  0.07090818]
# Sample 4: True=Fear, Pred=Fear, Prob=[0.11434055 0.03415308 0.6757735  0.02550624 0.03063947 0.09727187
#  0.02231533]
# Sample 5: True=Fear, Pred=Fear, Prob=[0.00821034 0.00881706 0.94810295 0.01605927 0.00913989 0.00475622
#  0.0049142 ]
# Classification Report:
#               precision    recall  f1-score   support
#
#        Angry       0.86      1.00      0.93        19
#        Happy       1.00      0.75      0.86         8
#         Fear       1.00      0.86      0.92         7
#      Neutral       0.89      0.89      0.89         9
#          Sad       1.00      0.80      0.89         5
#      Boredom       0.70      0.88      0.78         8
#      Disgust       1.00      0.80      0.89         5
#
#     accuracy                           0.89        61
#    macro avg       0.92      0.85      0.88        61
# weighted avg       0.90      0.89      0.89        61
#
#
# Evaluation metric formulas:
# 1. Precision = TP / (TP + FP)
#    - TP (True Positives): Number of samples correctly predicted for a class.
#    - FP (False Positives): Number of samples incorrectly predicted as that class.
# 2. Recall = TP / (TP + FN)
#    - FN (False Negatives): Number of samples that belong to the class but were incorrectly predicted.
# 3. F1 Score = 2 * (Precision * Recall) / (Precision + Recall)
#
# --- Predictions on individual test files ---
# Prediction probabilities for /kaggle/input/speech-emotion-10/EmoDB/EmoDB/Fear/10a02Ab.wav: [0.11050529 0.04099515 0.64365655 0.10500805 0.02834417 0.04234977
#  0.02914097]
# File: 10a02Ab.wav | True: Fear | Predicted: Fear
# Prediction probabilities for /kaggle/input/speech-emotion-10/EmoDB/EmoDB/Fear/11a04Ac.wav: [0.02531813 0.03611145 0.8435218  0.03607442 0.01810806 0.02241724
#  0.01844889]
# File: 11a04Ac.wav | True: Fear | Predicted: Fear
# Prediction probabilities for /kaggle/input/speech-emotion-10/EmoDB/EmoDB/Fear/15b09Ac.wav: [0.0706946  0.0626443  0.36656302 0.32171533 0.04977407 0.05770045
#  0.07090817]
# File: 15b09Ac.wav | True: Fear | Predicted: Fear
# Prediction probabilities for /kaggle/input/speech-emotion-10/EmoDB/EmoDB/Fear/16b01Aa.wav: [0.11434058 0.03415306 0.6757735  0.02550623 0.03063946 0.09727187
#  0.02231533]
# File: 16b01Aa.wav | True: Fear | Predicted: Fear
# Prediction probabilities for /kaggle/input/speech-emotion-10/EmoDB/EmoDB/Fear/13a04Ac.wav: [0.00821034 0.00881706 0.94810295 0.01605927 0.00913989 0.00475622
#  0.0049142 ]
# File: 13a04Ac.wav | True: Fear | Predicted: Fear
